# %% [markdown]
# # Bases de Datos II. NoSQL MongoDB 3 (sesión 4)
#
# ```
#                                                                   ,gggggggggggg,    ,ggggggggggg,
#                                                                  dP"""88""""""Y8b, dP"""88""""""Y8,
#                                                                  Yb,  88       `8b,Yb,  88      `8b
#                                                                   `"  88        `8b `"  88      ,8P
#                                                                       88         Y8     88aaaad8P"
#   ,ggg,,ggg,,ggg,     ,ggggg,    ,ggg,,ggg,     ,gggg,gg    ,ggggg,   88         d8     88""""Y8ba
#  ,8" "8P" "8P" "8,   dP"  "Y8ggg,8" "8P" "8,   dP"  "Y8I   dP"  "Y8ggg88        ,8P     88      `8b
#  I8   8I   8I   8I  i8'    ,8I  I8   8I   8I  i8'    ,8I  i8'    ,8I  88       ,8P'     88      ,8P
# ,dP   8I   8I   Yb,,d8,   ,d8' ,dP   8I   Yb,,d8,   ,d8I ,d8,   ,d8'  88______,dP'      88_____,d8'
# 8P'   8I   8I   `Y8P"Y8888P"   8P'   8I   `Y8P"Y8888P"888P"Y8888P"   888888888P"       88888888P"
#                                                     ,d8I'
#                                                   ,dP'8I
#                                                  ,8"  8I
#                                                  I8   8I
#                                                  `8, ,8I
#                                                   `Y8P"
#
#
#                                              ______
# |_  _  _  _  _     _| _     _| _ _|_ _  _     |  |
# |_)(_|_> (/__>    (_|(/_   (_|(_| |_(_)_>    _|__|_
# ```

# %% [markdown]
# ![MongoDB](https://webassets.mongodb.com/_com_assets/cms/MongoDB_Logo_FullColorBlack_RGB-4td3yuxzjs.png)
#
# Esta hoja es la tercera entrega y última del trabajo con MongoDB. Veremos temas avanzados como cálculos `aggregate()` más complejos, el uso de índices, etc. Al final habrá un conjunto de ejercicios que habrá que resolver y entregar en la tarea abierta para la ocasión.

# %% [markdown]
# ## Inicio de la hoja

# %%
RunningInCOLAB: bool = 'google.colab' in str(get_ipython()) if hasattr(__builtins__,'__IPYTHON__') else False

# %%
# !sudo apt-get update -qq
# !sudo apt-get install -y -qq gpg p7zip
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %% [markdown]
# ## Instalación inicial de MongoDB (sólo necesaria en Google Colab)

# %%
if RunningInCOLAB:
  # !wget -q https://raw.githubusercontent.com/dsevilla/bdge/refs/heads/24-25/addendum/mongo-utils/run-mongo-local.sh
  # !bash run-mongo-local.sh
# Out:
# Adding system user `mongodb' (UID 104) ...
# Adding new user `mongodb' (UID 104) with group `nogroup' ...
# Not creating home directory `/home/mongodb'.
# Adding group `mongodb' (GID 107) ...
# Done.
# Adding user `mongodb' to group `mongodb' ...
# Adding user mongodb to group mongodb
# Done.
# deb [ arch=amd64,arm64 ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/8.0 multiverse
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 10.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dialog.
# (Reading database ... 124947 files and directories currently installed.)
# Preparing to unpack .../0-dialog_1.3-20211214-1_amd64.deb ...
# Unpacking dialog (1.3-20211214-1) ...
# Selecting previously unselected package mongodb-database-tools.
# Preparing to unpack .../1-mongodb-database-tools_100.11.0_amd64.deb ...
# Unpacking mongodb-database-tools (100.11.0) ...
# Selecting previously unselected package mongodb-mongosh.
# Preparing to unpack .../2-mongodb-mongosh_2.4.0_amd64.deb ...
# Unpacking mongodb-mongosh (2.4.0) ...
# Selecting previously unselected package mongodb-org-shell.
# Preparing to unpack .../3-mongodb-org-shell_8.0.5_amd64.deb ...
# Unpacking mongodb-org-shell (8.0.5) ...
# Selecting previously unselected package mongodb-org-server.
# Preparing to unpack .../4-mongodb-org-server_8.0.5_amd64.deb ...
# Unpacking mongodb-org-server (8.0.5) ...
# Selecting previously unselected package mongodb-org-mongos.
# Preparing to unpack .../5-mongodb-org-mongos_8.0.5_amd64.deb ...
# Unpacking mongodb-org-mongos (8.0.5) ...
# Selecting previously unselected package mongodb-org-database-tools-extra.
# Preparing to unpack .../6-mongodb-org-database-tools-extra_8.0.5_amd64.deb ...
# Unpacking mongodb-org-database-tools-extra (8.0.5) ...
# Selecting previously unselected package mongodb-org-database.
# Preparing to unpack .../7-mongodb-org-database_8.0.5_amd64.deb ...
# Unpacking mongodb-org-database (8.0.5) ...
# Selecting previously unselected package mongodb-org-tools.
# Preparing to unpack .../8-mongodb-org-tools_8.0.5_amd64.deb ...
# Unpacking mongodb-org-tools (8.0.5) ...
# Selecting previously unselected package mongodb-org.
# Preparing to unpack .../9-mongodb-org_8.0.5_amd64.deb ...
# Unpacking mongodb-org (8.0.5) ...
# Setting up mongodb-mongosh (2.4.0) ...
# Setting up mongodb-org-server (8.0.5) ...
# Setting up mongodb-org-shell (8.0.5) ...
# Setting up dialog (1.3-20211214-1) ...
# Setting up mongodb-database-tools (100.11.0) ...
# Setting up mongodb-org-mongos (8.0.5) ...
# Setting up mongodb-org-database-tools-extra (8.0.5) ...
# Setting up mongodb-org-database (8.0.5) ...
# Setting up mongodb-org-tools (8.0.5) ...
# Setting up mongodb-org (8.0.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# about to fork child process, waiting until server is ready for connections.
# forked process: 4359
# child process started successfully, parent exiting
# db version v8.0.5
# Build Info: {
#     "version": "8.0.5",
#     "gitVersion": "cb9e2e5e552ee39dea1e39d7859336456d0c9820",
#     "openSSLVersion": "OpenSSL 3.0.2 15 Mar 2022",
#     "modules": [],
#     "allocator": "tcmalloc-google",
#     "environment": {
#         "distmod": "ubuntu2204",
#         "distarch": "x86_64",
#         "target_arch": "x86_64"
#     }
# }

# %% [markdown]
# ## Descarga de los datos en formato CSV

# %% [markdown]
#  - Formato: 7zipped
#  - Ficheros:
#    - **Comments**.csv
#        - Id
#        - PostId
#        - Score
#        - Text, e.g.: "@Stu Thompson: Seems possible to me - why not try it?"
#        - CreationDate, e.g.:"2008-09-06T08:07:10.730"
#        - UserId
#    - **Posts**.csv
#        - Id
#        - PostTypeId
#           - 1: Question
#           - 2: Answer
#        - ParentID (only present if PostTypeId is 2)
#        - AcceptedAnswerId (only present if PostTypeId is 1)
#        - CreationDate
#        - Score
#        - ViewCount
#        - Body
#        - OwnerUserId
#        - LastEditorUserId
#        - LastEditorDisplayName="Jeff Atwood"
#        - LastEditDate="2009-03-05T22:28:34.823"
#        - LastActivityDate="2009-03-11T12:51:01.480"
#        - CommunityOwnedDate="2009-03-11T12:51:01.480"
#        - ClosedDate="2009-03-11T12:51:01.480"
#        - Title=
#        - Tags=
#        - AnswerCount
#        - CommentCount
#        - FavoriteCount
#    - **Tags**.csv
#     - Id
#     - Count
#     - ExcerptPostId
#     - TagName
#     - WikiPostId
#    - **Users**.csv
#      - Id
#      - Reputation
#      - CreationDate
#      - DisplayName
#      - EmailHash
#      - LastAccessDate
#      - WebsiteUrl
#      - Location
#      - Age
#      - AboutMe
#      - Views
#      - UpVotes
#      - DownVotes
#    - **Votes**.csv
#      - Id
#      - PostId
#      - VoteTypeId
#         - ` 1`: AcceptedByOriginator
#         - ` 2`: UpMod
#         - ` 3`: DownMod
#         - ` 4`: Offensive
#         - ` 5`: Favorite - if VoteTypeId = 5 UserId will be populated
#         - ` 6`: Close
#         - ` 7`: Reopen
#         - ` 8`: BountyStart
#         - ` 9`: BountyClose
#         - `10`: Deletion
#         - `11`: Undeletion
#         - `12`: Spam
#         - `13`: InformModerator
#      - CreationDate
#      - UserId (only for VoteTypeId 5)
#      - BountyAmount (only for VoteTypeId 9)

# %%
# !wget https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.001 -O - > es.stackoverflow.csv.7z
# !wget https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.002 -O - >> es.stackoverflow.csv.7z
# Out:
# --2025-03-06 10:20:53--  https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.001
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.001 [following]
# --2025-03-06 10:20:54--  https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.001
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104857600 (100M) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>] 100.00M   226MB/s    in 0.4s
#
# 2025-03-06 10:20:54 (226 MB/s) - written to stdout [104857600/104857600]
#
# --2025-03-06 10:20:54--  https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.002
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.002 [following]
# --2025-03-06 10:20:54--  https://raw.githubusercontent.com/dsevilla/bd2-data/main/es.stackoverflow/es.stackoverflow.csv.7z.002
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95599938 (91M) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]  91.17M   136MB/s    in 0.7s
#
# 2025-03-06 10:20:55 (136 MB/s) - written to stdout [95599938/95599938]

# %%
!7zr x es.stackoverflow.csv.7z
# !rm es.stackoverflow.csv.7z
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 200457538 bytes (192 MiB)
#
# Extracting archive: es.stackoverflow.csv.7z
# --
# Path = es.stackoverflow.csv.7z
# Type = 7z
# Physical Size = 200457538
# Headers Size = 248
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Files: 5
# Size:       1044736301
# Compressed: 200457538

# %%
# !head Users.csv
# Out:
# Id,AboutMe,AccountId,CreationDate,DisplayName,DownVotes,LastAccessDate,Location,Reputation,UpVotes,Views,WebsiteUrl
# -1,"<p>Hola, no soy una persona real.</p><br/><br/><p>¡Soy un proceso que ayuda a mantener el sitio limpio!</p><br/><br/><p>Hago cosas como:</p><br/><br/><ul><br/><li>Dar empujoncitos a preguntas antiguas sin respuesta aproximadamente cada hora, para que atraigan algo de atención.</li><br/><li>Tener la propiedad de las preguntas y respuestas wiki para que nadie se lleve reputación por ellas</li><br/><li>Recibir la propiedad de los votos negativos en las publicaciones de spam o dañinas que son borradas permanentemente</li><br/><li>Tener la propiedad de las ediciones sugeridas por usuarios anónimos</li><br/><li><a href=""http://meta.stackoverflow.com/a/92006"">Quitar preguntas abandonadas</a></li><br/></ul><br/>",-1,2015-10-26T21:36:24.767,Comunidad,22504,2015-10-26T21:36:24.767,en la granja de servidores,1,10211,2516,
# 1,"<p>Dev #2 who helped create Stack Overflow currently working at Microsoft. I love all people willing to share their knowledge. Without community we are nothing.</p><br/><p>Find me on:</p><br/><p><a href=""http://www.twitter.com/SuperDalgas"" rel=""nofollow noreferrer"">Twitter</a><br/><br><br><br/><a href=""http://blog.stackoverflow.com/2009/05/welcome-stack-overflow-valued-associate-00003/"">Stack Overflow Valued Associate #00003</a></p><br/>",2,2015-10-26T22:50:12.710,Geoff Dalgas,0,2021-01-05T19:45:26.807,"Corvallis, OR",101,0,2917,http://stackoverflow.com
# 2,"<p>developer, techie, nerd.... ex-DBRE at Stack Overflow, previously a Community Manager for Stack Overflow.  When I'm not at my desk, I do CrossFit and run (a lot).</p><br/>",188123,2015-10-26T22:51:07.007,Taryn,0,2020-08-18T17:39:10.693,Arizona,101,0,109,https://tarynpivots.com
# 3,"<p>Topics you might be interested in reading about:</p><br/><ul><br/><li><a href=""https://jlericson.com/2023/10/16/catija.html"" rel=""nofollow noreferrer"">why Stack Exchange Inc undervalues community managers</a></li><br/><li><a href=""https://jlericson.com/tag/strike"" rel=""nofollow noreferrer"">the moderator strike</a></li><br/><li><a href=""https://jlericson.com/tag/documentation"" rel=""nofollow noreferrer"">documentation</a></li><br/><li><a href=""https://jlericson.com/tag/support"" rel=""nofollow noreferrer"">customer support</a></li><br/></ul><br/><p>I'm Head of Community at <a href=""https://talk.collegeconfidential.com/"" rel=""nofollow noreferrer"">College Confidential</a> and former <a href=""https://jlericson.com/2021/04/30/developer_advocate.html"" rel=""nofollow noreferrer"">Developer Advocate at EDB</a>. Stack Exchange no longer employs me as a <a href=""http://blog.stackoverflow.com/2013/08/please-welcome-jon-ericson-community-manager/"">Community Manager</a>.  I maintain an <a href=""http://chat.meta.stackexchange.com/rooms/738/jons-java-jitter-joint"">office on chat</a>. (Please ignore the meta cruft.)</p><br/><blockquote><br/><p><a href=""https://www.mechon-mamre.org/p/pt/pt2685.htm"" rel=""nofollow noreferrer"">Mercy and truth are met together; righteousness and peace have kissed each other.</a></p><br/></blockquote><br/><p>I write about my experience as a community manager at <a href=""https://jlericson.com/"" rel=""nofollow noreferrer"">jlericson.com</a>. You can read about what I've done over the years in my <a href=""https://web.archive.org/web/20220113195358/https://stackoverflow.com/users/story/1438"" rel=""nofollow noreferrer"" title=""Not guaranteed to be current.""><em>curriculum vitae</em></a>.</p><br/><p>On a personal note, I'm married and have three children.  Our oldest son loves school, friends, games, and music. Two of my children happen to have been born on the same day.  I <a href=""http://taking1and1.wordpress.com/"" rel=""nofollow noreferrer"" title=""Yet another half-assed blog."">sometimes write</a> about that experience. My wife loves taking care of people as a registered nurse and an all around wonderful person.</p><br/><p>Don't have time for a full review of something?  Why not try <a href=""http://fivesecondreview.wordpress.com/"" rel=""nofollow noreferrer"" title=""All reviews accurate and helpful or your money back."">my 5-second reviews</a>?</p><br/><p>I once wrote for <a href=""http://christianity.blogoverflow.com/author/jonericson/"" rel=""nofollow noreferrer"" title=""I haven't been on the rotation for a while, however."">Eschewmenical</a>, which was an experiment of <a href=""http://christianity.stackexchange.com/"">Christianity Stack Exchange</a>. For <em>a lot more</em> writing about the Bible, see <a href=""https://hermeneutics.stackexchange.com/users/68/jon-ericson?tab=summary"">my Biblical Hermeneutics posts</a>.</p><br/><br/>",1083,2015-10-26T22:52:12.923,Jon 'links in bio' Ericson,0,2023-06-04T23:58:02.373,Downtown Burbank,101,0,87,https://jlericson.com/
# 4,"<p>Lover of all things sharp including pencils, wit, and knives but not cheddar.</p><br/>",6254215,2015-10-26T23:18:40.547,Juan M,0,2022-02-11T16:07:18.457,Behind the Glass,101,56,260,
# 5,"<p>I am a Principal Software Engineer at Microsoft working on Azure Functions and related hosting technologies. Formerly the Architecture Lead for Stack Overflow where my day job consisted of being a Developer, Site Reliability Engineer, and DBA.</p><br/><p>I design and build very fast things in hopes of making life easier for millions of developers.</p><br/><p>Blog: <a href=""https://nickcraver.com/blog/"" rel=""nofollow noreferrer"">nickcraver.com/blog</a><br /><br/>Twitter: <a href=""https://twitter.com/Nick_Craver"" rel=""nofollow noreferrer"">@Nick_Craver</a><br /><br/>My Developer Story: <a href=""https://stackoverflow.com/story/ncraver"">stackoverflow.com/story/ncraver</a></p><br/><p><sub>Disclaimer: I have <em>no idea</em> what I'm talking about, all my answers are guesses!</sub></p><br/>",7598,2015-10-26T23:46:20.807,Nick Craver,0,2019-04-02T20:05:34.147,"Winston-Salem, NC",101,0,53,https://nickcraver.com/blog/
# 6,"<p>Chief Technical Officer at <a href=""https://postop.ai"" rel=""nofollow noreferrer"">https://postop.ai</a>.</p><br/><ul><br/><li>Stack Overflow Contributor since 2008</li><br/><li>Skeptics mod since 2011</li><br/><li>Core dev since March 2013</li><br/><li>Stack Overflow alumnus since February 2017</li><br/></ul><br/><p>You can find me on</p><br/><ul><br/><li><a href=""http://sklivvz.com"" rel=""nofollow noreferrer"">Personal site</a></li><br/><li><a href=""https://mastodon.social/@sklivvz"" rel=""nofollow noreferrer"">Mastodon</a></li><br/><li><a href=""https://github.com/sklivvz"" rel=""nofollow noreferrer"">Github</a></li><br/><li><a href=""https://www.linkedin.com/in/sklivvz/"" rel=""nofollow noreferrer"">LinkedIn</a></li><br/></ul><br/>",4623,2015-10-26T23:57:13.187,Sklivvz,0,2017-11-04T17:02:40.430,"Trento, Province of Trento, Italy",101,0,40,https://sklivvz.com
# 7,"<p><a href=""http://blog.stackoverflow.com/2013/09/summer-hiring-happened-so-fast/"">I'm</a> a Web Developer on the Stack Overflow Q&A Core <a href=""http://stackexchange.com/about/team"">team</a>. You can email me via sprelog (at) stackoverflow.com</p><br/>",51875,2015-10-27T07:03:55.417,m0sa,0,2023-01-24T10:24:53.517,Slovenia,101,0,51,
# 8,"<p>My top interests here are:</p><br/><br/><ul><br/><li>Python</li><br/><li>Django</li><br/><li>Software security</li><br/></ul><br/><br/><p>In the past, I used <code>python</code> and <code>django</code> to develop a payment solution at <a href=""https://www.my-bee.fr/pro/"" rel=""nofollow noreferrer"">MyBee</a> - I'm glad they're still going strong today! I also worked at <a href=""http://scalr.com/"" rel=""nofollow noreferrer"">Scalr</a> as a Product Manager, and at <a href=""http://www.accenture.com/"" rel=""nofollow noreferrer"">Accenture</a> as a consultant on business / IT projects. Today, I'm Lead Backend Engineer at <a href=""https://aptible.com"" rel=""nofollow noreferrer"">Aptible</a>.</p><br/><br/><p>Personal email: <code>thomas@orozco.fr</code></p><br/>",467632,2015-10-27T08:25:59.317,Thomas Orozco,0,2017-03-14T23:25:52.540,"Paris, France",101,0,27,

# %% [markdown]
# ## Instalación de la librería `pymongo`

# %%
# %pip install --upgrade pymongo tqdm pandas matplotlib
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.8 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 87.9 MB/s eta 0:00:00
# Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 89.5 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 17.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo, pandas, matplotlib
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed dnspython-2.7.0 matplotlib-3.10.1 pandas-2.2.3 pymongo-4.11.2

# %%
from pprint import pprint as pp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# Usaremos la librería `pymongo` para python. La cargamos a continuación.

# %%
from pymongo import MongoClient

# %% [markdown]
# ## Conexión a la base de datos

# %% [markdown]
# La conexión se inicia con `MongoClient` en el `host` descrito en el fichero `docker-compose.yml` (`mongo`), o bien a `localhost` si lo estamos haciendo en Colab.

# %%
import os
db_hostname: str = "localhost" if RunningInCOLAB else os.getenv('DB_HOSTNAME', "mongo")

# %%
from typing import Any

client: MongoClient[dict[str, Any]] = MongoClient(db_hostname,27017)
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %% [markdown]
# Las bases de datos se crean conforme se nombran. Se puede utilizar la notación punto o la de diccionario. Las colecciones también.

# %%
from pymongo.database import Database

db: Database[dict[str,Any]] = client.stackoverflow
# db: Database = client['stackoverflow'] # (equivalente)
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stackoverflow')

# %% [markdown]
# ## Importación de los ficheros CSV
#
# Por ahora creamos una colección diferente para cada uno. Después estudiaremos cómo poder optimizar el acceso usando agregación.

# %%
import csv
import sys
from datetime import datetime
from pymongo.collection import Collection
from typing import Any
from collections.abc import Callable, Iterable, Iterator
from tqdm.notebook import tqdm

def batched(iterable: Iterable, n) -> Iterable:
    from itertools import islice
    if n < 1:
        raise ValueError('n must be at least one')
    it: Iterator = iter(iterable)
    while batch := tuple(islice(it, n)):
        yield batch

def csv_to_mongo(file: str, coll: Collection):
    """
    Carga un fichero CSV en Mongo. file especifica el fichero, coll la colección
    dentro de la base de datos, y date_cols las columnas que serán interpretadas
    como fechas.
    """
    # Convertir todos los elementos que se puedan a números
    def to_numeric(d: str) -> str| int | float:
        if len(d) == 0:
            return ''
        if not ((d[0] >= '0' and d[0] <= '9') or d[0] == '-' or d[0] == '+' or d[0]=='.'):
            return d
        try:
            return int(d) if abs(int(d)) <= sys.maxsize else d # Ensure number is inside MongoDB max number range
        except ValueError:
            try:
                return float(d)
            except ValueError:
                return d

    def to_date(d: str) -> datetime | None:
        """To ISO Date. If this cannot be converted, return NULL (None)"""
        try:
            return datetime.strptime(d, "%Y-%m-%dT%H:%M:%S.%f")
        except ValueError:
            return None

    coll.drop()

    with open(file, encoding='utf-8') as f:
        # La llamada csv.reader() crea un iterador sobre un fichero CSV
        reader = csv.reader(f, dialect='excel')

        # Se leen las columnas. Sus nombres se usarán para crear las diferentes columnas en la familia
        columns: list[str] = next(reader)

        # Las columnas que contienen 'Date' se interpretan como fechas
        func_to_cols: list[Callable[[str], Any]] = list(map(lambda c: to_date if 'date' in c.lower() else to_numeric, columns))

        for batch in batched(tqdm(reader, desc='Leyendo e insertando filas...'), 10000):
            docs: list[dict[str, str | datetime | float | int | None]] = []
            for row in batch:
                built_row: list[str | datetime | float | int | None] = [func(e) for (func,e) in zip(func_to_cols, row)]
                docs.append(dict(zip(columns, built_row)))
            coll.insert_many(docs)

        print("¡Hecho!")

# %%
csv_to_mongo('Posts.csv',db.posts)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Users.csv',db.users)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Votes.csv',db.votes)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Comments.csv',db.comments)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
csv_to_mongo('Tags.csv',db.tags)
# Out:
# Leyendo e insertando filas...: 0it [00:00, ?it/s]
# ¡Hecho!

# %%
posts: Collection[dict[str,Any]] = db.posts
posts
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stackoverflow'), 'posts')

# %%
posts.count_documents({})
# Out:
# 410346

# %% [markdown]
# ### El API de colección de MongoDB
#
# El API de colección en Python se puede encontrar aquí: https://docs.mongodb.com/drivers/pymongo/. La mayoría de libros y referencias muestran el uso de mongo desde Javascript, ya que el *shell* de MongoDB acepta ese lenguaje. La sintaxis con respecto a Python cambia un poco, y se puede seguir en el enlace anterior. Existe incluso un curso de la MongoDB University que se puede realizar de forma gratuita: https://learn.mongodb.com/learning-paths/using-mongodb-with-python

# %% [markdown]
# ## Framework de Agregación
#
# Framework de agregación:
# - Aquí está la referencia de las diferentes etapas por las que puede pasar un pipeline: https://www.mongodb.com/docs/manual/reference/operator/aggregation-pipeline/.
# - Y aquí los distintos operadores que se permiten dentro de las etapas: https://docs.mongodb.com/manual/reference/operator/aggregation/.
# - Y aquí incluso un libro completo con usos prácticos de ejecutar agregación: https://www.practical-mongodb-aggregations.com/.
#
# A continuación otro vídeo interseante:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('VSX4a3h4SmQ',width=600)

# %% [markdown]
# ![](https://miro.medium.com/max/1060/1*2lDBxvZ8Cr3JYkoODTa0lQ.png)

# %% [markdown]
# Proyección: el operador `$project` permite filtar qué campos de los documentos queremos usar en la siguientes fases de agregación.

# %%
from pymongo.command_cursor import CommandCursor

respuestas: CommandCursor[dict[str,Any]] = db['posts'].aggregate( [
    {'$project' : { 'Id' : True }},
    {'$limit': 20} ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9773d3e772cc77527f664'), 'Id': 1},
#  {'_id': ObjectId('67c9773d3e772cc77527f665'), 'Id': 2},
#  {'_id': ObjectId('67c9773d3e772cc77527f666'), 'Id': 3},
#  {'_id': ObjectId('67c9773d3e772cc77527f667'), 'Id': 4},
#  {'_id': ObjectId('67c9773d3e772cc77527f668'), 'Id': 5},
#  {'_id': ObjectId('67c9773d3e772cc77527f669'), 'Id': 6},
#  {'_id': ObjectId('67c9773d3e772cc77527f66a'), 'Id': 7},
#  {'_id': ObjectId('67c9773d3e772cc77527f66b'), 'Id': 8},
#  {'_id': ObjectId('67c9773d3e772cc77527f66c'), 'Id': 9},
#  {'_id': ObjectId('67c9773d3e772cc77527f66d'), 'Id': 10},
#  {'_id': ObjectId('67c9773d3e772cc77527f66e'), 'Id': 11},
#  {'_id': ObjectId('67c9773d3e772cc77527f66f'), 'Id': 12},
#  {'_id': ObjectId('67c9773d3e772cc77527f670'), 'Id': 14},
#  {'_id': ObjectId('67c9773d3e772cc77527f671'), 'Id': 15},
#  {'_id': ObjectId('67c9773d3e772cc77527f672'), 'Id': 16},
#  {'_id': ObjectId('67c9773d3e772cc77527f673'), 'Id': 17},
#  {'_id': ObjectId('67c9773d3e772cc77527f674'), 'Id': 18},
#  {'_id': ObjectId('67c9773d3e772cc77527f675'), 'Id': 19},
#  {'_id': ObjectId('67c9773d3e772cc77527f676'), 'Id': 20},
#  {'_id': ObjectId('67c9773d3e772cc77527f677'), 'Id': 21}]

# %% [markdown]
# _Lookup_! El operador `$lookup` permite realizar búsquedas en otras colecciones. Podrían interpretarse como un `join` en el modelo relacional.

# %%
respuestas: CommandCursor[dict[str,Any]] = posts.aggregate( [
        {'$match': { 'Score' : {'$gte': 150}}},
        {'$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"}
        }
        ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9773d3e772cc77527f688'),
#   'Id': 40,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>Asumiendo que se está haciendo un <code>join</code> de columnas sin duplicados, lo cuál es un caso común:</p><br/><ul><br/><li><p>Un <strong>inner join</strong> de A y B entregará el resultado de la intersección de los conjuntos A y B. En otras palabras, la parte <em>interna</em> –intersección– en un diagrama de Venn.</p><br/></li><br/><li><p>Un <strong>full outer join</strong> entre A y B entregará el resultado de la unión de A y B. En otras palabras, la parte <em>externa</em> –unión– en un diagrama de Venn .</p><br/></li><br/></ul><br/><h1>Ejemplos:</h1><br/><p>Supongamos que tenemos dos tablas, con una sola columna cada una y los siguientes datos:</p><br/><pre><code>A    B<br/>-    -<br/>1    3<br/>2    4<br/>3    5<br/>4    6<br/></code></pre><br/><p>Nota que (1,2) solo se encuentran en A, (3,4) son comunes y (5,6) solamente se encuentran en B.</p><br/><h1>Inner Join</h1><br/><p>Un inner join –utilizando cualquiera de las sintaxis de consulta equivalente– te entrega la intersección de ambas tablas, es decir, las filas que ambas tablas tienen en común.</p><br/><pre><code>select * from a INNER JOIN b on a.a = b.b;<br/>select a.*, b.*  from a, b where a.a = b.b;<br/><br/>a | b<br/>--+--<br/>3 | 3<br/>4 | 4<br/></code></pre><br/><h1>Left outer join</h1><br/><p>Un <code>outer join</code> por la izquierda, te dará todas las filas de A, incluyendo las filas comunes entre A y B.</p><br/><pre><code>select * from a LEFT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a = b.b(+);<br/><br/>a |  b<br/>--+-----<br/>1 | null<br/>2 | null<br/>3 |    3<br/>4 |    4<br/></code></pre><br/><h1>Right outer join</h1><br/><p>Un <code>outer join</code> por la derecha te dará todas las filas de B, incluyendo las filas comunes con A.</p><br/><pre><code>select * from a RIGHT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a(+) = b.b;<br/><br/>a    |  b<br/>-----+----<br/>3    |  3<br/>4    |  4<br/>null |  5<br/>null |  6<br/></code></pre><br/><h1>Full outer join</h1><br/><p>Un <code>outer join</code> completo (full) te entregará la unión de A y B; es decir, todas las filas de A y todas las filas de B. Si una fila en A no tiene una fila correspondiente en B, la porción de B es null, y vice versa.</p><br/><pre><code>select * from a FULL OUTER JOIN b on a.a = b.b;<br/><br/> a   |  b<br/>-----+-----<br/>   1 | null<br/>   2 | null<br/>   3 |    3<br/>   4 |    4<br/>null |    5<br/>null |    6<br/></code></pre><br/><h1>Diagramas de Venn</h1><br/><p>Esto mismo, podemos verlo con diagramas de Venn:</p><br/><p><img src="https://upload.wikimedia.org/wikipedia/commons/e/eb/SQL_Joins_es.svg" alt="Explicación visual de joins" /><br/>Imagen <a href="https://commons.wikimedia.org/wiki/File:SQL_Joins_es.svg" rel="nofollow noreferrer">SQL_Joins_es.svg</a> de <a href="https://es.stackoverflow.com/users/21/jachguate">jachguate</a>/<a href="https://commons.wikimedia.org/wiki/User:Arbeck" rel="nofollow noreferrer">Arbeck</a>, compartida bajo licencia <a href="https://creativecommons.org/licenses/by/3.0/deed.en" rel="nofollow noreferrer">CC BY 3.0</a>.</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2015, 11, 2, 17, 8, 19, 893000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 21,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 21,
#   'ParentId': 36,
#   'PostTypeId': 2,
#   'Score': 206,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9777d3e772cc7752e3963'),
#     'Id': 21,
#     'AboutMe': '<p>Entrepreneur, software developer and <strong>traveler</strong>. :)</p><br/>',
#     'AccountId': 93263,
#     'CreationDate': datetime.datetime(2015, 10, 29, 13, 46, 46, 317000),
#     'DisplayName': 'jachguate',
#     'DownVotes': 281,
#     'LastAccessDate': datetime.datetime(2023, 11, 28, 16, 55, 27, 633000),
#     'Location': 'Guatemala',
#     'Reputation': 30128,
#     'UpVotes': 2727,
#     'Views': 2892,
#     'WebsiteUrl': 'http://jachguate.wordpress.com'}]},
#  {'_id': ObjectId('67c9773d3e772cc77527f708'),
#   'Id': 197,
#   'AcceptedAnswerId': '',
#   'AnswerCount': 13,
#   'Body': '<p>Unas veces los cálculos funcionan correctamente, pero otras veces no:</p><br/><br/><pre><code>> 0.1 + 0.1<br/>0.2 // correcto<br/>> 0.1 + 0.2<br/>0.30000000000000004 // ¿qué?<br/>> 10 * 0.67<br/>6.7 // correcto<br/>> 10 * 0.68<br/>6.800000000000001 // demasiado grande<br/>> 10 * 0.69<br/>6.8999999999999995 // demasiado pequeño<br/></code></pre><br/><br/><p>(Estos ejemplos están escritos en JavaScript, pero el mismo problema existe en muchos lenguajes de programación)</p><br/><br/><p>Estos cálculos son bastante fáciles: creo que todos podemos hacerlos en un momento. ¿Por qué mis programas no pueden hacer cálculos aritméticos correctamente, y qué puedo hacer si necesito resultados más precisos?</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 10,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 6, 15, 7, 957000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 2, 6, 22, 11, 20, 880000),
#   'LastEditDate': datetime.datetime(2015, 12, 5, 20, 22, 47, 177000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 20,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 416,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 176,
#   'Tags': '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#   'Title': '¿Por qué mis programas no pueden hacer cálculos aritméticos correctamente?',
#   'ViewCount': 9091,
#   'owner': [{'_id': ObjectId('67c9777d3e772cc7752e3acd'),
#     'Id': 416,
#     'AboutMe': '<p><strong>Projects</strong></p><br/><br/><ul><br/><li><a href="https://www.dong-chinese.com/" rel="nofollow noreferrer">Dong Chinese</a></li><br/><li><a href="https://github.com/peterolson/BigInteger.js" rel="nofollow noreferrer">BigInteger.js</a></li><br/><li><a href="http://www.virtualtrebuchet.com/" rel="nofollow noreferrer">Virtual Trebuchet</a></li><br/><li><a href="https://play.google.com/store/apps/details?id=com.peterolson.magnetpuzzle" rel="nofollow noreferrer">The Magnet Puzzle</a></li><br/></ul><br/><br/><h2><img src="https://projecteuler.net/profile/peter.olson.png" alt="enter image description here"></h2><br/><br/><p>You can contact me at </p><br/><br/><pre><code>peter.e.c.olson+stackexchange@gmail.com<br/></code></pre><br/>',
#     'AccountId': 262054,
#     'CreationDate': datetime.datetime(2015, 12, 2, 0, 35, 33, 333000),
#     'DisplayName': 'Peter Olson',
#     'DownVotes': 0,
#     'LastAccessDate': datetime.datetime(2022, 12, 5, 14, 52, 5, 970000),
#     'Location': 'Qingdao, China',
#     'Reputation': 4795,
#     'UpVotes': 7,
#     'Views': 178,
#     'WebsiteUrl': 'https://www.dong-chinese.com'}]},
#  {'_id': ObjectId('67c9773d3e772cc77527f70c'),
#   'Id': 204,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>El problema viene de la limitación que los ordenadores tienen para representar números de <a href="https://es.wikipedia.org/wiki/Coma_flotante">coma flotante</a> usando un número finito de bits.</p><br/><br/><p><a href="http://www.exploringbinary.com/why-0-point-1-does-not-exist-in-floating-point">En este artículo en inglés</a> hay una muy buena explicación. Básicamente, para representar el número 0.1 en coma flotante necesitamos un número infinito de dígitos binarios:</p><br/><br/><p><a href="https://i.stack.imgur.com/e5fNJ.png"><img src="https://i.stack.imgur.com/e5fNJ.png" alt="Dividiendo 1 entre 10 en binario"></a></p><br/><br/><p><em>Dividiendo 1 entre 10 en binario</em></p><br/><br/><p><a href="https://i.stack.imgur.com/rvPPD.png"><img src="https://i.stack.imgur.com/rvPPD.png" alt="1/10 en binario (primeros 1369 dígitos)"></a></p><br/><br/><p><em>1/10 en binario (primeros 1369 dígitos)</em></p><br/><br/><p>Si suponemos que nuestro ordenador es capaz de almacenar hasta 53 dígitos, una vez truncado nuestro 0.1 queda representado en binario como:</p><br/><br/><p>0.0001100110011001100110011001100110011001100110011001101</p><br/><br/><p>...que en decimal es</p><br/><br/><p>0.1000000000000000055511151231257827021181583404541015625</p><br/><br/><p>Para este problema hay básicamente dos soluciones:</p><br/><br/><ul><br/><li>Usar un tipo decimal exacto en vez de coma flotante. Hay lenguajes que proporcionan estos tipos nativamente (por ejemplo, .NET tiene el tipo <a href="https://msdn.microsoft.com/en-us/library/364x0z75.aspx">decimal</a>); para los que no, suele haber librerías especializadas para ello (por ejemplo <a href="https://github.com/MikeMcl/decimal.js">decimal.js</a> para Javascript).</li><br/><li>Si el número de decimales se conoce por adelantado (por ejemplo al tratar con valores monetarios), los valores se pueden representar como enteros. Así, 123.45€ se representaría como 12345 céntimos. El punto decimal se añadiría al final, a la hora de mostrar el valor al usuario.</li><br/></ul><br/><br/><p>Un buen sitio con más información sobre este tema: <a href="http://puntoflotante.org">http://puntoflotante.org</a></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 3,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 7, 43, 50, 70000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 23,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 23,
#   'ParentId': 197,
#   'PostTypeId': 2,
#   'Score': 195,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9777d3e772cc7752e3965'),
#     'Id': 23,
#     'AboutMe': '<p>Empecemos por lo importante: me encantan los <a href="http://en.wikipedia.org/wiki/MSX" rel="nofollow noreferrer">ordenadores MSX</a> y el <a href="https://en.wikipedia.org/wiki/Renault_Twingo#Twingo_I_.281993.E2.80.932007.29" rel="nofollow noreferrer">Renault Twingo clásico</a> (sólo el modelo 1993-2007; los modelos más nuevos son tan aburridos como cualquier otro coche).<br/></p><br/><p>Y ahora la parte aburrida. Soy ingeniero de telecomunicaciones pero trabajo como programador, principalmente en C#. He hecho mucho desarrollo en Windows Forms en el pasado, también WPF y Silverlight, pero ahora estoy más metido en el desarrollo web (al principio sólo backend, pero ahora estoy en el mundo del frontend también).<br/></p><br/><p><del>Cuando tengo tiempo libre me gusta</del> Cuando <em>tenía</em> tiempo libre me gustaba programar mi MSX Turbo-R en ensamblador de Z80. De hecho he desarrollado incluso <a href="http://konamiman.com/msx/msx-s.html#inl" rel="nofollow noreferrer">una pila TCP/IP completa para MSX</a> (<a href="https://bitbucket.org/konamiman/msx/src/cf8fc0cc652e1ff79b1a2fc657b2f10d4e0c72fb/SRC/INL/?at=default" rel="nofollow noreferrer">las fuentes están disponibles</a>, ¡échales un ojo!), que presenté como mi proyecto de final de carrera en la universidad, con muy buenos resultados.</p><br/><p>Puedes ver mis proyectos de software aquí:<br/><br/><a href="http://www.konamiman.com" rel="nofollow noreferrer">http://www.konamiman.com</a><br/><br/><a href="http://github.com/konamiman" rel="nofollow noreferrer">http://github.com/konamiman</a></p><br/><p>Y si quieres puedes escribirme: konamiman@konamiman.com</p><br/>',
#     'AccountId': 3201,
#     'CreationDate': datetime.datetime(2015, 10, 29, 14, 53, 36, 233000),
#     'DisplayName': 'Konamiman',
#     'DownVotes': 4,
#     'LastAccessDate': datetime.datetime(2023, 11, 13, 20, 49, 46, 673000),
#     'Location': 'Palma de Mallorca, Spain',
#     'Reputation': 5278,
#     'UpVotes': 367,
#     'Views': 787,
#     'WebsiteUrl': 'http://www.konamiman.com'}]},
#  {'_id': ObjectId('67c977423e772cc775282ed6'),
#   'Id': 18232,
#   'AcceptedAnswerId': 18233,
#   'AnswerCount': 6,
#   'Body': '<p>Las sentencias dinámicas son sentencias SQL que se crean como cadenas de texto (strings) y en las que se insertan/concatenan valores obtenidos de alguna fuente (normalmente proveniente del usuario), lo que puede hacer que sean vulnerables a inyección SQL si no se sanean las entradas, como por ejemplo:</p><br/><br/><pre><code>$id_usuario = $_POST["id"];<br/><br/>mysql_query("SELECT * FROM usuarios WHERE id = $id_usuario");<br/></code></pre><br/><br/><p>Eso es un ejemplo de una vulnerabilidad grave en la seguridad de una aplicación (web o no) porque si el usuario introdujese un valor como <code>1; DROP TABLE usuarios;--</code> nos encontraríamos con que la sentencia ejecutada sería:</p><br/><br/><pre><code>SELECT * FROM usuarios WHERE id = 1; DROP TABLE usuarios;--<br/></code></pre><br/><br/><p>Y se eliminaría la tabla Usuarios con todos los datos contenidos en ella. </p><br/><br/><p><strong>¿Cómo puedo evitar que la inyección SQL ocurra en PHP?</strong></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 1,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2023, 5, 16, 22, 14, 53, 633000),
#   'LastEditDate': datetime.datetime(2017, 3, 4, 3, 8, 9, 33000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 29967,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 232,
#   'Tags': '<php><mysql><sql><seguridad><inyección-sql>',
#   'Title': '¿Cómo evitar la inyección SQL en PHP?',
#   'ViewCount': 77113,
#   'owner': [{'_id': ObjectId('67c9777d3e772cc7752e3a36'),
#     'Id': 250,
#     'AboutMe': '<p>Ingeniero Software con experiencia en diferentes lenguajes y tecnologías. Moderador electo de Stack Overflow en español desde 2017.</p><br/><br/><p>En mi tiempo libre me gusta jugar con tecnologías web y, en particular, hacer pequeñas cosas en HTML y CSS (sin JavaScript). Como por ejemplo esta <a href="https://codepen.io/alvaromontoro/full/WZZNPR" rel="nofollow noreferrer">pila Duracell</a>, un <a href="https://codepen.io/alvaromontoro/full/jGLOBy" rel="nofollow noreferrer">juego de preguntas</a>, un <a href="https://codepen.io/alvaromontoro/full/Nwgarb/" rel="nofollow noreferrer">reloj textual</a>, o un <a href="https://codepen.io/alvaromontoro/full/OwwQMm/" rel="nofollow noreferrer">juego de mesa completo: Serpientes y Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a mi <a href="https://www.linkedin.com/in/alvaromontoro/" rel="nofollow noreferrer">perfil profesional de LinkedIn</a>. Si me añades como conexión, añade una nota con tu nombre en Stack Overflow para saber quién eres.</p><br/>',
#     'AccountId': 4550651,
#     'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#     'DisplayName': 'Alvaro Montoro',
#     'DownVotes': 1312,
#     'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#     'Location': 'Austin, TX',
#     'Reputation': 49245,
#     'UpVotes': 3420,
#     'Views': 7610,
#     'WebsiteUrl': 'http://www.alvaromontoro.com'}]},
#  {'_id': ObjectId('67c977423e772cc775282ed7'),
#   'Id': 18233,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<blockquote><br/><h1>NO USES SENTENCIAS DINÁMICAS NI FUNCIONES <code>mysql_*</code></h1><br/><p>Las funciones <code>mysql_*</code> (<code>mysql_connect</code>, <code>mysql_query</code>, etc.) son inseguras por naturaleza y su uso no sólo no está recomendado, sino que <strong>se consideran obsoletas y se han eliminado completamente a partir de PHP7</strong>.</p><br/><p>Incluso los métodos nativos que existen en PHP para sanear las entradas de usuario (como <code>mysql_real_escape_string</code>) pueden presentar (raros) problemas y fallar en algunos casos como cuando se usan codificación de caracteres diferentes a UTF-8 junto a versiones no actualizadas de MySQL (en las <a href="http://php.net/manual/es/mysqli.real-escape-string.php" rel="noreferrer">páginas de PHP para estas funciones</a> se avisa de este riesgo).</p><br/></blockquote><br/><hr /><br/><h1>Usa sentencias preparadas y consultas parametrizadas</h1><br/><p>Aunque se podrían sanear las entradas usando métodos como <code>mysqli_real_escape_string</code>, es más recomendable la utilización de sentencias preparadas o parametrizadas. Las sentencias preparadas te permitirán ejecutar la misma sentencia con gran eficiencia.</p><br/><p>En PHP, tienes dos alternativas principales: <a href="https://www.php.net/manual/es/book.pdo.php" rel="noreferrer">PDO</a> y  <a href="https://www.php.net/manual/es/book.mysqli.php" rel="noreferrer">MySQLi</a>. Hay varias diferencias entre ambas, pero la principal es que PDO se puede usar con diferentes tipos de base de datos (<a href="https://www.php.net/manual/es/intro.pdo.php#intro.pdo" rel="noreferrer">dependiendo del driver utilizado</a>) mientras que MySQLi es exclusivamente para bases de datos MySQL. Es por ello que recomendaría PDO sobre MySQLi.</p><br/><h2>PDO</h2><br/><p>Los <a href="https://www.php.net/manual/es/pdo.prepare.php#refsect1-pdo.prepare-description" rel="noreferrer">marcadores de posición</a> (que indican dónde se sustituirá una cadena por su valor), se pueden definir bien usando un signo de interrogación (<code>?</code>) o bien usando un nombre (generalmente empezando con <code>:</code>). Personalmente prefiero usar un nombre, porque eso me ayuda a encontrar posibles errores en caso de tener múltiples variables.</p><br/><p>Aquí dejo un ejemplo para el código de la pregunta:</p><br/><pre><code>// la variable $pdo contendrá el objeto con la conexión PDO<br/>$pdo = new PDO(\'mysql:host=mihost;dbname=basedatos\', "usuario", "contraseña");<br/><br/>$id_usuario = $_POST["id"];<br/><br/>$sentencia = $pdo->prepare("SELECT * FROM usuarios WHERE id = :idusuario");<br/>$sentencia=$pdo->setAttribute(PDO::ATTR_EMULATE_PREPARES, false);<br/>$sentencia->bindParam(":idusuario", $id_usuario, PDO::PARAM_INT);<br/>$sentencia->execute();<br/></code></pre><br/><p>En este caso, <code>:idusuario</code> se sustituirá por el valor de <code>$_POST["id"]</code> de forma segura, y cuando hace el <em>bind</em> se indica que la variable es de tipo entero (<code>PDO::PARAM_INT</code>).</p><br/><blockquote><br/><p>Nota: si la variable es una cadena de texto se usará <code>PDO::PARAM_STR</code> y no hace falta poner las comillas en la sentencia SQL; al especificarle a PHP que es una cadena, las añadirá automáticamente al hacer el <em>bind</em>.</p><br/></blockquote><br/><p>En caso de que existan varias variables a incluir en la sentencia SQL, se debe incluir un único parámetro para cada uno de los valores que se usan en la sentencia. Del ejemplo anterior, el <code>:idusuario</code> puede usarse una única vez en la consulta que se esta preparando. Si fuera necesario usar el "idusuario" de nuevo en la consulta, se debe crear otro parámetro con el valor de <code>$id_usuario</code>.</p><br/><pre><code>$pdo = new PDO(\'mysql:host=mihost;dbname=basedatos\', "usuario", "contraseña");<br/><br/>$id_usuario = $_POST["id"];<br/>    <br/>$sentencia = $pdo->prepare("UPDATE usuarios SET id = :idusuario WHERE id = :idusuario1");<br/>$sentencia=$pdo->setAtt ...
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 195444,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': 18232,
#   'PostTypeId': 2,
#   'Score': 219,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9777d3e772cc7752e3a36'),
#     'Id': 250,
#     'AboutMe': '<p>Ingeniero Software con experiencia en diferentes lenguajes y tecnologías. Moderador electo de Stack Overflow en español desde 2017.</p><br/><br/><p>En mi tiempo libre me gusta jugar con tecnologías web y, en particular, hacer pequeñas cosas en HTML y CSS (sin JavaScript). Como por ejemplo esta <a href="https://codepen.io/alvaromontoro/full/WZZNPR" rel="nofollow noreferrer">pila Duracell</a>, un <a href="https://codepen.io/alvaromontoro/full/jGLOBy" rel="nofollow noreferrer">juego de preguntas</a>, un <a href="https://codepen.io/alvaromontoro/full/Nwgarb/" rel="nofollow noreferrer">reloj textual</a>, o un <a href="https://codepen.io/alvaromontoro/full/OwwQMm/" rel="nofollow noreferrer">juego de mesa completo: Serpientes y Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a mi <a href="https://www.linkedin.com/in/alvaromontoro/" rel="nofollow noreferrer">perfil profesional de LinkedIn</a>. Si me añades como conexión, añade una nota con tu nombre en Stack Overflow para saber quién eres.</p><br/>',
#     'AccountId': 4550651,
#     'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#     'DisplayName': 'Alvaro Montoro',
#     'DownVotes': 1312,
#     'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#     'Location': 'Austin, TX',
#     'Reputation': 49245,
#     'UpVotes': 3420,
#     'Views': 7610,
#     'WebsiteUrl': 'http://www.alvaromontoro.com'}]},
#  {'_id': ObjectId('67c9774c3e772cc77528f78d'),
#   'Id': 87842,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>Hola, mi nombre es Álvaro Montoro, soy un Ingeniero Informático español aunque actualmente vivo y trabajo en los Estados Unidos, en la capital del estado de Texas: Austin.</p><br/><br/><p>Tengo experiencia en diferentes ámbitos de programación: back-end, front-end, bases de datos, seguridad... y en bastantes lenguajes: PHP, Java, C#, Visual Basic, C/C++, JavaScript... lo que hace que me mueva por un grupo variado de etiquetas (aunque prefiera las de programación web) y se refleja en la medalla <a href="https://es.stackoverflow.com/help/badges/15/generalist"><code>generalista</code></a> (de momento el único que la tiene).</p><br/><br/><p>Pros:</p><br/><br/><ul><br/><li>Paso bastante tiempo en SOes (he visitado el sitio 594 días, 384 consecutivos ).</li><br/><li>He estado en el sitio desde Area 51 y cuento con experiencia en otros sitios de SE (no como moderador).</li><br/><li>Me gusta guiarme por las reglas del Centro de Ayuda.</li><br/></ul><br/><br/><p>Contras:</p><br/><br/><ul><br/><li>Aunque activo en chat y meta, debería ser más activo.</li><br/><li>Cuento con experiencia en otros sitios de SE, lo que hace que a veces use la misma vara de medir que usaría en otros sitios.</li><br/><li>Me gusta guiarme por las reglas del Centro de Ayuda... y a veces hay que ser más paciente y flexible.</li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 12,
#   'CommunityOwnedDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 250,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 250,
#   'ParentId': '',
#   'PostTypeId': 6,
#   'Score': 173,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': '',
#   'owner': [{'_id': ObjectId('67c9777d3e772cc7752e3a36'),
#     'Id': 250,
#     'AboutMe': '<p>Ingeniero Software con experiencia en diferentes lenguajes y tecnologías. Moderador electo de Stack Overflow en español desde 2017.</p><br/><br/><p>En mi tiempo libre me gusta jugar con tecnologías web y, en particular, hacer pequeñas cosas en HTML y CSS (sin JavaScript). Como por ejemplo esta <a href="https://codepen.io/alvaromontoro/full/WZZNPR" rel="nofollow noreferrer">pila Duracell</a>, un <a href="https://codepen.io/alvaromontoro/full/jGLOBy" rel="nofollow noreferrer">juego de preguntas</a>, un <a href="https://codepen.io/alvaromontoro/full/Nwgarb/" rel="nofollow noreferrer">reloj textual</a>, o un <a href="https://codepen.io/alvaromontoro/full/OwwQMm/" rel="nofollow noreferrer">juego de mesa completo: Serpientes y Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a mi <a href="https://www.linkedin.com/in/alvaromontoro/" rel="nofollow noreferrer">perfil profesional de LinkedIn</a>. Si me añades como conexión, añade una nota con tu nombre en Stack Overflow para saber quién eres.</p><br/>',
#     'AccountId': 4550651,
#     'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#     'DisplayName': 'Alvaro Montoro',
#     'DownVotes': 1312,
#     'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#     'Location': 'Austin, TX',
#     'Reputation': 49245,
#     'UpVotes': 3420,
#     'Views': 7610,
#     'WebsiteUrl': 'http://www.alvaromontoro.com'}]}]

# %% [markdown]
# El `$lookup` genera un _array_ con todos los resultados. El operador `$arrayElementAt` accede al primer elemento.

# %%
respuestas: CommandCursor[dict[str,Any]] = db.posts.aggregate( [
        {'$match': { 'Score' : {'$gte': 150}}},
        {'$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"}
        },
        { '$project' : {
            'Id' : True,
            'Score' : True,
            'username' : {'$arrayElemAt' : ['$owner.DisplayName', 0]},
            'owner.DisplayName' : True
          }}
        ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9773d3e772cc77527f688'),
#   'Id': 40,
#   'Score': 206,
#   'owner': [{'DisplayName': 'jachguate'}],
#   'username': 'jachguate'},
#  {'_id': ObjectId('67c9773d3e772cc77527f708'),
#   'Id': 197,
#   'Score': 176,
#   'owner': [{'DisplayName': 'Peter Olson'}],
#   'username': 'Peter Olson'},
#  {'_id': ObjectId('67c9773d3e772cc77527f70c'),
#   'Id': 204,
#   'Score': 195,
#   'owner': [{'DisplayName': 'Konamiman'}],
#   'username': 'Konamiman'},
#  {'_id': ObjectId('67c977423e772cc775282ed6'),
#   'Id': 18232,
#   'Score': 232,
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c977423e772cc775282ed7'),
#   'Id': 18233,
#   'Score': 219,
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9774c3e772cc77528f78d'),
#   'Id': 87842,
#   'Score': 173,
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'}]

# %% [markdown]
# `$unwind` también puede usarse. "Desdobla" cada fila por cada elemento del array. En este caso, como sabemos que el array sólo contiene un elemento, sólo habrá una fila por fila original, pero sin el _array_. Finalmente se puede proyectar el campo que se quiera. Volvemos a proyectar los campos anteriores para comprobar las diferencias.

# %%
respuestas: CommandCursor[dict[str,Any]] = db.posts.aggregate( [
        { '$match': { 'Score' : {'$gte': 150}}},
        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },
        { '$unwind': '$owner'},  # desdobla los contenidos haciendo que desparezcan los corchetes
        { '$project' : {
            'Id' : True,
            'Score' : True,
            'username': '$owner.DisplayName',
            'owner.DisplayName' : True
          }
        }
        ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9773d3e772cc77527f688'),
#   'Id': 40,
#   'Score': 206,
#   'owner': {'DisplayName': 'jachguate'},
#   'username': 'jachguate'},
#  {'_id': ObjectId('67c9773d3e772cc77527f708'),
#   'Id': 197,
#   'Score': 176,
#   'owner': {'DisplayName': 'Peter Olson'},
#   'username': 'Peter Olson'},
#  {'_id': ObjectId('67c9773d3e772cc77527f70c'),
#   'Id': 204,
#   'Score': 195,
#   'owner': {'DisplayName': 'Konamiman'},
#   'username': 'Konamiman'},
#  {'_id': ObjectId('67c977423e772cc775282ed6'),
#   'Id': 18232,
#   'Score': 232,
#   'owner': {'DisplayName': 'Alvaro Montoro'},
#   'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c977423e772cc775282ed7'),
#   'Id': 18233,
#   'Score': 219,
#   'owner': {'DisplayName': 'Alvaro Montoro'},
#   'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9774c3e772cc77528f78d'),
#   'Id': 87842,
#   'Score': 173,
#   'owner': {'DisplayName': 'Alvaro Montoro'},
#   'username': 'Alvaro Montoro'}]

# %% [markdown]
# Repetimos la consulta anterior, pero proyectando solamente el campo 'username'.

# %%
respuestas: CommandCursor[dict[str,Any]] = db.posts.aggregate( [
        { '$match': { 'Score' : {'$gte': 150}}},
        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },
        { '$unwind': '$owner'},
        { '$project' : {
            'username': '$owner.DisplayName',
          }
        }
        ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9773d3e772cc77527f688'), 'username': 'jachguate'},
#  {'_id': ObjectId('67c9773d3e772cc77527f708'), 'username': 'Peter Olson'},
#  {'_id': ObjectId('67c9773d3e772cc77527f70c'), 'username': 'Konamiman'},
#  {'_id': ObjectId('67c977423e772cc775282ed6'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c977423e772cc775282ed7'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9774c3e772cc77528f78d'), 'username': 'Alvaro Montoro'}]

# %% [markdown]
# Veamos cómo se ha realizado la consulta anterior. Para ello usamos la opción `explain`. En el campo `strategy` que se ha usado `NestedLoopJoin`. Para cada documento en `posts`, busca ''manualmente'' en `users` los documentos que coincidan con `OwnerUserId`.

# %%
db.command('aggregate', 'posts', pipeline= [
  { '$match': { 'Score' : {'$gte': 150}}},
  { '$lookup': {
      'from': "users",
      'localField': "OwnerUserId",
      'foreignField': "Id",
      'as': "owner"
    }
  },
  { '$unwind': '$owner'},
  { '$project': {
      'username': '$owner.DisplayName',

     }
  }
  ],
  explain = True
)
# Out:
# {'explainVersion': '1',
#  'stages': [{'$cursor': {'queryPlanner': {'namespace': 'stackoverflow.posts',
#      'parsedQuery': {'Score': {'$gte': 150}},
#      'indexFilterSet': False,
#      'queryHash': 'FE018D7F',
#      'planCacheShapeHash': 'FE018D7F',
#      'planCacheKey': '632B2F53',
#      'optimizationTimeMillis': 0,
#      'maxIndexedOrSolutionsReached': False,
#      'maxIndexedAndSolutionsReached': False,
#      'maxScansToExplodeReached': False,
#      'prunedSimilarIndexes': False,
#      'winningPlan': {'isCached': False,
#       'stage': 'PROJECTION_SIMPLE',
#       'transformBy': {'OwnerUserId': 1, '_id': 1},
#       'inputStage': {'stage': 'COLLSCAN',
#        'filter': {'Score': {'$gte': 150}},
#        'direction': 'forward'}},
#      'rejectedPlans': []}}},
#   {'$lookup': {'from': 'users',
#     'as': 'owner',
#     'localField': 'OwnerUserId',
#     'foreignField': 'Id',
#     'unwinding': {'preserveNullAndEmptyArrays': False}}},
#   {'$project': {'_id': True, 'username': '$owner.DisplayName'}}],
#  'queryShapeHash': '7C43FDBCEC03CEB5157B5AB6FEF170D915FE4B8D2398CF4A8BB25555CA9B25E8',
#  'serverInfo': {'host': 'cb45e58c90c0',
#   'port': 27017,
#   'version': '8.0.5',
#   'gitVersion': 'cb9e2e5e552ee39dea1e39d7859336456d0c9820'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'command': {'aggregate': 'posts',
#   'pipeline': [{'$match': {'Score': {'$gte': 150}}},
#    {'$lookup': {'from': 'users',
#      'localField': 'OwnerUserId',
#      'foreignField': 'Id',
#      'as': 'owner'}},
#    {'$unwind': '$owner'},
#    {'$project': {'username': '$owner.DisplayName'}}],
#   'explain': True,
#   'lsid': {'id': Binary(b'\xf0\xa7\x0f\x15I\x14KB\xa7[\n\xac\x05z\xd7\x96', 4)},
#   '$db': 'stackoverflow'},
#  'ok': 1.0}

# %% [markdown]
# ## Definición de índices
#
# Las consultas anteriores no se han podido realizar, ya que el uso de `$lookup` (equivalente a un JOIN de SQL) hace que se tenga que buscar en toda la colección usuarios para encontrar el usuario con `Id` especificado por `OwnerUserId`. Vamos a probarlas sin limitación después de crear un índice.

# %%
from pymongo import HASHED

db.users.create_index(['Id', HASHED])
# Out:
# 'Id_1_hashed_1'

# %%
respuestas: CommandCursor[dict[str,Any]] = db.posts.aggregate( [
  { '$match': { 'Score' : {'$gte': 150}}},
  { '$lookup': {
      'from': "users",
      'localField': "OwnerUserId",
      'foreignField': "Id",
      'as': "owner"
    }
  },
  { '$unwind': '$owner'},
  { '$project' : {
        'username': '$owner.DisplayName'
    }
  }
  ])
list(respuestas)
# Out:
# [{'_id': ObjectId('67c9773d3e772cc77527f688'), 'username': 'jachguate'},
#  {'_id': ObjectId('67c9773d3e772cc77527f708'), 'username': 'Peter Olson'},
#  {'_id': ObjectId('67c9773d3e772cc77527f70c'), 'username': 'Konamiman'},
#  {'_id': ObjectId('67c977423e772cc775282ed6'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c977423e772cc775282ed7'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('67c9774c3e772cc77528f78d'), 'username': 'Alvaro Montoro'}]

# %% [markdown]
# Veamos cómo se ha usado el índice en la consulta (no se incluye la consulta entera porque el explain no lo termina de hacer bien si hay muchos pasos). De nuevo usamos la opción `explain`. En el campo `strategy` que se ha usado `IndexedLoopJoin`. En este caso se utiliza el índice creado en `users` para hacer la búsqueda de una forma más rápida y eficiente.

# %%
db.command('aggregate', 'posts', pipeline= [
  { '$match': { 'Score' : {'$gte': 150}}},
  { '$lookup': {
      'from': "users",
      'localField': "OwnerUserId",
      'foreignField': "Id",
      'as': "owner"
    }
  }],
  explain = True
)
# Out:
# {'explainVersion': '2',
#  'queryPlanner': {'namespace': 'stackoverflow.posts',
#   'parsedQuery': {'Score': {'$gte': 150}},
#   'indexFilterSet': False,
#   'queryHash': '0873BBE5',
#   'planCacheShapeHash': '0873BBE5',
#   'planCacheKey': 'D1416C01',
#   'optimizationTimeMillis': 0,
#   'optimizedPipeline': True,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'queryPlan': {'stage': 'EQ_LOOKUP',
#     'planNodeId': 2,
#     'foreignCollection': 'stackoverflow.users',
#     'localField': 'OwnerUserId',
#     'foreignField': 'Id',
#     'asField': 'owner',
#     'strategy': 'IndexedLoopJoin',
#     'indexName': 'Id_1_hashed_1',
#     'indexKeyPattern': {'Id': 1, 'hashed': 1},
#     'scanDirection': 'forward',
#     'inputStage': {'stage': 'COLLSCAN',
#      'planNodeId': 1,
#      'filter': {'Score': {'$gte': 150}},
#      'direction': 'forward'}},
#    'slotBasedPlan': {'slots': '$$RESULT=s30 env: { s4 = 150 }',
#     'stages': '[2] mkbson s30 s2 [] drop [owner = s29] true false \n[2] nlj inner [s2] [s10] \n    left \n        [2] nlj inner [s2] [s2] \n            left \n                [1] filter {traverseF(s1, lambda(l2.0) { ((move(l2.0) >= s4) ?: false) }, false)} \n                [1] scan s2 s3 none none none none none none lowPriority [s1 = Score] @"30662d20-7c37-4a6f-8468-b5c631d4d470" true false \n            right \n                [2] project [s10 = \n                    if isArrayEmpty(s8) \n                    then [null] \n                    else s8 \n               ] \n                [2] group [] [s8 = addToSet(s6)] spillSlots[s9] mergingExprs[aggSetUnion(s9)] \n                [2] unwind s6 s7 s5 true \n                [2] project [s5 = getField(s2, "OwnerUserId")] \n                [2] limit 1ll \n                [2] coscan \n    right \n        [2] limit 1ll \n        [2] union [s29] \n            branch0 [s27] \n                [2] project [s27 = getElement(s25, 0)] \n                [2] group [] [s25 = addToArrayCapped(s23, 104857600)] spillSlots[s26] mergingExprs[aggConcatArraysCapped(s26, 104857600)] \n                [2] filter {traverseF((getField(s23, "Id") ?: null), lambda(l3.0) { isMember(l3.0, s10) }, true)} \n                [2] nlj inner [] [s19, s21, s22, s20, s18] \n                    left \n                        [2] nlj inner [s18] [s16, s17] \n                            left \n                                [2] nlj inner [] [s11] \n                                    left \n                                        [2] unwind s11 s12 s10 true \n                                        [2] limit 1ll \n                                        [2] coscan \n                                    right \n                                        [2] project [s16 = ks(1ll, 0, s15, 1ll), s17 = ks(1ll, 0, s15, 2ll), s18 = {"Id" : 1, "hashed" : 1}] \n                                        [2] union [s15] \n                                            branch0 [s13] \n                                                [2] filter {(isArray(s11) && !(isMember(s13, s10)))} \n                                                [2] project [s13 = (getElement(s11, 0) ?: undefined)] \n                                                [2] limit 1ll \n                                                [2] coscan \n                                            branch1 [s14] \n                                                [2] project [s14 = s11] \n                                                [2] limit 1ll \n                                                [2] coscan \n                            right \n                                [2] ixseek s16 s17 s20 s19 s21 s22 [] @"8ae263bb-7f82-4d94-b98e-3fc9915fb551" @"Id_1_hashed_1" true \n                    right \n                        [2] limit 1ll \n                        [2] seek s19 s23 s24 s21 s22 s20 s18 none none [] @"8ae263bb-7f82-4d94-b98e-3fc9915fb551" true false \n            branch1 [s28] \n                [2] project [s28 = []] \n                [2] limit 1ll \n                [2] coscan \n'}},
#   'rejectedPlans': []},
#  'queryShapeHash': 'D343DDF36A4FD6DA0C046D7363B2AE2F9B1150F439AB4EA1C519B8F34F48B1AF',
#  'command': {'aggregate': 'posts',
#   'pipeline': [{'$match': {'Score': {'$gte': 150}}},
#    {'$lookup': {'from': 'users',
#      'localField': 'OwnerUserId',
#      'foreignField': 'Id',
#      'as': 'owner'}}],
#   'explain': True,
#   'lsid': {'id': Binary(b'\xf0\xa7\x0f\x15I\x14KB\xa7[\n\xac\x05z\xd7\x96', 4)},
#   '$db': 'stackoverflow'},
#  'serverInfo': {'host': 'cb45e58c90c0',
#   'port': 27017,
#   'version': '8.0.5',
#   'gitVersion': 'cb9e2e5e552ee39dea1e39d7859336456d0c9820'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'ok': 1.0}

# %% [markdown]
# Calculemos la media de puntuación por usuario:

# %%
media_puntuación_usuarios: CommandCursor[dict[str,Any]] = db.posts.aggregate([
    {
        '$group': {
            '_id': '$OwnerUserId',
            'media_puntuación': { '$avg':  '$Score' }
            }
    },
    { '$limit': 100 }
    ])
list(media_puntuación_usuarios)
# Out:
# [{'_id': 3152, 'media_puntuación': -3.0},
#  {'_id': 205473, 'media_puntuación': 0.3333333333333333},
#  {'_id': 333899, 'media_puntuación': 0.0},
#  {'_id': 179081, 'media_puntuación': 0.0},
#  {'_id': 209417, 'media_puntuación': 0.23076923076923078},
#  {'_id': 195601, 'media_puntuación': 0.75},
#  {'_id': 321266, 'media_puntuación': 0.0},
#  {'_id': 173691, 'media_puntuación': 1.0},
#  {'_id': 91659, 'media_puntuación': 0.0},
#  {'_id': 193826, 'media_puntuación': 0.0},
#  {'_id': 248651, 'media_puntuación': 2.0},
#  {'_id': 275177, 'media_puntuación': 0.0},
#  {'_id': 272240, 'media_puntuación': 0.0},
#  {'_id': 27069, 'media_puntuación': 2.0},
#  {'_id': 49222, 'media_puntuación': 1.0},
#  {'_id': 133414, 'media_puntuación': 0.8571428571428571},
#  {'_id': 96714, 'media_puntuación': 1.0},
#  {'_id': 304112, 'media_puntuación': -0.3333333333333333},
#  {'_id': 64790, 'media_puntuación': 0.5714285714285714},
#  {'_id': 191347, 'media_puntuación': 1.0},
#  {'_id': 207347, 'media_puntuación': 0.0},
#  {'_id': 194197, 'media_puntuación': 0.5},
#  {'_id': 263294, 'media_puntuación': 2.0},
#  {'_id': 277278, 'media_puntuación': 4.0},
#  {'_id': 150998, 'media_puntuación': 1.3333333333333333},
#  {'_id': 285838, 'media_puntuación': -1.0},
#  {'_id': 86181, 'media_puntuación': 3.0},
#  {'_id': 237102, 'media_puntuación': 0.0},
#  {'_id': 3763, 'media_puntuación': 4.4},
#  {'_id': 115600, 'media_puntuación': 0.3333333333333333},
#  {'_id': 124051, 'media_puntuación': 1.0},
#  {'_id': 23619, 'media_puntuación': 1.5},
#  {'_id': 25838, 'media_puntuación': 0.7857142857142857},
#  {'_id': 266194, 'media_puntuación': 0.0},
#  {'_id': 326902, 'media_puntuación': 1.0},
#  {'_id': 97865, 'media_puntuación': 0.0},
#  {'_id': 222724, 'media_puntuación': 0.0},
#  {'_id': 48983, 'media_puntuación': 0.0},
#  {'_id': 10921, 'media_puntuación': 1.5},
#  {'_id': 49212, 'media_puntuación': -0.1},
#  {'_id': 202184, 'media_puntuación': 0.0},
#  {'_id': 304942, 'media_puntuación': 0.0},
#  {'_id': 291324, 'media_puntuación': 0.0},
#  {'_id': 94208, 'media_puntuación': 3.0},
#  {'_id': 296614, 'media_puntuación': 0.0},
#  {'_id': 24229, 'media_puntuación': 1.0},
#  {'_id': 200897, 'media_puntuación': 1.0},
#  {'_id': 201547, 'media_puntuación': 3.0},
#  {'_id': 302912, 'media_puntuación': 0.5},
#  {'_id': 202947, 'media_puntuación': 0.3333333333333333},
#  {'_id': 100510, 'media_puntuación': 1.0},
#  {'_id': 74645, 'media_puntuación': 0.25},
#  {'_id': 42736, 'media_puntuación': 1.0},
#  {'_id': 70855, 'media_puntuación': 0.3076923076923077},
#  {'_id': 311882, 'media_puntuación': 3.0},
#  {'_id': 195382, 'media_puntuación': 0.0},
#  {'_id': 74121, 'media_puntuación': 0.9696969696969697},
#  {'_id': 88103, 'media_puntuación': 2.0},
#  {'_id': 85325, 'media_puntuación': 0.36363636363636365},
#  {'_id': 2319, 'media_puntuación': 1.0},
#  {'_id': 117475, 'media_puntuación': 1.0},
#  {'_id': 245579, 'media_puntuación': 0.5},
#  {'_id': 124823, 'media_puntuación': 0.0},
#  {'_id': 87999, 'media_puntuación': 0.0},
#  {'_id': 4861, 'media_puntuación': 1.0},
#  {'_id': 87012, 'media_puntuación': 0.0},
#  {'_id': 287468, 'media_puntuación': 1.0},
#  {'_id': 317520, 'media_puntuación': 0.0},
#  {'_id': 16028, 'media_puntuación': 0.3333333333333333},
#  {'_id': 132753, 'media_puntuación': 0.0},
#  {'_id': 58579, 'media_puntuación': 0.2},
#  {'_id': 167478, 'media_puntuación': 1.0},
#  {'_id': 139769, 'media_puntuación': 0.0},
#  {'_id': 145469, 'media_puntuación': 0.6779661016949152},
#  {'_id': 333108, 'media_puntuación': -1.0},
#  {'_id': 82898, 'media_puntuación': 0.0},
#  {'_id': 8867, 'media_puntuación': 2.0},
#  {'_id': 26468, 'media_puntuación': 3.0},
#  {'_id': 86897, 'media_puntuación': 0.6666666666666666},
#  {'_id': 152737, 'media_puntuación': 3.0},
#  {'_id': 32006, 'media_puntuación': 1.0},
#  {'_id': 25253, 'media_puntuación': 3.0},
#  {'_id': 273907, 'media_puntuación': 0.0},
#  {'_id': 295632, 'media_puntuación': 0.16666666666666666},
#  {'_id': 108924, 'media_puntuación': 0.0},
#  {'_id': 258481, 'media_puntuación': 1.0},
#  {'_id': 301092, 'media_puntuación': 0.0},
#  {'_id': 18974, 'media_puntuación': -0.5},
#  {'_id': 16291, 'media_puntuación': 1.0},
#  {'_id': 33785, 'media_puntuación': 0.3333333333333333},
#  {'_id': 14888, 'media_puntuación': 2.0},
#  {'_id': 49135, 'media_puntuación': 2.0},
#  {'_id': 111677, 'media_puntuación': -1.0},
#  {'_id': 167034, 'media_puntuación': 0.0},
#  {'_id': 140161, 'media_puntuación': 0.0},
#  {'_id': 5408, 'media_puntuación': 1.0},
#  {'_id': 10398, 'media_puntuación': 1.353658536585366},
#  {'_id': 70794, 'media_puntuación': 0.0},
#  {'_id': 28948, 'media_puntuación': 0.55},
#  {'_id': 270090, 'media_puntuación': 0.0}]

# %% [markdown]
# Calculemos el máximo y mínimo de puntuación de cada usuario:

# %%
max_min_puntuación_usuarios: CommandCursor[dict[str,Any]] = db.posts.aggregate([
    {
        '$group': {
            '_id': '$OwnerUserId',
            'media_puntuación': { '$avg':  '$Score' },
            'min': { '$min':  '$Score' },
            'max': { '$max' : "$Score"}
        }
    },
    { '$limit': 100 }
    ])
list(max_min_puntuación_usuarios)
# Out:
# [{'_id': 3152, 'media_puntuación': -3.0, 'min': -3, 'max': -3},
#  {'_id': 205473, 'media_puntuación': 0.3333333333333333, 'min': 0, 'max': 1},
#  {'_id': 333899, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 179081, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 209417, 'media_puntuación': 0.23076923076923078, 'min': -1, 'max': 1},
#  {'_id': 195601, 'media_puntuación': 0.75, 'min': 0, 'max': 1},
#  {'_id': 321266, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 173691, 'media_puntuación': 1.0, 'min': 1, 'max': 1},
#  {'_id': 91659, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 193826, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 248651, 'media_puntuación': 2.0, 'min': 2, 'max': 2},
#  {'_id': 275177, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 272240, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 27069, 'media_puntuación': 2.0, 'min': 2, 'max': 2},
#  {'_id': 49222, 'media_puntuación': 1.0, 'min': 1, 'max': 1},
#  {'_id':
 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 8867, 'media_puntuación': 2.0, 'min': 2, 'max': 2},
#  {'_id': 26468, 'media_puntuación': 3.0, 'min': 3, 'max': 3},
#  {'_id': 86897, 'media_puntuación': 0.6666666666666666, 'min': 0, 'max': 1},
#  {'_id': 152737, 'media_puntuación': 3.0, 'min': 3, 'max': 3},
#  {'_id': 32006, 'media_puntuación': 1.0, 'min': 1, 'max': 1},
#  {'_id': 25253, 'media_puntuación': 3.0, 'min': 3, 'max': 3},
#  {'_id': 273907, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 295632, 'media_puntuación': 0.16666666666666666, 'min': 0, 'max': 1},
#  {'_id': 108924, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 258481, 'media_puntuación': 1.0, 'min': 1, 'max': 1},
#  {'_id': 301092, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 18974, 'media_puntuación': -0.5, 'min': -1, 'max': 0},
#  {'_id': 16291, 'media_puntuación': 1.0, 'min': 1, 'max': 1},
#  {'_id': 33785, 'media_puntuación': 0.3333333333333333, 'min': -1, 'max': 3},
#  {'_id': 14888, 'media_puntuación': 2.0, 'min': 2, 'max': 2},
#  {'_id': 49135, 'media_puntuación': 2.0, 'min': 2, 'max': 2},
#  {'_id': 111677, 'media_puntuación': -1.0, 'min': -2, 'max': 0},
#  {'_id': 167034, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 140161, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 5408, 'media_puntuación': 1.0, 'min': 1, 'max': 1},
#  {'_id': 10398, 'media_puntuación': 1.353658536585366, 'min': -4, 'max': 7},
#  {'_id': 70794, 'media_puntuación': 0.0, 'min': 0, 'max': 0},
#  {'_id': 28948, 'media_puntuación': 0.55, 'min': -2, 'max': 7},
#  {'_id': 270090, 'media_puntuación': 0.0, 'min': 0, 'max': 0}]

# %% [markdown]
# Pasemos ahora a trabajar con la colección Votes. Antes de empezar, veamos las primeras líneas del fichero `Votes.csv`:

# %%
# !head Votes.csv
# Out:
# Id,BountyAmount,CreationDate,PostId,UserId,VoteTypeId
# 1,,2015-10-29T00:00:00.000,1,,2
# 2,,2015-10-29T00:00:00.000,2,,2
# 3,,2015-10-30T00:00:00.000,3,,2
# 4,,2015-10-30T00:00:00.000,5,,2
# 5,,2015-10-30T00:00:00.000,7,,2
# 7,,2015-10-30T00:00:00.000,3,,16
# 8,,2015-10-30T00:00:00.000,4,,2
# 9,,2015-10-30T00:00:00.000,1,,2
# 10,,2015-10-30T00:00:00.000,1,,16

# %% [markdown]
# Podemos comprobar que todos los posts tienen los votos correctos contando los votos positivos (`VoteTypeId=2`) y negativos (`VoteTypeId=3`).
#
# Primero, calcular el resultado de cada voto. Nótese cómo haciendo uso de `$cond` se puede aplicar una condición `if` para sumar o restar dependiendo del tipo del voto.
#
# Después lo comprobaremos con los existentes en Posts.

# %%
score_by_post: CommandCursor[dict[str,Any]] = db.votes.aggregate([
    { "$match" : {"$or" : [ {"VoteTypeId" : 2},
                            {"VoteTypeId" : 3}]
                  }
    },
    {
        '$group': {
            '_id': '$PostId',
            'score': { '$sum': { "$cond": {
                                            "if" : { "$eq" : [ "$VoteTypeId", 2 ]},
                                            "then" : 1,
                                            "else" : -1
                                          }} }
        }
    },
    { '$limit' : 20}
    ])
list(score_by_post)
# Out:
# [{'_id': 420145, 'score': -2},
#  {'_id': 322412, 'score': -1},
#  {'_id': 79797, 'score': -2},
#  {'_id': 210395, 'score': 2},
#  {'_id': 506704, 'score': 1},
#  {'_id': 22157, 'score': 1},
#  {'_id': 302749, 'score': 3},
#  {'_id': 127392, 'score': 2},
#  {'_id': 350293, 'score': 1},
#  {'_id': 578600, 'score': -1},
#  {'_id': 274394, 'score': 1},
#  {'_id': 376331, 'score': 1},
#  {'_id': 526551, 'score': 2},
#  {'_id': 96807, 'score': -1},
#  {'_id': 410236, 'score': -1},
#  {'_id': 291895, 'score': 1},
#  {'_id': 55339, 'score': 2},
#  {'_id': 400664, 'score': 1},
#  {'_id': 74776, 'score': 1},
#  {'_id': 48012, 'score': 1}]

# %% [markdown]
# Y después comparado con lo que hay en los Posts. La consulta, como se puede ver, sacará sólo los elementos en donde los votos en `Votes` no coincide con `Posts` (debe ser vacío). Nótese el uso de la nueva construcción `$expr`, que permite añadir expresiones dentro de la consulta.
#
# **CUIDADO** Si no se define el índice correcto, la consulta tarda mucho. ¿Cuál?

# %%
# Creación del índice secreto... ¿cuál?
import zlib
secret_code = b'x\x9cKI\xd2+\xc8/.)\xd6K.JM,I\x8d\xcf\xccKI\xad\xd0\x88V\xf7LQ\xd7Q\xf0p\x0c\xf6pu\x89\xd5\x04\x00\xfe`\x0cD'
eval(zlib.decompress(secret_code).decode())
# Out:
# 'Id_1_hashed_1'

# %%
score_by_post_comp: CommandCursor[dict[str,Any]] = db.votes.aggregate([
    { "$match" : {"$or" : [ {"VoteTypeId" : 2},
                            {"VoteTypeId" : 3}]
                  }
    },
    {
        '$group': {
            '_id': '$PostId',
            'score': { '$sum': { "$cond" : {
                                            "if" : { "$eq" : [ "$VoteTypeId", 2 ]},
                                            "then" : 1,
                                            "else" : -1
                                           }}}
        }
    },
    {
        "$lookup": {
            'from': "posts",
            'localField': "_id",
            'foreignField': "Id",
            'as': "post"
        }
    },
    { "$unwind" : "$post"},
    {
        "$match" : {'$expr' : {'$ne' : [ '$score', '$post.Score']}}
    }
])
list(score_by_post_comp)
# Out:
# []

# %% [markdown]
# ### Ejemplo de realización de una consulta de reciprocidad

# %% [markdown]
# Como ejemplo de consulta compleja con el Framework de Agregación, adjunto una posible solución a la consulta siguiente: ¿Hay usuarios que hacen preguntas y son respondidos por otros usuarios que a su vez preguntaron y fueron respondidos por los primeros? (Es decir, ¿hay reciprocidad en las interacciones en Stacokverflow español?)

# %%
RQ4: CommandCursor[dict[str,Any]] = db.posts.aggregate( [
        { "$match" : {"PostTypeId": 2}}, # cogemos solo los qu eosn repsuestas (tipo 2)
        { '$lookup': {
            'from': "posts",
            'localField': "ParentId",  # id de la pregunta a la que se refiere la respuesta
            'foreignField': "Id",
            'as': "question"
          }
        },

        { '$unwind' : '$question' },

        { '$project' : {
            'OwnerUserId': True,
            'OP' : '$question.OwnerUserId'  # original poster (el usuario orignal que hizo la pregunta)
          }
        },
        { '$group' : {'_id' : {'min' : { '$min' : ['$OwnerUserId' , '$OP'] },
                               'max' : { '$max' : ['$OwnerUserId' , '$OP'] }},
                      'pairs' : {'$addToSet' : { '0q': '$OP', '1a': '$OwnerUserId'}}
          }
        },
        { '$project': {
            'pairs' : True,
            'npairs' : { '$size' : '$pairs'}
          }
        },
        { '$match' : { 'npairs' : { '$eq' : 2}} }
    ])
RQ4 = list(RQ4)
RQ4
# Out:
# [{'_id': {'min': 2429, 'max': 6491},
#   'pairs': [{'0q': 6491, '1a': 2429}, {'0q': 2429, '1a': 6491}],
#   'npairs': 2},
#  {'_id': {'min': 20709, 'max': 29967},
#   'pairs': [{'0q': 20709, '1a': 29967}, {'0q': 29967, '1a': 20709}],
#   'npairs': 2},
#  {'_id': {'min': 32292, 'max': ''},
#   'pairs': [{'0q': '', '1a': 32292}, {'0q': 32292, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 4229, 'max': 29967},
#   'pairs': [{'0q': 4229, '1a': 29967}, {'0q': 29967, '1a': 4229}],
#   'npairs': 2},
#  {'_id': {'min': 6095, 'max': 13938},
#   'pairs': [{'0q': 13938, '1a': 6095}, {'0q': 6095, '1a': 13938}],
#   'npairs': 2},
#  {'_id': {'min': 3092, 'max': ''},
#   'pairs': [{'0q': '', '1a': 3092}, {'0q': 3092, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 6095, 'max': 19610},
#   'pairs': [{'0q': 6095, '1a': 19610}, {'0q': 19610, '1a': 6095}],
#   'npairs': 2},
#  {'_id': {'min': 729, 'max': 1839},
#   'pairs': [{'0q': 729, '1a': 1839}, {'0q': 1839, '1a': 729}],
#   'npairs': 2},
#  {'_id': {'min': 23, 'max': 25},
#   'pairs': [{'0q': 25, '1a': 23}, {'0q': 23, '1a': 25}],
#   'npairs': 2},
#  {'_id': {'min': 33256, 'max': 77052},
#   'pairs': [{'0q': 77052, '1a': 33256}, {'0q': 33256, '1a': 77052}],
#   'npairs': 2},
#  {'_id': {'min': 26651, 'max': ''},
#   'pairs': [{'0q': 26651, '1a': ''}, {'0q': '', '1a': 26651}],
#   'npairs': 2},
#  {'_id': {'min': 22, 'max': 342},
#   'pairs': [{'0q': 342, '1a': 22}, {'0q': 22, '1a': 342}],
#   'npairs': 2},
#  {'_id': {'min': 638, 'max': 29967},
#   'pairs': [{'0q': 638, '1a': 29967}, {'0q': 29967, '1a': 638}],
#   'npairs': 2},
#  {'_id': {'min': 116640, 'max': ''},
#   'pairs': [{'0q': '', '1a': 116640}, {'0q': 116640, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 22620, 'max': ''},
#   'pairs': [{'0q': '', '1a': 22620}, {'0q': 22620, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 54706, 'max': 57158},
#   'pairs': [{'0q': 54706, '1a': 57158}, {'0q': 57158, '1a': 54706}],
#   'npairs': 2},
#  {'_id': {'min': 22, 'max': 729},
#   'pairs': [{'0q': 729, '1a': 22}, {'0q': 22, '1a': 729}],
#   'npairs': 2},
#  {'_id': {'min': 42107, 'max': ''},
#   'pairs': [{'0q': '', '1a': 42107}, {'0q': 42107, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 11313, 'max': 29967},
#   'pairs': [{'0q': 11313, '1a': 29967}, {'0q': 29967, '1a': 11313}],
#   'npairs': 2},
#  {'_id': {'min': 56616, 'max': ''},
#   'pairs': [{'0q': 56616, '1a': ''}, {'0q': '', '1a': 56616}],
#   'npairs': 2},
#  {'_id': {'min': 104587, 'max': ''},
#   'pairs': [{'0q': '', '1a': 104587}, {'0q': 104587, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 20709, 'max': 48081},
#   'pairs': [{'0q': 48081, '1a': 20709}, {'0q': 20709, '1a': 48081}],
#   'npairs': 2},
#  {'_id': {'min': 54246, 'max': 54443},
#   'pairs': [{'0q': 54246, '1a': 54443}, {'0q': 54443, '1a': 54246}],
#   'npairs': 2},
#  {'_id': {'min': 121157, 'max': ''},
#   'pairs': [{'0q': 121157, '1a': ''}, {'0q': '', '1a': 121157}],
#   'npairs': 2},
#  {'_id': {'min': 51594, 'max': ''},
#   'pairs': [{'0q': 51594, '1a': ''}, {'0q': '', '1a': 51594}],
#   'npairs': 2},
#  {'_id': {'min': 154, 'max': 13938},
#   'pairs': [{'0q': 13938, '1a': 154}, {'0q': 154, '1a': 13938}],
#   'npairs': 2},
#  {'_id': {'min': 56195, 'max': ''},
#   'pairs': [{'0q': '', '1a': 56195}, {'0q': 56195, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 47499, 'max': ''},
#   'pairs': [{'0q': 47499, '1a': ''}, {'0q': '', '1a': 47499}],
#   'npairs': 2},
#  {'_id': {'min': 75807, 'max': ''},
#   'pairs': [{'0q': 75807, '1a': ''}, {'0q': '', '1a': 75807}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 32268},
#   'pairs': [{'0q': 29967, '1a': 32268}, {'0q': 32268, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 131982, 'max': ''},
#   'pairs': [{'0q': '', '1a': 131982}, {'0q': 131982, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 184, 'max': ''},
#   'pairs': [{'0q': 184, '1a': ''}, {'0q': '', '1a': 184}],
#   'npairs': 2},
#  {'_id': {'min': 154, 'max': ''},
#   'pairs': [{'0q': '', '1a': 154}, {'0q': 154, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 19533, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 19533}, {'0q': 19533, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 18597},
#   'pairs': [{'0q': 18597, '1a': 250}, {'0q': 250, '1a': 18597}],
#   'npairs': 2},
#  {'_id': {'min': 3834, 'max': ''},
#   'pairs': [{'0q': 3834, '1a': ''}, {'0q': '', '1a': 3834}],
#   'npairs': 2},
#  {'_id': {'min': 80614, 'max': ''},
#   'pairs': [{'0q': 80614, '1a': ''}, {'0q': '', '1a': 80614}],
#   'npairs': 2},
#  {'_id': {'min': 7123, 'max': 180118},
#   'pairs': [{'0q': 180118, '1a': 7123}, {'0q': 7123, '1a': 180118}],
#   'npairs': 2},
#  {'_id': {'min': 85496, 'max': 248814},
#   'pairs': [{'0q': 248814, '1a': 85496}, {'0q': 85496, '1a': 248814}],
#   'npairs': 2},
#  {'_id': {'min': 729, 'max': 1798},
#   'pairs': [{'0q': 1798, '1a': 729}, {'0q': 729, '1a': 1798}],
#   'npairs': 2},
#  {'_id': {'min': 131982, 'max': 178543},
#   'pairs': [{'0q': 131982, '1a': 178543}, {'0q': 178543, '1a': 131982}],
#   'npairs': 2},
#  {'_id': {'min': 40248, 'max': ''},
#   'pairs': [{'0q': '', '1a': 40248}, {'0q': 40248, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 78696, 'max': ''},
#   'pairs': [{'0q': 78696, '1a': ''}, {'0q': '', '1a': 78696}],
#   'npairs': 2},
#  {'_id': {'min': 71997, 'max': ''},
#   'pairs': [{'0q': 71997, '1a': ''}, {'0q': '', '1a': 71997}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 2163},
#   'pairs': [{'0q': 2163, '1a': 250}, {'0q': 250, '1a': 2163}],
#   'npairs': 2},
#  {'_id': {'min': 39181, 'max': ''},
#   'pairs': [{'0q': 39181, '1a': ''}, {'0q': '', '1a': 39181}],
#   'npairs': 2},
#  {'_id': {'min': 9885, 'max': 16108},
#   'pairs': [{'0q': 16108, '1a': 9885}, {'0q': 9885, '1a': 16108}],
#   'npairs': 2},
#  {'_id': {'min': 18505, 'max': ''},
#   'pairs': [{'0q': 18505, '1a': ''}, {'0q': '', '1a': 18505}],
#   'npairs': 2},
#  {'_id': {'min': 119615, 'max': ''},
#   'pairs': [{'0q': 119615, '1a': ''}, {'0q': '', '1a': 119615}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 47532},
#   'pairs': [{'0q': 29967, '1a': 47532}, {'0q': 47532, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 463, 'max': 19600},
#   'pairs': [{'0q': 19600, '1a': 463}, {'0q': 463, '1a': 19600}],
#   'npairs': 2},
#  {'_id': {'min': 6491, 'max': 10576},
#   'pairs': [{'0q': 6491, '1a': 10576}, {'0q': 10576, '1a': 6491}],
#   'npairs': 2},
#  {'_id': {'min': 28035, 'max': 34093},
#   'pairs': [{'0q': 34093, '1a': 28035}, {'0q': 28035, '1a': 34093}],
#   'npairs': 2},
#  {'_id': {'min': 22112, 'max': ''},
#   'pairs': [{'0q': '', '1a': 22112}, {'0q': 22112, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 353},
#   'pairs': [{'0q': 353, '1a': 100}, {'0q': 100, '1a': 353}],
#   'npairs': 2},
#  {'_id': {'min': 54039, 'max': 55865},
#   'pairs': [{'0q': 55865, '1a': 54039}, {'0q': 54039, '1a': 55865}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 301},
#   'pairs': [{'0q': 301, '1a': 24}, {'0q': 24, '1a': 301}],
#   'npairs': 2},
#  {'_id': {'min': 22, 'max': 288},
#   'pairs': [{'0q': 22, '1a': 288}, {'0q': 288, '1a': 22}],
#   'npairs': 2},
#  {'_id': {'min': 56235, 'max': ''},
#   'pairs': [{'0q': '', '1a': 56235}, {'0q': 56235, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 205526, 'max': ''},
#   'pairs': [{'0q': 205526, '1a': ''}, {'0q': '', '1a': 205526}],
#   'npairs': 2},
#  {'_id': {'min': 13938, 'max': ''},
#   'pairs': [{'0q': '', '1a': 13938}, {'0q': 13938, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 16841, 'max': ''},
#   'pairs': [{'0q': 16841, '1a': ''}, {'0q': '', '1a': 16841}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 6491},
#   'pairs': [{'0q': 250, '1a': 6491}, {'0q': 6491, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 2366, 'max': 5324},
#   'pairs': [{'0q': 5324, '1a': 2366}, {'0q': 2366, '1a': 5324}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 73380},
#   'pairs': [{'0q': 29967, '1a': 73380}, {'0q': 73380, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 14243},
#   'pairs': [{'0q': 14243, '1a': 250}, {'0q': 250, '1a': 14243}],
#   'npairs': 2},
#  {'_id': {'min': 78, 'max': 250},
#   'pairs': [{'0q': 78, '1a': 250}, {'0q': 250, '1a': 78}],
#   'npairs': 2},
#  {'_id': {'min': 13938, 'max': 18771},
#   'pairs': [{'0q': 18771, '1a': 13938}, {'0q': 13938, '1a': 18771}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 2004},
#   'pairs': [{'0q': 100, '1a': 2004}, {'0q': 2004, '1a': 100}],
#   'npairs': 2},
#  {'_id': {'min': 191, 'max': 2230},
#   'pairs': [{'0q': 2230, '1a': 191}, {'0q': 191, '1a': 2230}],
#   'npairs': 2},
#  {'_id': {'min': 89811, 'max': 93721},
#   'pairs': [{'0q': 89811, '1a': 93721}, {'0q': 93721, '1a': 89811}],
#   'npairs': 2},
#  {'_id': {'min': 83, 'max': 29967},
#   'pairs': [{'0q': 83, '1a': 29967}, {'0q': 29967, '1a': 83}],
#   'npairs': 2},
#  {'_id': {'min': 6046, 'max': ''},
#   'pairs': [{'0q': '', '1a': 6046}, {'0q': 6046, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 399},
#   'pairs': [{'0q': 399, '1a': 100}, {'0q': 100, '1a': 399}],
#   'npairs': 2},
#  {'_id': {'min': 73, 'max': 2224},
#   'pairs': [{'0q': 73, '1a': 2224}, {'0q': 2224, '1a': 73}],
#   'npairs': 2},
#  {'_id': {'min': 165012, 'max': ''},
#   'pairs': [{'0q': 165012, '1a': ''}, {'0q': '', '1a': 165012}],
#   'npairs': 2},
#  {'_id': {'min': 16349, 'max': 25555},
#   'pairs': [{'0q': 25555, '1a': 16349}, {'0q': 16349, '1a': 25555}],
#   'npairs': 2},
#  {'_id': {'min': 21178, 'max': 78168},
#   'pairs': [{'0q': 78168, '1a': 21178}, {'0q': 21178, '1a': 78168}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 12625},
#   'pairs': [{'0q': 12625, '1a': 250}, {'0q': 250, '1a': 12625}],
#   'npairs': 2},
#  {'_id': {'min': 18597, 'max': 29967},
#   'pairs': [{'0q': 18597, '1a': 29967}, {'0q': 29967, '1a': 18597}],
#   'npairs': 2},
#  {'_id': {'min': 33627, 'max': ''},
#   'pairs': [{'0q': '', '1a': 33627}, {'0q': 33627, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 3275, 'max': 35873},
#   'pairs': [{'0q': 35873, '1a': 3275}, {'0q': 3275, '1a': 35873}],
#   'npairs': 2},
#  {'_id': {'min': 77266, 'max': 147493},
#   'pairs': [{'0q': 77266, '1a': 147493}, {'0q': 147493, '1a': 77266}],
#   'npairs': 2},
#  {'_id': {'min': 24490, 'max': 24922},
#   'pairs': [{'0q': 24922, '1a': 24490}, {'0q': 24490, '1a': 24922}],
#   'npairs': 2},
#  {'_id': {'min': 53715, 'max': ''},
#   'pairs': [{'0q': 53715, '1a': ''}, {'0q': '', '1a': 53715}],
#   'npairs': 2},
#  {'_id': {'min': 73, 'max': 29967},
#   'pairs': [{'0q': 73, '1a': 29967}, {'0q': 29967, '1a': 73}],
#   'npairs': 2},
#  {'_id': {'min': 25656, 'max': ''},
#   'pairs': [{'0q': '', '1a': 25656}, {'0q': 25656, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 34430, 'max': 56195},
#   'pairs': [{'0q': 34430, '1a': 56195}, {'0q': 56195, '1a': 34430}],
#   'npairs': 2},
#  {'_id': {'min': 109469, 'max': 115971},
#   'pairs': [{'0q': 109469, '1a': 115971}, {'0q': 115971, '1a': 109469}],
#   'npairs': 2},
#  {'_id': {'min': 65, 'max': 78},
#   'pairs': [{'0q': 65, '1a': 78}, {'0q': 78, '1a': 65}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 2838},
#   'pairs': [{'0q': 100, '1a': 2838}, {'0q': 2838, '1a': 100}],
#   'npairs': 2},
#  {'_id': {'min': 33391, 'max': ''},
#   'pairs': [{'0q': 33391, '1a': ''}, {'0q': '', '1a': 33391}],
#   'npairs': 2},
#  {'_id': {'min': 2742, 'max': ''},
#   'pairs': [{'0q': '', '1a': 2742}, {'0q': 2742, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 342, 'max': 2367},
#   'pairs': [{'0q': 342, '1a': 2367}, {'0q': 2367, '1a': 342}],
#   'npairs': 2},
#  {'_id': {'min': 342, 'max': ''},
#   'pairs': [{'0q': '', '1a': 342}, {'0q': 342, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 24872, 'max': ''},
#   'pairs': [{'0q': 24872, '1a': ''}, {'0q': '', '1a': 24872}],
#   'npairs': 2},
#  {'_id': {'min': 65578, 'max': ''},
#   'pairs': [{'0q': '', '1a': 65578}, {'0q': 65578, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 27881},
#   'pairs': [{'0q': 27881, '1a': 250}, {'0q': 250, '1a': 27881}],
#   'npairs': 2},
#  {'_id': {'min': 45772, 'max': 70473},
#   'pairs': [{'0q': 70473, '1a': 45772}, {'0q': 45772, '1a': 70473}],
#   'npairs': 2},
#  {'_id': {'min': 638, 'max': 35232},
#   'pairs': [{'0q': 638, '1a': 35232}, {'0q': 35232, '1a': 638}],
#   'npairs': 2},
#  {'_id': {'min': 38304, 'max': 56453},
#   'pairs': [{'0q': 38304, '1a': 56453}, {'0q': 56453, '1a': 38304}],
#   'npairs': 2},
#  {'_id': {'min': 143803, 'max': ''},
#   'pairs': [{'0q': '', '1a': 143803}, {'0q': 143803, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 10859, 'max': ''},
#   'pairs': [{'0q': 10859, '1a': ''}, {'0q': '', '1a': 10859}],
#   'npairs': 2},
#  {'_id': {'min': 31764, 'max': 47366},
#   'pairs': [{'0q': 31764, '1a': 47366}, {'0q': 47366, '1a': 31764}],
#   'npairs': 2},
#  {'_id': {'min': 44779, 'max': ''},
#   'pairs': [{'0q': 44779, '1a': ''}, {'0q': '', '1a': 44779}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 27297},
#   'pairs': [{'0q': 250, '1a': 27297}, {'0q': 27297, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 6765, 'max': ''},
#   'pairs': [{'0q': 6765, '1a': ''}, {'0q': '', '1a': 6765}],
#   'npairs': 2},
#  {'_id': {'min': 18771, 'max': 27881},
#   'pairs': [{'0q': 27881, '1a': 18771}, {'0q': 18771, '1a': 27881}],
#   'npairs': 2},
#  {'_id': {'min': 81074, 'max': 84943},
#   'pairs': [{'0q': 81074, '1a': 84943}, {'0q': 84943, '1a': 81074}],
#   'npairs': 2},
#  {'_id': {'min': 16841, 'max': 95875},
#   'pairs': [{'0q': 95875, '1a': 16841}, {'0q': 16841, '1a': 95875}],
#   'npairs': 2},
#  {'_id': {'min': 120, 'max': 531},
#   'pairs': [{'0q': 531, '1a': 120}, {'0q': 120, '1a': 531}],
#   'npairs': 2},
#  {'_id': {'min': 517, 'max': 2676},
#   'pairs': [{'0q': 517, '1a': 2676}, {'0q': 2676, '1a': 517}],
#   'npairs': 2},
#  {'_id': {'min': 28650, 'max': ''},
#   'pairs': [{'0q': '', '1a': 28650}, {'0q': 28650, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 399, 'max': 555},
#   'pairs': [{'0q': 555, '1a': 399}, {'0q': 399, '1a': 555}],
#   'npairs': 2},
#  {'_id': {'min': 63533, 'max': ''},
#   'pairs': [{'0q': '', '1a': 63533}, {'0q': 63533, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 4499, 'max': ''},
#   'pairs': [{'0q': 4499, '1a': ''}, {'0q': '', '1a': 4499}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 9897},
#   'pairs': [{'0q': 9897, '1a': 250}, {'0q': 250, '1a': 9897}],
#   'npairs': 2},
#  {'_id': {'min': 822, 'max': ''},
#   'pairs': [{'0q': 822, '1a': ''}, {'0q': '', '1a': 822}],
#   'npairs': 2},
#  {'_id': {'min': 2429, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 2429}, {'0q': 2429, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 109858, 'max': ''},
#   'pairs': [{'0q': 109858, '1a': ''}, {'0q': '', '1a': 109858}],
#   'npairs': 2},
#  {'_id': {'min': 14488, 'max': ''},
#   'pairs': [{'0q': '', '1a': 14488}, {'0q': 14488, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 150301, 'max': ''},
#   'pairs': [{'0q': 150301, '1a': ''}, {'0q': '', '1a': 150301}],
#   'npairs': 2},
#  {'_id': {'min': 54178, 'max': 57158},
#   'pairs': [{'0q': 57158, '1a': 54178}, {'0q': 54178, '1a': 57158}],
#   'npairs': 2},
#  {'_id': {'min': 729, 'max': 2224},
#   'pairs': [{'0q': 2224, '1a': 729}, {'0q': 729, '1a': 2224}],
#   'npairs': 2},
#  {'_id': {'min': 85031, 'max': 96564},
#   'pairs': [{'0q': 85031, '1a': 96564}, {'0q': 96564, '1a': 85031}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 39181},
#   'pairs': [{'0q': 29967, '1a': 39181}, {'0q': 39181, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 69440, 'max': ''},
#   'pairs': [{'0q': '', '1a': 69440}, {'0q': 69440, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 25, 'max': ''},
#   'pairs': [{'0q': '', '1a': 25}, {'0q': 25, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 64276, 'max': ''},
#   'pairs': [{'0q': '', '1a': 64276}, {'0q': 64276, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 95, 'max': 250},
#   'pairs': [{'0q': 250, '1a': 95}, {'0q': 95, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 95341, 'max': 96682},
#   'pairs': [{'0q': 96682, '1a': 95341}, {'0q': 95341, '1a': 96682}],
#   'npairs': 2},
#  {'_id': {'min': 141893, 'max': ''},
#   'pairs': [{'0q': '', '1a': 141893}, {'0q': 141893, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 731},
#   'pairs': [{'0q': 731, '1a': 250}, {'0q': 250, '1a': 731}],
#   'npairs': 2},
#  {'_id': {'min': 127500, 'max': ''},
#   'pairs': [{'0q': '', '1a': 127500}, {'0q': 127500, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 12870, 'max': 106331},
#   'pairs': [{'0q': 106331, '1a': 12870}, {'0q': 12870, '1a': 106331}],
#   'npairs': 2},
#  {'_id': {'min': 202972, 'max': ''},
#   'pairs': [{'0q': '', '1a': 202972}, {'0q': 202972, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 353, 'max': ''},
#   'pairs': [{'0q': '', '1a': 353}, {'0q': 353, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 18484, 'max': ''},
#   'pairs': [{'0q': '', '1a': 18484}, {'0q': 18484, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 44721, 'max': 72179},
#   'pairs': [{'0q': 44721, '1a': 72179}, {'0q': 72179, '1a': 44721}],
#   'npairs': 2},
#  {'_id': {'min': 199780, 'max': ''},
#   'pairs': [{'0q': '', '1a': 199780}, {'0q': 199780, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 15855, 'max': 18124},
#   'pairs': [{'0q': 15855, '1a': 18124}, {'0q': 18124, '1a': 15855}],
#   'npairs': 2},
#  {'_id': {'min': 131662, 'max': ''},
#   'pairs': [{'0q': '', '1a': 131662}, {'0q': 131662, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 25, 'max': 288},
#   'pairs': [{'0q': 288, '1a': 25}, {'0q': 25, '1a': 288}],
#   'npairs': 2},
#  {'_id': {'min': 26910, 'max': 37305},
#   'pairs': [{'0q': 37305, '1a': 26910}, {'0q': 26910, '1a': 37305}],
#   'npairs': 2},
#  {'_id': {'min': 183782, 'max': ''},
#   'pairs': [{'0q': '', '1a': 183782}, {'0q': 183782, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 13759, 'max': ''},
#   'pairs': [{'0q': '', '1a': 13759}, {'0q': 13759, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 84466, 'max': ''},
#   'pairs': [{'0q': 84466, '1a': ''}, {'0q': '', '1a': 84466}],
#   'npairs': 2},
#  {'_id': {'min': 225338, 'max': ''},
#   'pairs': [{'0q': '', '1a': 225338}, {'0q': 225338, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 2742, 'max': 19610},
#   'pairs': [{'0q': 2742, '1a': 19610}, {'0q': 19610, '1a': 2742}],
#   'npairs': 2},
#  {'_id': {'min': 463, 'max': ''},
#   'pairs': [{'0q': 463, '1a': ''}, {'0q': '', '1a': 463}],
#   'npairs': 2},
#  {'_id': {'min': 6491, 'max': 23233},
#   'pairs': [{'0q': 23233, '1a': 6491}, {'0q': 6491, '1a': 23233}],
#   'npairs': 2},
#  {'_id': {'min': 2230, 'max': 16108},
#   'pairs': [{'0q': 16108, '1a': 2230}, {'0q': 2230, '1a': 16108}],
#   'npairs': 2},
#  {'_id': {'min': 38304, 'max': 39259},
#   'pairs': [{'0q': 38304, '1a': 39259}, {'0q': 39259, '1a': 38304}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 32772},
#   'pairs': [{'0q': 32772, '1a': 24}, {'0q': 24, '1a': 32772}],
#   'npairs': 2},
#  {'_id': {'min': 18376, 'max': 26302},
#   'pairs': [{'0q': 18376, '1a': 26302}, {'0q': 26302, '1a': 18376}],
#   'npairs': 2},
#  {'_id': {'min': 4229, 'max': ''},
#   'pairs': [{'0q': 4229, '1a': ''}, {'0q': '', '1a': 4229}],
#   'npairs': 2},
#  {'_id': {'min': 33073, 'max': ''},
#   'pairs': [{'0q': 33073, '1a': ''}, {'0q': '', '1a': 33073}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': ''},
#   'pairs': [{'0q': '', '1a': 100}, {'0q': 100, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 10576, 'max': ''},
#   'pairs': [{'0q': 10576, '1a': ''}, {'0q': '', '1a': 10576}],
#   'npairs': 2},
#  {'_id': {'min': 2004, 'max': ''},
#   'pairs': [{'0q': 2004, '1a': ''}, {'0q': '', '1a': 2004}],
#   'npairs': 2},
#  {'_id': {'min': 34, 'max': 250},
#   'pairs': [{'0q': 34, '1a': 250}, {'0q': 250, '1a': 34}],
#   'npairs': 2},
#  {'_id': {'min': 10576, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 10576}, {'0q': 10576, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 74880, 'max': ''},
#   'pairs': [{'0q': 74880, '1a': ''}, {'0q': '', '1a': 74880}],
#   'npairs': 2},
#  {'_id': {'min': 21, 'max': 1184},
#   'pairs': [{'0q': 1184, '1a': 21}, {'0q': 21, '1a': 1184}],
#   'npairs': 2},
#  {'_id': {'min': 48081, 'max': ''},
#   'pairs': [{'0q': '', '1a': 48081}, {'0q': 48081, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 30364, 'max': ''},
#   'pairs': [{'0q': 30364, '1a': ''}, {'0q': '', '1a': 30364}],
#   'npairs': 2},
#  {'_id': {'min': 44942, 'max': 44946},
#   'pairs': [{'0q': 44946, '1a': 44942}, {'0q': 44942, '1a': 44946}],
#   'npairs': 2},
#  {'_id': {'min': 69447, 'max': 74711},
#   'pairs': [{'0q': 69447, '1a': 74711}, {'0q': 74711, '1a': 69447}],
#   'npairs': 2},
#  {'_id': {'min': 107224, 'max': ''},
#   'pairs': [{'0q': '', '1a': 107224}, {'0q': 107224, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': ''},
#   'pairs': [{'0q': '', '1a': 29967}, {'0q': 29967, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 2429, 'max': ''},
#   'pairs': [{'0q': 2429, '1a': ''}, {'0q': '', '1a': 2429}],
#   'npairs': 2},
#  {'_id': {'min': 9754, 'max': ''},
#   'pairs': [{'0q': '', '1a': 9754}, {'0q': 9754, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 1466, 'max': ''},
#   'pairs': [{'0q': '', '1a': 1466}, {'0q': 1466, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 252576, 'max': ''},
#   'pairs': [{'0q': 252576, '1a': ''}, {'0q': '', '1a': 252576}],
#   'npairs': 2},
#  {'_id': {'min': 84738, 'max': ''},
#   'pairs': [{'0q': 84738, '1a': ''}, {'0q': '', '1a': 84738}],
#   'npairs': 2},
#  {'_id': {'min': 400, 'max': ''},
#   'pairs': [{'0q': '', '1a': 400}, {'0q': 400, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 27881, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 27881}, {'0q': 27881, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 78168, 'max': ''},
#   'pairs': [{'0q': 78168, '1a': ''}, {'0q': '', '1a': 78168}],
#   'npairs': 2},
#  {'_id': {'min': 12625, 'max': ''},
#   'pairs': [{'0q': '', '1a': 12625}, {'0q': 12625, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 2230, 'max': ''},
#   'pairs': [{'0q': 2230, '1a': ''}, {'0q': '', '1a': 2230}],
#   'npairs': 2},
#  {'_id': {'min': 188974, 'max': ''},
#   'pairs': [{'0q': 188974, '1a': ''}, {'0q': '', '1a': 188974}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 638},
#   'pairs': [{'0q': 638, '1a': 100}, {'0q': 100, '1a': 638}],
#   'npairs': 2},
#  {'_id': {'min': 228290, 'max': ''},
#   'pairs': [{'0q': '', '1a': 228290}, {'0q': 228290, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 63378, 'max': ''},
#   'pairs': [{'0q': '', '1a': 63378}, {'0q': 63378, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 6491, 'max': 18771},
#   'pairs': [{'0q': 6491, '1a': 18771}, {'0q': 18771, '1a': 6491}],
#   'npairs': 2},
#  {'_id': {'min': 91499, 'max': 180509},
#   'pairs': [{'0q': 91499, '1a': 180509}, {'0q': 180509, '1a': 91499}],
#   'npairs': 2},
#  {'_id': {'min': 72179, 'max': ''},
#   'pairs': [{'0q': 72179, '1a': ''}, {'0q': '', '1a': 72179}],
#   'npairs': 2},
#  {'_id': {'min': 398, 'max': 547},
#   'pairs': [{'0q': 547, '1a': 398}, {'0q': 398, '1a': 547}],
#   'npairs': 2},
#  {'_id': {'min': 102339, 'max': ''},
#   'pairs': [{'0q': '', '1a': 102339}, {'0q': 102339, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 30877, 'max': ''},
#   'pairs': [{'0q': 30877, '1a': ''}, {'0q': '', '1a': 30877}],
#   'npairs': 2},
#  {'_id': {'min': 27366, 'max': ''},
#   'pairs': [{'0q': '', '1a': 27366}, {'0q': 27366, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 60569, 'max': ''},
#   'pairs': [{'0q': '', '1a': 60569}, {'0q': 60569, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 65, 'max': 7661},
#   'pairs': [{'0q': 65, '1a': 7661}, {'0q': 7661, '1a': 65}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': ''},
#   'pairs': [{'0q': '', '1a': 250}, {'0q': 250, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 50539, 'max': ''},
#   'pairs': [{'0q': '', '1a': 50539}, {'0q': 50539, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 103288, 'max': ''},
#   'pairs': [{'0q': 103288, '1a': ''}, {'0q': '', '1a': 103288}],
#   'npairs': 2},
#  {'_id': {'min': 41772, 'max': ''},
#   'pairs': [{'0q': 41772, '1a': ''}, {'0q': '', '1a': 41772}],
#   'npairs': 2},
#  {'_id': {'min': 83, 'max': 301},
#   'pairs': [{'0q': 301, '1a': 83}, {'0q': 83, '1a': 301}],
#   'npairs': 2},
#  {'_id': {'min': 18771, 'max': 29967},
#   'pairs': [{'0q': 18771, '1a': 29967}, {'0q': 29967, '1a': 18771}],
#   'npairs': 2},
#  {'_id': {'min': 7358, 'max': ''},
#   'pairs': [{'0q': 7358, '1a': ''}, {'0q': '', '1a': 7358}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 399},
#   'pairs': [{'0q': 250, '1a': 399}, {'0q': 399, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 324},
#   'pairs': [{'0q': 324, '1a': 250}, {'0q': 250, '1a': 324}],
#   'npairs': 2},
#  {'_id': {'min': 45772, 'max': 49705},
#   'pairs': [{'0q': 45772, '1a': 49705}, {'0q': 49705, '1a': 45772}],
#   'npairs': 2},
#  {'_id': {'min': 122597, 'max': ''},
#   'pairs': [{'0q': 122597, '1a': ''}, {'0q': '', '1a': 122597}],
#   'npairs': 2},
#  {'_id': {'min': 31764, 'max': 61530},
#   'pairs': [{'0q': 61530, '1a': 31764}, {'0q': 31764, '1a': 61530}],
#   'npairs': 2},
#  {'_id': {'min': 260743, 'max': 305409},
#   'pairs': [{'0q': 305409, '1a': 260743}, {'0q': 260743, '1a': 305409}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 39259},
#   'pairs': [{'0q': 39259, '1a': 29967}, {'0q': 29967, '1a': 39259}],
#   'npairs': 2},
#  {'_id': {'min': 87233, 'max': 209421},
#   'pairs': [{'0q': 209421, '1a': 87233}, {'0q': 87233, '1a': 209421}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 2230},
#   'pairs': [{'0q': 24, '1a': 2230}, {'0q': 2230, '1a': 24}],
#   'npairs': 2},
#  {'_id': {'min': 6635, 'max': ''},
#   'pairs': [{'0q': '', '1a': 6635}, {'0q': 6635, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 53715},
#   'pairs': [{'0q': 53715, '1a': 29967}, {'0q': 29967, '1a': 53715}],
#   'npairs': 2},
#  {'_id': {'min': 34844, 'max': 54260},
#   'pairs': [{'0q': 54260, '1a': 34844}, {'0q': 34844, '1a': 54260}],
#   'npairs': 2},
#  {'_id': {'min': 158389, 'max': 158505},
#   'pairs': [{'0q': 158389, '1a': 158505}, {'0q': 158505, '1a': 158389}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 2230},
#   'pairs': [{'0q': 250, '1a': 2230}, {'0q': 2230, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 15264, 'max': ''},
#   'pairs': [{'0q': 15264, '1a': ''}, {'0q': '', '1a': 15264}],
#   'npairs': 2},
#  {'_id': {'min': 19533, 'max': 38304},
#   'pairs': [{'0q': 19533, '1a': 38304}, {'0q': 38304, '1a': 19533}],
#   'npairs': 2},
#  {'_id': {'min': 65, 'max': 1184},
#   'pairs': [{'0q': 65, '1a': 1184}, {'0q': 1184, '1a': 65}],
#   'npairs': 2},
#  {'_id': {'min': 16597, 'max': ''},
#   'pairs': [{'0q': 16597, '1a': ''}, {'0q': '', '1a': 16597}],
#   'npairs': 2},
#  {'_id': {'min': 74103, 'max': 167021},
#   'pairs': [{'0q': 74103, '1a': 167021}, {'0q': 167021, '1a': 74103}],
#   'npairs': 2},
#  {'_id': {'min': 6173, 'max': ''},
#   'pairs': [{'0q': 6173, '1a': ''}, {'0q': '', '1a': 6173}],
#   'npairs': 2},
#  {'_id': {'min': 16597, 'max': 54039},
#   'pairs': [{'0q': 54039, '1a': 16597}, {'0q': 16597, '1a': 54039}],
#   'npairs': 2},
#  {'_id': {'min': 16597, 'max': 29967},
#   'pairs': [{'0q': 16597, '1a': 29967}, {'0q': 29967, '1a': 16597}],
#   'npairs': 2},
#  {'_id': {'min': 32202, 'max': ''},
#   'pairs': [{'0q': 32202, '1a': ''}, {'0q': '', '1a': 32202}],
#   'npairs': 2},
#  {'_id': {'min': 142367, 'max': 143364},
#   'pairs': [{'0q': 143364, '1a': 142367}, {'0q': 142367, '1a': 143364}],
#   'npairs': 2},
#  {'_id': {'min': 4048, 'max': ''},
#   'pairs': [{'0q': 4048, '1a': ''}, {'0q': '', '1a': 4048}],
#   'npairs': 2},
#  {'_id': {'min': 16349, 'max': 25360},
#   'pairs': [{'0q': 25360, '1a': 16349}, {'0q': 16349, '1a': 25360}],
#   'npairs': 2},
#  {'_id': {'min': 12975, 'max': ''},
#   'pairs': [{'0q': 12975, '1a': ''}, {'0q': '', '1a': 12975}],
#   'npairs': 2},
#  {'_id': {'min': 49326, 'max': ''},
#   'pairs': [{'0q': '', '1a': 49326}, {'0q': 49326, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 463},
#   'pairs': [{'0q': 24, '1a': 463}, {'0q': 463, '1a': 24}],
#   'npairs': 2},
#  {'_id': {'min': 2230, 'max': 12446},
#   'pairs': [{'0q': 12446, '1a': 2230}, {'0q': 2230, '1a': 12446}],
#   'npairs': 2},
#  {'_id': {'min': 72859, 'max': ''},
#   'pairs': [{'0q': '', '1a': 72859}, {'0q': 72859, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 10775, 'max': 38468},
#   'pairs': [{'0q': 38468, '1a': 10775}, {'0q': 10775, '1a': 38468}],
#   'npairs': 2},
#  {'_id': {'min': 42407, 'max': ''},
#   'pairs': [{'0q': 42407, '1a': ''}, {'0q': '', '1a': 42407}],
#   'npairs': 2},
#  {'_id': {'min': 342, 'max': 517},
#   'pairs': [{'0q': 342, '1a': 517}, {'0q': 517, '1a': 342}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 529},
#   'pairs': [{'0q': 100, '1a': 529}, {'0q': 529, '1a': 100}],
#   'npairs': 2},
#  {'_id': {'min': 71173, 'max': 126651},
#   'pairs': [{'0q': 126651, '1a': 71173}, {'0q': 71173, '1a': 126651}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 131982},
#   'pairs': [{'0q': 29967, '1a': 131982}, {'0q': 131982, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 65775, 'max': ''},
#   'pairs': [{'0q': 65775, '1a': ''}, {'0q': '', '1a': 65775}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 60437},
#   'pairs': [{'0q': 29967, '1a': 60437}, {'0q': 60437, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 83304, 'max': ''},
#   'pairs': [{'0q': '', '1a': 83304}, {'0q': 83304, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 20709, 'max': 77342},
#   'pairs': [{'0q': 20709, '1a': 77342}, {'0q': 77342, '1a': 20709}],
#   'npairs': 2},
#  {'_id': {'min': 73625, 'max': ''},
#   'pairs': [{'0q': 73625, '1a': ''}, {'0q': '', '1a': 73625}],
#   'npairs': 2},
#  {'_id': {'min': 2230, 'max': 5902},
#   'pairs': [{'0q': 5902, '1a': 2230}, {'0q': 2230, '1a': 5902}],
#   'npairs': 2},
#  {'_id': {'min': 60437, 'max': ''},
#   'pairs': [{'0q': '', '1a': 60437}, {'0q': 60437, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 46832, 'max': 99941},
#   'pairs': [{'0q': 99941, '1a': 46832}, {'0q': 46832, '1a': 99941}],
#   'npairs': 2},
#  {'_id': {'min': 26910, 'max': ''},
#   'pairs': [{'0q': '', '1a': 26910}, {'0q': 26910, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 10576},
#   'pairs': [{'0q': 10576, '1a': 250}, {'0q': 250, '1a': 10576}],
#   'npairs': 2},
#  {'_id': {'min': 20709, 'max': ''},
#   'pairs': [{'0q': '', '1a': 20709}, {'0q': 20709, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 44721, 'max': ''},
#   'pairs': [{'0q': '', '1a': 44721}, {'0q': 44721, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 81074, 'max': ''},
#   'pairs': [{'0q': 81074, '1a': ''}, {'0q': '', '1a': 81074}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 16597},
#   'pairs': [{'0q': 250, '1a': 16597}, {'0q': 16597, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 48306, 'max': 55380},
#   'pairs': [{'0q': 48306, '1a': 55380}, {'0q': 55380, '1a': 48306}],
#   'npairs': 2},
#  {'_id': {'min': 175073, 'max': ''},
#   'pairs': [{'0q': 175073, '1a': ''}, {'0q': '', '1a': 175073}],
#   'npairs': 2},
#  {'_id': {'min': 106915, 'max': 134369},
#   'pairs': [{'0q': 106915, '1a': 134369}, {'0q': 134369, '1a': 106915}],
#   'npairs': 2},
#  {'_id': {'min': 67039, 'max': 105945},
#   'pairs': [{'0q': 105945, '1a': 67039}, {'0q': 67039, '1a': 105945}],
#   'npairs': 2},
#  {'_id': {'min': 65, 'max': ''},
#   'pairs': [{'0q': '', '1a': 65}, {'0q': 65, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 184, 'max': 16597},
#   'pairs': [{'0q': 184, '1a': 16597}, {'0q': 16597, '1a': 184}],
#   'npairs': 2},
#  {'_id': {'min': 124687, 'max': ''},
#   'pairs': [{'0q': 124687, '1a': ''}, {'0q': '', '1a': 124687}],
#   'npairs': 2},
#  {'_id': {'min': 113455, 'max': 143803},
#   'pairs': [{'0q': 113455, '1a': 143803}, {'0q': 143803, '1a': 113455}],
#   'npairs': 2},
#  {'_id': {'min': 121157, 'max': 205526},
#   'pairs': [{'0q': 121157, '1a': 205526}, {'0q': 205526, '1a': 121157}],
#   'npairs': 2},
#  {'_id': {'min': 68558, 'max': ''},
#   'pairs': [{'0q': 68558, '1a': ''}, {'0q': '', '1a': 68558}],
#   'npairs': 2},
#  {'_id': {'min': 153229, 'max': ''},
#   'pairs': [{'0q': 153229, '1a': ''}, {'0q': '', '1a': 153229}],
#   'npairs': 2},
#  {'_id': {'min': 33391, 'max': 96969},
#   'pairs': [{'0q': 33391, '1a': 96969}, {'0q': 96969, '1a': 33391}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 94452},
#   'pairs': [{'0q': 94452, '1a': 29967}, {'0q': 29967, '1a': 94452}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 70868},
#   'pairs': [{'0q': 70868, '1a': 29967}, {'0q': 29967, '1a': 70868}],
#   'npairs': 2},
#  {'_id': {'min': 70975, 'max': ''},
#   'pairs': [{'0q': '', '1a': 70975}, {'0q': 70975, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 48306},
#   'pairs': [{'0q': 29967, '1a': 48306}, {'0q': 48306, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 83, 'max': ''},
#   'pairs': [{'0q': '', '1a': 83}, {'0q': 83, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 3440, 'max': 6491},
#   'pairs': [{'0q': 3440, '1a': 6491}, {'0q': 6491, '1a': 3440}],
#   'npairs': 2},
#  {'_id': {'min': 301, 'max': ''},
#   'pairs': [{'0q': '', '1a': 301}, {'0q': 301, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 58622, 'max': 91758},
#   'pairs': [{'0q': 91758, '1a': 58622}, {'0q': 58622, '1a': 91758}],
#   'npairs': 2},
#  {'_id': {'min': 73, 'max': 6497},
#   'pairs': [{'0q': 6497, '1a': 73}, {'0q': 73, '1a': 6497}],
#   'npairs': 2},
#  {'_id': {'min': 34270, 'max': 46823},
#   'pairs': [{'0q': 46823, '1a': 34270}, {'0q': 34270, '1a': 46823}],
#   'npairs': 2},
#  {'_id': {'min': 72571, 'max': ''},
#   'pairs': [{'0q': 72571, '1a': ''}, {'0q': '', '1a': 72571}],
#   'npairs': 2},
#  {'_id': {'min': 70749, 'max': 81846},
#   'pairs': [{'0q': 70749, '1a': 81846}, {'0q': 81846, '1a': 70749}],
#   'npairs': 2},
#  {'_id': {'min': 2163, 'max': 2230},
#   'pairs': [{'0q': 2163, '1a': 2230}, {'0q': 2230, '1a': 2163}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 13938},
#   'pairs': [{'0q': 250, '1a': 13938}, {'0q': 13938, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 69440, 'max': 89811},
#   'pairs': [{'0q': 69440, '1a': 89811}, {'0q': 89811, '1a': 69440}],
#   'npairs': 2},
#  {'_id': {'min': 25459, 'max': ''},
#   'pairs': [{'0q': 25459, '1a': ''}, {'0q': '', '1a': 25459}],
#   'npairs': 2},
#  {'_id': {'min': 27297, 'max': 29967},
#   'pairs': [{'0q': 27297, '1a': 29967}, {'0q': 29967, '1a': 27297}],
#   'npairs': 2},
#  {'_id': {'min': 6564, 'max': ''},
#   'pairs': [{'0q': '', '1a': 6564}, {'0q': 6564, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 729},
#   'pairs': [{'0q': 100, '1a': 729}, {'0q': 729, '1a': 100}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 95},
#   'pairs': [{'0q': 95, '1a': 24}, {'0q': 24, '1a': 95}],
#   'npairs': 2},
#  {'_id': {'min': 10421, 'max': ''},
#   'pairs': [{'0q': 10421, '1a': ''}, {'0q': '', '1a': 10421}],
#   'npairs': 2},
#  {'_id': {'min': 69628, 'max': 100009},
#   'pairs': [{'0q': 100009, '1a': 69628}, {'0q': 69628, '1a': 100009}],
#   'npairs': 2},
#  {'_id': {'min': 48306, 'max': ''},
#   'pairs': [{'0q': '', '1a': 48306}, {'0q': 48306, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 19610},
#   'pairs': [{'0q': 24, '1a': 19610}, {'0q': 19610, '1a': 24}],
#   'npairs': 2},
#  {'_id': {'min': 31764, 'max': 69447},
#   'pairs': [{'0q': 31764, '1a': 69447}, {'0q': 69447, '1a': 31764}],
#   'npairs': 2},
#  {'_id': {'min': 87282, 'max': 212120},
#   'pairs': [{'0q': 87282, '1a': 212120}, {'0q': 212120, '1a': 87282}],
#   'npairs': 2},
#  {'_id': {'min': 100, 'max': 187},
#   'pairs': [{'0q': 100, '1a': 187}, {'0q': 187, '1a': 100}],
#   'npairs': 2},
#  {'_id': {'min': 55132, 'max': ''},
#   'pairs': [{'0q': 55132, '1a': ''}, {'0q': '', '1a': 55132}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 25},
#   'pairs': [{'0q': 24, '1a': 25}, {'0q': 25, '1a': 24}],
#   'npairs': 2},
#  {'_id': {'min': 729, 'max': 6095},
#   'pairs': [{'0q': 6095, '1a': 729}, {'0q': 729, '1a': 6095}],
#   'npairs': 2},
#  {'_id': {'min': 5808, 'max': 21775},
#   'pairs': [{'0q': 21775, '1a': 5808}, {'0q': 5808, '1a': 21775}],
#   'npairs': 2},
#  {'_id': {'min': 38304, 'max': ''},
#   'pairs': [{'0q': '', '1a': 38304}, {'0q': 38304, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 729},
#   'pairs': [{'0q': 729, '1a': 250}, {'0q': 250, '1a': 729}],
#   'npairs': 2},
#  {'_id': {'min': 342, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 342}, {'0q': 342, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 19610, 'max': ''},
#   'pairs': [{'0q': 19610, '1a': ''}, {'0q': '', '1a': 19610}],
#   'npairs': 2},
#  {'_id': {'min': 31764, 'max': 88852},
#   'pairs': [{'0q': 88852, '1a': 31764}, {'0q': 31764, '1a': 88852}],
#   'npairs': 2},
#  {'_id': {'min': 2509, 'max': ''},
#   'pairs': [{'0q': 2509, '1a': ''}, {'0q': '', '1a': 2509}],
#   'npairs': 2},
#  {'_id': {'min': 191045, 'max': 201156},
#   'pairs': [{'0q': 201156, '1a': 191045}, {'0q': 191045, '1a': 201156}],
#   'npairs': 2},
#  {'_id': {'min': 16597, 'max': 77879},
#   'pairs': [{'0q': 77879, '1a': 16597}, {'0q': 16597, '1a': 77879}],
#   'npairs': 2},
#  {'_id': {'min': 73, 'max': 250},
#   'pairs': [{'0q': 250, '1a': 73}, {'0q': 73, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 398, 'max': 2171},
#   'pairs': [{'0q': 398, '1a': 2171}, {'0q': 2171, '1a': 398}],
#   'npairs': 2},
#  {'_id': {'min': 30697, 'max': ''},
#   'pairs': [{'0q': 30697, '1a': ''}, {'0q': '', '1a': 30697}],
#   'npairs': 2},
#  {'_id': {'min': 24137, 'max': 38468},
#   'pairs': [{'0q': 38468, '1a': 24137}, {'0q': 24137, '1a': 38468}],
#   'npairs': 2},
#  {'_id': {'min': 25, 'max': 225},
#   'pairs': [{'0q': 225, '1a': 25}, {'0q': 25, '1a': 225}],
#   'npairs': 2},
#  {'_id': {'min': 30281, 'max': ''},
#   'pairs': [{'0q': 30281, '1a': ''}, {'0q': '', '1a': 30281}],
#   'npairs': 2},
#  {'_id': {'min': 43380, 'max': ''},
#   'pairs': [{'0q': '', '1a': 43380}, {'0q': 43380, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 2676, 'max': 29967},
#   'pairs': [{'0q': 2676, '1a': 29967}, {'0q': 29967, '1a': 2676}],
#   'npairs': 2},
#  {'_id': {'min': 26017, 'max': 84468},
#   'pairs': [{'0q': 26017, '1a': 84468}, {'0q': 84468, '1a': 26017}],
#   'npairs': 2},
#  {'_id': {'min': 31929, 'max': ''},
#   'pairs': [{'0q': 31929, '1a': ''}, {'0q': '', '1a': 31929}],
#   'npairs': 2},
#  {'_id': {'min': 2230, 'max': 22112},
#   'pairs': [{'0q': 2230, '1a': 22112}, {'0q': 22112, '1a': 2230}],
#   'npairs': 2},
#  {'_id': {'min': 95, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 95}, {'0q': 95, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 13938, 'max': 19919},
#   'pairs': [{'0q': 13938, '1a': 19919}, {'0q': 19919, '1a': 13938}],
#   'npairs': 2},
#  {'_id': {'min': 27297, 'max': ''},
#   'pairs': [{'0q': '', '1a': 27297}, {'0q': 27297, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 142239},
#   'pairs': [{'0q': 29967, '1a': 142239}, {'0q': 142239, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 37713, 'max': ''},
#   'pairs': [{'0q': '', '1a': 37713}, {'0q': 37713, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 29967, 'max': 81846},
#   'pairs': [{'0q': 29967, '1a': 81846}, {'0q': 81846, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 2004, 'max': 2747},
#   'pairs': [{'0q': 2747, '1a': 2004}, {'0q': 2004, '1a': 2747}],
#   'npairs': 2},
#  {'_id': {'min': 342, 'max': 112975},
#   'pairs': [{'0q': 342, '1a': 112975}, {'0q': 112975, '1a': 342}],
#   'npairs': 2},
#  {'_id': {'min': 85078, 'max': ''},
#   'pairs': [{'0q': 85078, '1a': ''}, {'0q': '', '1a': 85078}],
#   'npairs': 2},
#  {'_id': {'min': 22112, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 22112}, {'0q': 22112, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 73416, 'max': ''},
#   'pairs': [{'0q': '', '1a': 73416}, {'0q': 73416, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 13883, 'max': 14699},
#   'pairs': [{'0q': 13883, '1a': 14699}, {'0q': 14699, '1a': 13883}],
#   'npairs': 2},
#  {'_id': {'min': 85934, 'max': ''},
#   'pairs': [{'0q': '', '1a': 85934}, {'0q': 85934, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 78, 'max': ''},
#   'pairs': [{'0q': 78, '1a': ''}, {'0q': '', '1a': 78}],
#   'npairs': 2},
#  {'_id': {'min': 104026, 'max': ''},
#   'pairs': [{'0q': '', '1a': 104026}, {'0q': 104026, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 42107, 'max': 130407},
#   'pairs': [{'0q': 130407, '1a': 42107}, {'0q': 42107, '1a': 130407}],
#   'npairs': 2},
#  {'_id': {'min': 6974, 'max': 29967},
#   'pairs': [{'0q': 6974, '1a': 29967}, {'0q': 29967, '1a': 6974}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 19610},
#   'pairs': [{'0q': 250, '1a': 19610}, {'0q': 19610, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 50452, 'max': ''},
#   'pairs': [{'0q': '', '1a': 50452}, {'0q': 50452, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 83, 'max': 100},
#   'pairs': [{'0q': 83, '1a': 100}, {'0q': 100, '1a': 83}],
#   'npairs': 2},
#  {'_id': {'min': 6491, 'max': 29967},
#   'pairs': [{'0q': 6491, '1a': 29967}, {'0q': 29967, '1a': 6491}],
#   'npairs': 2},
#  {'_id': {'min': 16349, 'max': 29967},
#   'pairs': [{'0q': 16349, '1a': 29967}, {'0q': 29967, '1a': 16349}],
#   'npairs': 2},
#  {'_id': {'min': 3275, 'max': ''},
#   'pairs': [{'0q': '', '1a': 3275}, {'0q': 3275, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 2230, 'max': 4684},
#   'pairs': [{'0q': 2230, '1a': 4684}, {'0q': 4684, '1a': 2230}],
#   'npairs': 2},
#  {'_id': {'min': 110030, 'max': ''},
#   'pairs': [{'0q': 110030, '1a': ''}, {'0q': '', '1a': 110030}],
#   'npairs': 2},
#  {'_id': {'min': 535, 'max': 2230},
#   'pairs': [{'0q': 535, '1a': 2230}, {'0q': 2230, '1a': 535}],
#   'npairs': 2},
#  {'_id': {'min': 25360, 'max': 54923},
#   'pairs': [{'0q': 54923, '1a': 25360}, {'0q': 25360, '1a': 54923}],
#   'npairs': 2},
#  {'_id': {'min': 13273, 'max': ''},
#   'pairs': [{'0q': '', '1a': 13273}, {'0q': 13273, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 48559, 'max': ''},
#   'pairs': [{'0q': '', '1a': 48559}, {'0q': 48559, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 30426, 'max': ''},
#   'pairs': [{'0q': 30426, '1a': ''}, {'0q': '', '1a': 30426}],
#   'npairs': 2},
#  {'_id': {'min': 86010, 'max': ''},
#   'pairs': [{'0q': 86010, '1a': ''}, {'0q': '', '1a': 86010}],
#   'npairs': 2},
#  {'_id': {'min': 2676, 'max': ''},
#   'pairs': [{'0q': 2676, '1a': ''}, {'0q': '', '1a': 2676}],
#   'npairs': 2},
#  {'_id': {'min': 95, 'max': 131982},
#   'pairs': [{'0q': 131982, '1a': 95}, {'0q': 95, '1a': 131982}],
#   'npairs': 2},
#  {'_id': {'min': 9897, 'max': ''},
#   'pairs': [{'0q': 9897, '1a': ''}, {'0q': '', '1a': 9897}],
#   'npairs': 2},
#  {'_id': {'min': 9874, 'max': 19919},
#   'pairs': [{'0q': 19919, '1a': 9874}, {'0q': 9874, '1a': 19919}],
#   'npairs': 2},
#  {'_id': {'min': 119615, 'max': 131662},
#   'pairs': [{'0q': 119615, '1a': 131662}, {'0q': 131662, '1a': 119615}],
#   'npairs': 2},
#  {'_id': {'min': 279872, 'max': ''},
#   'pairs': [{'0q': 279872, '1a': ''}, {'0q': '', '1a': 279872}],
#   'npairs': 2},
#  {'_id': {'min': 16349, 'max': ''},
#   'pairs': [{'0q': 16349, '1a': ''}, {'0q': '', '1a': 16349}],
#   'npairs': 2},
#  {'_id': {'min': 16597, 'max': 128299},
#   'pairs': [{'0q': 128299, '1a': 16597}, {'0q': 16597, '1a': 128299}],
#   'npairs': 2},
#  {'_id': {'min': 120501, 'max': 129981},
#   'pairs': [{'0q': 129981, '1a': 120501}, {'0q': 120501, '1a': 129981}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 2429},
#   'pairs': [{'0q': 250, '1a': 2429}, {'0q': 2429, '1a': 250}],
#   'npairs': 2},
#  {'_id': {'min': 301, 'max': 2230},
#   'pairs': [{'0q': 2230, '1a': 301}, {'0q': 301, '1a': 2230}],
#   'npairs': 2},
#  {'_id': {'min': 106915, 'max': ''},
#   'pairs': [{'0q': 106915, '1a': ''}, {'0q': '', '1a': 106915}],
#   'npairs': 2},
#  {'_id': {'min': 22851, 'max': 28035},
#   'pairs': [{'0q': 22851, '1a': 28035}, {'0q': 28035, '1a': 22851}],
#   'npairs': 2},
#  {'_id': {'min': 25243, 'max': ''},
#   'pairs': [{'0q': '', '1a': 25243}, {'0q': 25243, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 127, 'max': 29967},
#   'pairs': [{'0q': 127, '1a': 29967}, {'0q': 29967, '1a': 127}],
#   'npairs': 2},
#  {'_id': {'min': 22429, 'max': ''},
#   'pairs': [{'0q': '', '1a': 22429}, {'0q': 22429, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 17864, 'max': ''},
#   'pairs': [{'0q': 17864, '1a': ''}, {'0q': '', '1a': 17864}],
#   'npairs': 2},
#  {'_id': {'min': 19919, 'max': ''},
#   'pairs': [{'0q': '', '1a': 19919}, {'0q': 19919, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 24225, 'max': 34527},
#   'pairs': [{'0q': 24225, '1a': 34527}, {'0q': 34527, '1a': 24225}],
#   'npairs': 2},
#  {'_id': {'min': 83, 'max': 224441},
#   'pairs': [{'0q': 224441, '1a': 83}, {'0q': 83, '1a': 224441}],
#   'npairs': 2},
#  {'_id': {'min': 4676, 'max': ''},
#   'pairs': [{'0q': 4676, '1a': ''}, {'0q': '', '1a': 4676}],
#   'npairs': 2},
#  {'_id': {'min': 28050, 'max': 30751},
#   'pairs': [{'0q': 28050, '1a': 30751}, {'0q': 30751, '1a': 28050}],
#   'npairs': 2},
#  {'_id': {'min': 250, 'max': 29967},
#   'pairs': [{'0q': 29967, '1a': 250}, {'0q': 250, '1a': 29967}],
#   'npairs': 2},
#  {'_id': {'min': 13735, 'max': 14088},
#   'pairs': [{'0q': 13735, '1a': 14088}, {'0q': 14088, '1a': 13735}],
#   'npairs': 2},
#  {'_id': {'min': 9885, 'max': ''},
#   'pairs': [{'0q': '', '1a': 9885}, {'0q': 9885, '1a': ''}],
#   'npairs': 2},
#  {'_id': {'min': 74698, 'max': 76420},
#   'pairs': [{'0q': 76420, '1a': 74698}, {'0q': 74698, '1a': 76420}],
#   'npairs': 2},
#  {'_id': {'min': 10531, 'max': 29967},
#   'pairs': [{'0q': 10531, '1a': 29967}, {'0q': 29967, '1a': 10531}],
#   'npairs': 2},
#  {'_id': {'min': 98940, 'max': ''},
#   'pairs': [{'0q': 98940, '1a': ''}, {'0q': '', '1a': 98940}],
#   'npairs': 2},
#  {'_id': {'min': 6491, 'max': 34430},
#   'pairs': [{'0q': 6491, '1a': 34430}, {'0q': 34430, '1a': 6491}],
#   'npairs': 2},
#  {'_id': {'min': 73, 'max': 9897},
#   'pairs': [{'0q': 73, '1a': 9897}, {'0q': 9897, '1a': 73}],
#   'npairs': 2},
#  {'_id': {'min': 7123, 'max': 31764},
#   'pairs': [{'0q': 31764, '1a': 7123}, {'0q': 7123, '1a': 31764}],
#   'npairs': 2},
#  {'_id': {'min': 27881, 'max': ''},
#   'pairs': [{'0q': 27881, '1a': ''}, {'0q': '', '1a': 27881}],
#   'npairs': 2},
#  {'_id': {'min': 2832, 'max': 6497},
#   'pairs': [{'0q': 2832, '1a': 6497}, {'0q': 6497, '1a': 2832}],
#   'npairs': 2},
#  {'_id': {'min': 463, 'max': 2742},
#   'pairs': [{'0q': 463, '1a': 2742}, {'0q': 2742, '1a': 463}],
#   'npairs': 2},
#  {'_id': {'min': 38304, 'max': 49326},
#   'pairs': [{'0q': 49326, '1a': 38304}, {'0q': 38304, '1a': 49326}],
#   'npairs': 2},
#  {'_id': {'min': 69447, 'max': 77052},
#   'pairs': [{'0q': 69447, '1a': 77052}, {'0q': 77052, '1a': 69447}],
#   'npairs': 2},
#  {'_id': {'min': 45793, 'max': ''},
#   'pairs': [{'0q': '', '1a': 45793}, {'0q': 45793, '1a': ''}],
#   'npairs': 2}]

# %% [markdown]
# En el caso de que queramos tener como referencia las preguntas y respuestas a las que se refiere la conversación, se puede añadir un campo más que guarde todas las preguntas junto con sus respuestas consideradas:

# %%
RQ4: CommandCursor[dict[str,Any]] = db.posts.aggregate( [
        { '$match': { 'PostTypeId' : 2}},
        { '$lookup': {
            'from': "posts",
            'localField': "ParentId",
            'foreignField': "Id",
            'as': "question"
          }
        },

        { '$unwind' : '$question' },

        { '$project' : {
            'OwnerUserId': True,
            'QId' : '$question.Id',
            'AId' : '$Id',
            'OP' : '$question.OwnerUserId'
          }
        },
        { '$group' : {'_id' : {'min' : { '$min' : ['$OwnerUserId' , '$OP'] },
                               'max' : { '$max' : ['$OwnerUserId' , '$OP'] }},
                      'pairs' : {'$addToSet' : { '0q':'$OP', '1a': '$OwnerUserId'}},
                      'considered_pairs' : { '$push' : {'QId' : '$QId', 'AId' : '$AId'}}
          }
        },
        { '$project': {
            'pairs' : True,
            'npairs' : { '$size' : '$pairs'},
            'considered_pairs' : True
          }
        },
        { '$match' : { 'npairs' : { '$eq' : 2}} }
    ])
RQ4 = list(RQ4)
RQ4
# Out:
# [{'_id': {'min': 21, 'max': 1184},
#   'pairs': [{'0q': 21, '1a': 1184}, {'0q': 1184, '1a': 21}],
#   'considered_pairs': [{'QId': 2615, 'AId': 2619},
#    {'QId': 36, 'AId': 47441},
#    {'QId': 4630, 'AId': 446773}],
#   'npairs': 2},
#  {'_id': {'min': 22, 'max': 288},
#   'pairs': [{'0q': 22, '1a': 288}, {'0q': 288, '1a': 22}],
#   'considered_pairs': [{'QId': 565, 'AId': 604}, {'QId': 731, 'AId': 734}],
#   'npairs': 2},
#  {'_id': {'min': 22, 'max': 342},
#   'pairs': [{'0q': 22, '1a': 342}, {'0q': 342, '1a': 22}],
#   'considered_pairs': [{'QId': 618, 'AId': 623}, {'QId': 552, 'AId': 832}],
#   'npairs': 2},
#  {'_id': {'min': 22, 'max': 729},
#   'pairs': [{'0q': 729, '1a': 22}, {'0q': 22, '1a': 729}],
#   'considered_pairs': [{'QId': 2454, 'AId': 2459}, {'QId': 1919, 'AId': 2734}],
#   'npairs': 2},
#  {'_id': {'min': 23, 'max': 25},
#   'pairs': [{'0q': 23, '1a': 25}, {'0q': 25, '1a': 23}],
#   'considered_pairs': [{'QId': 48, 'AId': 52},
#    {'QId': 803, 'AId': 805},
#    {'QId': 1015, 'AId': 1095}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 25},
#   'pairs': [{'0q': 25, '1a': 24}, {'0q': 24, '1a': 25}],
#   'considered_pairs': [{'QId': 5, 'AId': 7},
#    {'QId': 29, 'AId': 30},
#    {'QId': 540, 'AId': 543},
#    {'QId': 803, 'AId': 809}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 95},
#   'pairs': [{'0q': 24, '1a': 95}, {'0q': 95, '1a': 24}],
#   'considered_pairs': [{'QId': 5, 'AId': 88},
#    {'QId': 2544, 'AId': 3326},
#    {'QId': 3514, 'AId': 3516}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 301},
#   'pairs': [{'0q': 24, '1a': 301}, {'0q': 301, '1a': 24}],
#   'considered_pairs': [{'QId': 3066, 'AId': 3068},
#    {'QId': 69740, 'AId': 69748}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 463},
#   'pairs': [{'0q': 463, '1a': 24}, {'0q': 24, '1a': 463}],
#   'considered_pairs': [{'QId': 5, 'AId': 208},
#    {'QId': 540, 'AId': 555},
#    {'QId': 6, 'AId': 654},
#    {'QId': 782, 'AId': 783},
#    {'QId': 818, 'AId': 819},
#    {'QId': 67346, 'AId': 67376},
#    {'QId': 80658, 'AId': 80686}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 2230},
#   'pairs': [{'0q': 24, '1a': 2230}, {'0q': 2230, '1a': 24}],
#   'considered_pairs': [{'QId': 2504, 'AId': 2510},
#    {'QId': 2640, 'AId': 2642},
#    {'QId': 2677, 'AId': 2680},
#    {'QId': 2825, 'AId': 2828},
#    {'QId': 3145, 'AId': 3163},
#    {'QId': 3331, 'AId': 3339}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max': 19610},
#   'pairs': [{'0q': 24, '1a': 19610}, {'0q': 19610, '1a': 24}],
#   'considered_pairs': [{'QId': 56542, 'AId': 56688},
#    {'QId': 57644, 'AId': 57648}],
#   'npairs': 2},
#  {'_id': {'min': 24, 'max':
#   'npairs': 2},
#  {'_id': {'min': 10421, 'max': ''},
#   'pairs': [{'0q': 10421, '1a': ''}, {'0q': '', '1a': 10421}],
#   'considered_pairs': [{'QId': 114753, 'AId': 114787},
#    {'QId': 234988, 'AId': 234991}],
#   'npairs': 2},
#  {'_id': {'min': 10531, 'max': 29967},
#   'pairs': [{'0q': 10531, '1a': 29967}, {'0q': 29967, '1a': 10531}],
#   'considered_pairs': [{'QId': 80924, 'AId': 80986},
#    {'QId': 218063, 'AId': 218069}],
#   'npairs': 2},
#  {'_id': {'min': 10576, 'max': 29967},
#   'pairs': [{'0q': 10576, '1a': 29967}, {'0q': 29967, '1a': 10576}],
#   'considered_pairs': [{'QId': 53779, 'AId': 56082},
#    {'QId': 92944, 'AId': 93234},
#    {'QId': 114051, 'AId': 114105},
#    {'QId': 131550, 'AId': 131580},
#    {'QId': 442116, 'AId': 442384}],
#   'npairs': 2},
#  {'_id': {'min': 10576, 'max': ''},
#   'pairs': [{'0q': 10576, '1a': ''}, {'0q': '', '1a': 10576}],
#   'considered_pairs': [{'QId': 33376, 'AId': 40925},
#    {'QId': 26853, 'AId': 83901},
#    {'QId': 120132, 'AId': 120141},
# ...
#   'pairs': [{'0q': 78696, '1a': ''}, {'0q': '', '1a': 78696}],
#   'considered_pairs': [{'QId': 160478, 'AId': 160480},
#    {'QId': 227286, 'AId': 227290}],
#   'npairs': 2},
#  {'_id': {'min': 80614, 'max': ''},
#   'pairs': [{'0q': 80614, '1a': ''}, {'0q': '', '1a': 80614}],
#   'considered_pairs': [{'QId': 155269, 'AId': 155287},
#    {'QId': 176854, 'AId': 176862}],
#   'npairs': 2},
#  {'_id': {'min': 81074, 'max': 84943},
#   'pairs': [{'0q': 84943, '1a': 81074}, {'0q': 81074, '1a': 84943}],
#   'considered_pairs': [{'QId': 175057, 'AId': 175063},
#    {'QId': 175613, 'AId': 175617}],
#   'npairs': 2},
#  {'_id': {'min': 81074, 'max': ''},
#   'pairs': [{'0q': '', '1a': 81074}, {'0q': 81074, '1a': ''}],
#   'considered_pairs': [{'QId': 150242, 'AId': 150301},
#    {'QId': 177150, 'AId': 177155},
#    {'QId': 184991, 'AId': 185028},
#    {'QId': 186706, 'AId': 186711},
#    {'QId': 190358, 'AId': 190370},
#    {'QId': 191323, 'AId': 191328},
#    {'QId': 192027, 'AId': 192030},
#    {'QId': 195203, 'AId': 195208},
#    {'QId': 197009, 'AId': 197011},
#    {'QId': 197438, 'AId': 197458},
#    {'QId': 216792, 'AId': 216794}],
#   'npairs': 2},
#  {'_id': {'min': 83304, 'max': ''},
#   'pairs': [{'0q': 83304, '1a': ''}, {'0q': '', '1a': 83304}],
#   'considered_pairs': [{'QId': 217509, 'AId': 217585},
#    {'QId': 219313, 'AId': 219325},
#    {'QId': 363982, 'AId': 364208}],
#   'npairs': 2},
#  {'_id': {'min': 84466, 'max': ''},
#   'pairs': [{'0q': '', '1a': 84466}, {'0q': 84466, '1a': ''}],
#   'considered_pairs': [{'QId': 300572, 'AId': 300629},
#    {'QId': 375342, 'AId': 375361}],
#   'npairs': 2},
#  {'_id': {'min': 84738, 'max': ''},
#   'pairs': [{'0q': '', '1a': 84738}, {'0q': 84738, '1a': ''}],
#   'considered_pairs': [{'QId': 160430, 'AId': 160432},
#    {'QId': 160556, 'AId': 160565},
#    {'QId': 254893, 'AId': 254898},
#    {'QId': 255067, 'AId': 255075},
#    {'QId': 255556, 'AId': 255557},
#    {'QId': 316115, 'AId': 316119},
#    {'QId': 355671, 'AId': 355680}],
#   'npairs': 2},
#  {'_id': {'min': 85031, 'max': 96564},
#   'pairs': [{'0q': 85031, '1a': 96564}, {'0q': 96564, '1a': 85031}],
#   'considered_pairs': [{'QId': 188001, 'AId': 188014},
#    {'QId': 188077, 'AId': 188079}],
#   'npairs': 2},
#  {'_id': {'min': 85078, 'max': ''},
#   'pairs': [{'0q': '', '1a': 85078}, {'0q': 85078, '1a': ''}],
#   'considered_pairs': [{'QId': 160134, 'AId': 160178},
#    {'QId': 190734, 'AId': 190875}],
#   'npairs': 2},
#  {'_id': {'min': 85496, 'max': 248814},
#   'pairs': [{'0q': 85496, '1a': 248814}, {'0q': 248814, '1a': 85496}],
#   'considered_pairs': [{'QId': 493342, 'AId': 493533},
#    {'QId': 560205, 'AId': 561011}],
#   'npairs': 2},
#  {'_id': {'min': 85934, 'max': ''},
#   'pairs': [{'0q': 85934, '1a': ''}, {'0q': '', '1a': 85934}],
#   'considered_pairs': [{'QId': 168155, 'AId': 168157},
#    {'QId': 390612, 'AId': 441866}],
#   'npairs': 2},
#  {'_id': {'min': 86010, 'max': ''},
#   'pairs': [{'0q': 86010, '1a': ''}, {'0q': '', '1a': 86010}],
#   'considered_pairs': [{'QId': 189747, 'AId': 189750},
#    {'QId': 189924, 'AId': 189927},
#    {'QId': 191530, 'AId': 191567}],
#   'npairs': 2},
#  {'_id': {'min': 87233, 'max': 209421},
#   'pairs': [{'0q': 209421, '1a': 87233}, {'0q': 87233, '1a': 209421}],
#   'considered_pairs': [{'QId': 558821, 'AId': 558828},
#    {'QId': 558829, 'AId': 558858}],
#   'npairs': 2},
#  {'_id': {'min': 87282, 'max': 212120},
#   'pairs': [{'0q': 212120, '1a': 87282}, {'0q': 87282, '1a': 212120}],
#   'considered_pairs': [{'QId': 438203, 'AId': 438209},
#    {'QId': 437386, 'AId': 438480}],
#   'npairs': 2},
#  {'_id': {'min': 89811, 'max': 93721},
#   'pairs': [{'0q': 93721, '1a': 89811}, {'0q': 89811, '1a': 93721}],
#   'considered_pairs': [{'QId': 186237, 'AId': 186616},
#    {'QId': 233936, 'AId': 237275}],
#   'npairs': 2},
#  {'_id': {'min': 91499, 'max': 180509},
#   'pairs': [{'0q': 91499, '1a': 180509}, {'0q': 180509, '1a': 91499}],
#   'considered_pairs': [{'QId': 400123, 'AId': 402203},
#    {'QId': 411593, 'AId': 448501}],
#   'npairs': 2},
#  {'_id': {'min': 95341, 'max': 96682},
#   'pairs': [{'0q': 96682, '1a': 95341}, {'0q': 95341, '1a': 96682}],
#    {'QId': 503219, 'AId': 503247}],
#   'npairs': 2},
#  {'_id': {'min': 121157, 'max': ''},
#   'pairs': [{'0q': '', '1a': 121157}, {'0q': 121157, '1a': ''}],
#   'considered_pairs': [{'QId': 246527, 'AId': 247416},
#    {'QId': 332758, 'AId': 334949},
#    {'QId': 405296, 'AId': 405330},
#    {'QId': 486440, 'AId': 487128},
#    {'QId': 491397, 'AId': 491430},
#    {'QId': 501152, 'AId': 501185},
#    {'QId': 540389, 'AId': 540421},
#    {'QId': 553470, 'AId': 553525},
#    {'QId': 555775, 'AId': 555803},
#    {'QId': 565872, 'AId': 566777}],
#   'npairs': 2},
#  {'_id': {'min': 122597, 'max': ''},
#   'pairs': [{'0q': 122597, '1a': ''}, {'0q': '', '1a': 122597}],
#   'considered_pairs': [{'QId': 275663, 'AId': 275711},
#    {'QId': 288018, 'AId': 288051}],
#   'npairs': 2},
#  {'_id': {'min': 124687, 'max': ''},
#   'pairs': [{'0q': 124687, '1a': ''}, {'0q': '', '1a': 124687}],
#   'considered_pairs': [{'QId': 254905, 'AId': 254911},
#    {'QId': 316685, 'AId': 316708}],
#   'npairs': 2},
#  {'_id': {'min': 127500, 'max': ''},
#   'pairs': [{'0q': 127500, '1a': ''}, {'0q': '', '1a': 127500}],
#   'considered_pairs': [{'QId': 261380, 'AId': 263957},
#    {'QId': 385878, 'AId': 385880}],
#   'npairs': 2},
#  {'_id': {'min': 131662, 'max': ''},
#   'pairs': [{'0q': 131662, '1a': ''}, {'0q': '', '1a': 131662}],
#   'considered_pairs': [{'QId': 403517, 'AId': 403522},
#    {'QId': 405886, 'AId': 405904},
#    {'QId': 462747, 'AId': 462790},
#    {'QId': 495012, 'AId': 495023},
#    {'QId': 502555, 'AId': 502559}],
#   'npairs': 2},
#  {'_id': {'min': 131982, 'max': 178543},
#   'pairs': [{'0q': 131982, '1a': 178543}, {'0q': 178543, '1a': 131982}],
#   'considered_pairs': [{'QId': 391512, 'AId': 391526},
#    {'QId': 505549, 'AId': 505645}],
#   'npairs': 2},
#  {'_id': {'min': 131982, 'max': ''},
#   'pairs': [{'0q': 131982, '1a': ''}, {'0q': '', '1a': 131982}],
#   'considered_pairs': [{'QId': 383443, 'AId': 383446},
#    {'QId': 389418, 'AId': 389425},
#    {'QId': 520727, 'AId': 522841}],
#   'npairs': 2},
#  {'_id': {'min': 141893, 'max': ''},
#   'pairs': [{'0q': '', '1a': 141893}, {'0q': 141893, '1a': ''}],
#   'considered_pairs': [{'QId': 295528, 'AId': 295538},
#    {'QId': 308547, 'AId': 567401},
#    {'QId': 568387, 'AId': 568389}],
#   'npairs': 2},
#  {'_id': {'min': 142367, 'max': 143364},
#   'pairs': [{'0q': 142367, '1a': 143364}, {'0q': 143364, '1a': 142367}],
#   'considered_pairs': [{'QId': 305813, 'AId': 305822},
#    {'QId': 312644, 'AId': 312645}],
#   'npairs': 2},
#  {'_id': {'min': 143803, 'max': ''},
#   'pairs': [{'0q': 143803, '1a': ''}, {'0q': '', '1a': 143803}],
#  {'_id': {'min': 199780, 'max': ''},
#   'pairs': [{'0q': '', '1a': 199780}, {'0q': 199780, '1a': ''}],
#   'considered_pairs': [{'QId': 495728, 'AId': 495735},
#    {'QId': 553546, 'AId': 553549}],
#   'npairs': 2},
#  {'_id': {'min': 202972, 'max': ''},
#   'pairs': [{'0q': '', '1a': 202972}, {'0q': 202972, '1a': ''}],
#   'considered_pairs': [{'QId': 409891, 'AId': 409896},
#    {'QId': 414851, 'AId': 414871},
#    {'QId': 415471, 'AId': 415483}],
#   'npairs': 2},
#  {'_id': {'min': 205526, 'max': ''},
#   'pairs': [{'0q': 205526, '1a': ''}, {'0q': '', '1a': 205526}],
#   'considered_pairs': [{'QId': 470036, 'AId': 470042},
#    {'QId': 488036, 'AId': 488064},
#    {'QId': 493578, 'AId': 493583}],
#   'npairs': 2},
#  {'_id': {'min': 225338, 'max': ''},
#   'pairs': [{'0q': 225338, '1a': ''}, {'0q': '', '1a': 225338}],
#   'considered_pairs': [{'QId': 452873, 'AId': 452915},
#    {'QId': 455531, 'AId': 455542},
#    {'QId': 466865, 'AId': 466868},
#    {'QId': 467175, 'AId': 467184}],
#   'npairs': 2},
#  {'_id': {'min': 228290, 'max': ''},
#   'pairs': [{'0q': '', '1a': 228290}, {'0q': 228290, '1a': ''}],
#   'considered_pairs': [{'QId': 455531, 'AId': 455547},
#    {'QId': 476001, 'AId': 476019}],
#   'npairs': 2},
#  {'_id': {'min': 252576, 'max': ''},
#   'pairs': [{'0q': 252576, '1a': ''}, {'0q': '', '1a': 252576}],
#   'considered_pairs': [{'QId': 557957, 'AId': 557970},
#    {'QId': 561265, 'AId': 561269}],
#   'npairs': 2},
#  {'_id': {'min': 260743, 'max': 305409},
#   'pairs': [{'0q': 260743, '1a': 305409}, {'0q': 305409, '1a': 260743}],
#   'considered_pairs': [{'QId': 531136, 'AId': 560725},
#    {'QId': 560728, 'AId': 560729},
#    {'QId': 570650, 'AId': 570740},
#    {'QId': 607702, 'AId': 608300}],
#   'npairs': 2},
#  {'_id': {'min': 279872, 'max': ''},
#   'pairs': [{'0q': 279872, '1a': ''}, {'0q': '', '1a': 279872}],
#   'considered_pairs': [{'QId': 542440, 'AId': 542992},
#    {'QId': 552740, 'AId': 552744}],
#   'npairs': 2}]

# %% [markdown]
# Comprobemos ahora cuatro entradas que están relacionadas dos a dos.

# %%
(db.posts.find_one({'Id': 238}), db.posts.find_one({'Id': 243}),
db.posts.find_one({'Id': 222}), db.posts.find_one({'Id': 223}))
# Out:
# ({'_id': ObjectId('67c9773d3e772cc77527f72c'),
#   'Id': 238,
#   'AcceptedAnswerId': 243,
#   'AnswerCount': 1,
#   'Body': "<p>Estoy observando un mensaje de alerta (no es un error) <code>InsecurePlatformWarning</code> al ejecutar el comando <code>pip</code> en Linux:</p><br/><br/><pre><code>$ pip search reportlab<br/>/usr/local/lib/python2.7/dist-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:90:<br/>         InsecurePlatformWarning: A true SSLContext object is not available.<br/>         This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail.<br/>         For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.<br/>  InsecurePlatformWarning<br/>reportlab           - The ReportLab Toolkit<br/></code></pre><br/><br/><p>Tengo instalada la última versión de <code>pip</code>:</p><br/><br/><pre><code>$ pip show pip<br/>---<br/>Metadata-Version: 2.0<br/>Name: pip<br/>Version: 7.1.2<br/>Summary: The PyPA recommended tool for installing Python packages.<br/>Home-page: https://pip.pypa.io/<br/>Author: The pip developers<br/>Author-email: python-virtualenv@groups.google.com<br/>License: MIT<br/>Location: /usr/local/lib/python2.7/dist-packages<br/>Requires: <br/></code></pre><br/><br/><p>Estoy usando Python 2.7.6.</p><br/><br/><p>En versiones anteriores no me mostraba este mensaje. Entiendo que me está indicando que mi plataforma es insegura, ¿cómo o qué tengo que instalar para evitar recibir esta alerta?</p><br/><br/><p><strong>Actualización:</strong></p><br/><br/><p>Ya tengo instalada la última versión de PyOpenSSL:</p><br/><br/><pre><code>$ pip show pyOpenSSL<br/>---<br/>Metadata-Version: 1.0<br/>Name: pyOpenSSL<br/>Version: 0.13<br/>Summary: Python wrapper module around the OpenSSL library<br/>Home-page: http://pyopenssl.sourceforge.net/<br/>Author: Jean-Paul Calderone<br/>Author-email: exarkun@twistedmatrix.com<br/>License: APL2<br/>Location: /usr/lib/python2.7/dist-packages<br/>Requires: <br/></code></pre><br/><br/><p>Si intento instalar <code>request[security]</code> me da el siguiente mensaje:</p><br/><br/><pre><code>$ pip install 'request[security]'<br/>requests 2.2.1 does not provide the extra 'security'<br/></code></pre><br/>",
#   'ClosedDate': None,
#   'CommentCount': 7,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 14, 39, 34, 293000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 15, 22, 56, 327000),
#   'LastEditDate': datetime.datetime(2015, 12, 2, 15, 22, 56, 327000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 83,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 100,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 7,
#   'Tags': '<python><linux><pip><ubuntu><python-2.7>',
#   'Title': 'InsecurePlatformWarning al usar pip en Ubuntu',
#   'ViewCount': 344},
#  {'_id': ObjectId('67c9773d3e772cc77527f731'),
#   'Id': 243,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p><sub>Respondo tras consultar la <a href="https://stackoverflow.com/a/29202163/1983854">respuesta equivalente en inglés</a> y "debugar" en los comentarios</sub></p><br/><br/><p>Simplemente debes instalar los paquetes de seguridad:</p><br/><br/><pre><code>pip install requests[security]<br/></code></pre><br/><br/><p>o instalarlos directamente:</p><br/><br/><pre><code>pip install pyopenssl ndg-httpsclient pyasn1<br/></code></pre><br/><br/><p>Si en Ubuntu tienes problemas instalando <code>pyopenssl</code>, deberás instalar también las siguientes dependencias:</p><br/><br/><pre><code>apt-get install libffi-dev libssl-dev<br/></code></pre><br/>',
#   'ClosedDate': None,
#   'CommentCount': 1,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 15, 0, 4, 50000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 15, 7, 13, 380000),
#   'LastEditDate': datetime.datetime(2017, 5, 23, 12, 39, 21, 413000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': -1,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 83,
#   'ParentId': 238,
#   'PostTypeId': 2,
#   'Score': 4,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': ''},
#  {'_id': ObjectId('67c9773d3e772cc77527f71d'),
#   'Id': 222,
#   'AcceptedAnswerId': 223,
#   'AnswerCount': 1,
#   'Body': '<p>Hasta hace poco utilizaba Bash. Allí, puedes eliminar todo el contenido de la línea desde donde está el cursor hasta el principo de la línea apretando <kbd>Ctrl</kbd> + <kbd>U</kbd>.</p><br/><br/><pre><code>$ hola que tal estas<br/>          ^<br/>$ tal estas            # Ctrl+U<br/>  ^<br/></code></pre><br/><br/><p>Y así lo indica el manual de Bash en <a href="https://www.gnu.org/software/bash/manual/html_node/Commands-For-Killing.html" rel="noreferrer">8.4.4 Killing And Yanking</a>:</p><br/><br/><blockquote><br/>  <p><strong>unix-line-discard (C-u)</strong></p><br/>  <br/>  <p>Kill backward from the cursor to the beginning of the current line.</p><br/></blockquote><br/><br/><p>Sin embargo, ahora uso <code>zsh</code> (<a href="http://ohmyz.sh/" rel="noreferrer">Oh My Zsh</a> en concreto) y esta funcionalidad ha desaparecido. Ahora cuando pulso <kbd>Ctrl</kbd> + <kbd>U</kbd> se elimina la línea entera. Si hago <kbd>Ctrl</kbd> + <kbd>W</kbd> se eliminan palabras de la siguiente forma:</p><br/><br/><pre><code> $ hola que_tal estas<br/>               ^<br/> $ hola que_ estas        # Ctrl+U<br/>            ^<br/> $ hola  estas            # Ctrl+U<br/>        ^<br/></code></pre><br/><br/><p>¿Alguien sabe qué debo configurar para que Ctrl+U vuelva a eliminar todo desde el cursor hasta el principo de la línea?</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 5,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 12, 5, 19, 570000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2015, 12, 7, 12, 53, 32, 643000),
#   'LastEditDate': None,
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': '',
#   'OwnerDisplayName': '',
#   'OwnerUserId': 83,
#   'ParentId': '',
#   'PostTypeId': 1,
#   'Score': 8,
#   'Tags': '<bash><zsh>',
#   'Title': '¿Cómo eliminar el contenido de la consola desde el cursor hasta el principio?',
#   'ViewCount': 178},
#  {'_id': ObjectId('67c9773d3e772cc77527f71e'),
#   'Id': 223,
#   'AcceptedAnswerId': '',
#   'AnswerCount': '',
#   'Body': '<p>Al parecer <kbd>Ctrl</kbd>+<kbd>U</kbd> en zsh cumpla la función <code>kill-whole-line</code> por defecto, lo que necesitas es que haga un <code>backward-kill-line</code>, intenta agregando esto a tu <code>.zshrc</code>:</p><br/><br/><pre><code>bindkey \\^U backward-kill-line<br/></code></pre><br/><br/><p>Cabe mencionar que la lista de comandos (o widgets) la puedes encontrar en el manpage de <code>zshzle</code> en la sección <em>STANDARD WIDGETS</em></p><br/><br/><p>Para mayor referencia:</p><br/><br/><ul><br/><li><a href="http://zsh.sourceforge.net/Guide/zshguide04.html">The Z-Shell Line Editor</a></li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 1,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 12, 10, 43, 770000),
#   'FavoriteCount': '',
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 12, 17, 23, 367000),
#   'LastEditDate': datetime.datetime(2015, 12, 2, 12, 17, 23, 367000),
#   'LastEditorDisplayName': '',
#   'LastEditorUserId': 100,
#   'OwnerDisplayName': '',
#   'OwnerUserId': 100,
#   'ParentId': 222,
#   'PostTypeId': 2,
#   'Score': 12,
#   'Tags': '',
#   'Title': '',
#   'ViewCount': ''})

# %% [markdown]
# ### Ejemplo de consulta: Tiempo medio desde que se hace una pregunta hasta que se le da la primera respuesta
#
# Veamos cómo calcular el tiempo medio desde que se hace una pregunta hasta que se le da la primera respuesta. No se considerarán pues las preguntas que no tienen respuesta, lo cual es razonable.

# %% [markdown]
# Esto sólo calcula el tiempo mínimo de cada pregunta a su respuesta. Después se añadirá el código que calcula la media final:

# %%
min_answer_time: CommandCursor[dict[str,Any]] = db.posts.aggregate([
    { "$match" : {"PostTypeId" : 2} },
    { '$group' : {
        '_id' : '$ParentId',
        # 'answers' : { '$push' : {'Id' : "$Id", 'CreationDate' : "$CreationDate"}},
        'min' : {'$min' : "$CreationDate"}
      }
    },
    { "$lookup" : {
        'from': "posts",
        'localField': "_id",
        'foreignField': "Id",
        'as': "post"}
    },
    { "$unwind" : "$post"},
    { "$project" : {
        "_id" : True,
        "min" : True,
        "diff" : {"$subtract" : ["$min", "$post.CreationDate"]}
      }
    }
])
min_answer_time = list(min_answer_time)
min_answer_time
# Out:
# [{'_id': 239189,
#   'min': datetime.datetime(2019, 2, 19, 20, 26, 34, 910000),
#   'diff': 4248673},
#  {'_id': 166903,
#   'min': datetime.datetime(2018, 5, 23, 1, 50, 3, 750000),
#   'diff': 7071650},
#  {'_id': 444609,
#   'min': datetime.datetime(2021, 4, 15, 21, 53, 38, 30000),
#   'diff': 1905937},
#  {'_id': 55425,
#   'min': datetime.datetime(2017, 3, 15, 8, 35, 39, 887000),
#   'diff': 2542824},
#  {'_id': 55282,
#   'min': datetime.datetime(2017, 3, 14, 19, 20, 16, 333000),
#   'diff': 2158323},
#  {'_id': 438317,
#   'min': datetime.datetime(2021, 3, 25, 18, 57, 22, 280000),
#   'diff': 83447},
#  {'_id': 92904,
#   'min': datetime.datetime(2017, 8, 4, 17, 15, 7, 250000),
#   'diff': 295353},
#  {'_id': 256886,
#   'min': datetime.datetime(2019, 4, 24, 4, 38, 20, 337000),
#   'diff': 18483554},
#  {'_id': 40600,
#   'min': datetime.datetime(2016, 12, 22, 22, 48, 2, 810000),
#   'diff': 12706867},
#  {'_id': 346744,
#   'min': datetime.datetime(2020, 4, 16, 23, 47, 27, 40000),
#   'diff': 1058047},
#  {'_id': 249417,
#   'min': datetime.datetime(2019, 8, 26, 17, 2, 13, 813000),
#   'diff': 13116620266},
#  {'_id': 565853,
#   'min': datetime.datetime(2022, 11, 2, 16, 50, 11, 803000),
#   'diff': 1445070},
#  {'_id': 330323,
#   'min': datetime.datetime(2020, 2, 18, 16, 6, 52, 203000),
#   'diff': 5886136},
#  {'_id': 225796,
#   'min': datetime.datetime(2018, 12, 27, 13, 22, 57, 857000),
#   'diff': 2530544},
#  {'_id': 468879,
#   'min': datetime.datetime(2021, 7, 14, 18, 5, 16, 997000),
#   'diff': 1082290},
#  {'_id': 569754,
#   'min': datetime.datetime(2022, 11, 23, 17, 54, 52, 907000),
#   'diff': 154463060},
#   'min': datetime.datetime(2021, 8, 19, 11, 47, 30, 847000),
#   'diff': 41452167},
#  {'_id': 364984,
#   'min': datetime.datetime(2020, 6, 13, 6, 47, 4, 530000),
#   'diff': 531213},
#  {'_id': 445486,
#   'min': datetime.datetime(2021, 7, 20, 8, 50, 35, 760000),
#   'diff': 7904260107},
#  {'_id': 23953,
#   'min': datetime.datetime(2016, 9, 15, 17, 9, 10, 867000),
#   'diff': 1097524},
#  {'_id': 74236,
#   'min': datetime.datetime(2017, 5, 30, 1, 28, 51, 470000),
#   'diff': 1997617},
#  {'_id': 185928,
#   'min': datetime.datetime(2018, 8, 3, 21, 18, 37, 130000),
#   'diff': 81575823},
#  {'_id': 575206,
#   'min': datetime.datetime(2022, 12, 23, 5, 20, 44, 367000),
#   'diff': 12415667},
#  {'_id': 343953,
#   'min': datetime.datetime(2020, 4, 6, 23, 1, 54, 203000),
#   'diff': 496996},
#  {'_id': 594628,
#   'min': datetime.datetime(2023, 5, 24, 20, 27, 19, 410000),
#   'diff': 8202320},
#  {'_id': 9920,
#   'min': datetime.datetime(2016, 5, 14, 15, 29, 18, 603000),
#   'diff': 51310136},
#  {'_id': 103545,
#   'min': datetime.datetime(2017, 9, 20, 3, 14, 14, 883000),
#   'diff': 1585593},
#  {'_id': 509401,
#   'min': datetime.datetime(2022, 1, 16, 18, 35, 39, 217000),
#   'diff': 26456334},
#  {'_id': 209943,
#   'min': datetime.datetime(2018, 11, 1, 17, 28, 8, 193000),
#   'diff': 590793},
#  {'_id': 374925,
#   'min': datetime.datetime(2020, 7, 20, 17, 19, 56, 337000),
#   'diff': 1053067},
#  {'_id': 36680,
#   'min': datetime.datetime(2016, 11, 29, 17, 37, 40, 863000),
#   'diff': 3279033},
#  {'_id': 506755,
#   'min': datetime.datetime(2021, 12, 30, 19, 3, 57, 710000),
#   'diff': 9140250},
#  {'_id': 500722,
#   'min': datetime.datetime(2021, 12, 1, 20, 38, 29, 960000),
#   'diff': 1353280},
#  {'_id': 7535,
#   'min': datetime.datetime(2016, 4, 11, 20, 11, 43, 970000),
#   'diff': 472680},
#  {'_id': 7820,
#   'min': datetime.datetime(2016, 4, 15, 17, 58, 41, 197000),
#   'diff': 47934880},
#  {'_id': 19664,
#   'min': datetime.datetime(2016, 8, 5, 0, 17, 55, 223000),
#   'diff': 12015423},
#  {'_id': 511755,
#   'min': datetime.datetime(2022, 1, 28, 21, 16, 48, 27000),
#   'diff': 289477},
#  {'_id': 537988,
#   'min': datetime.datetime(2022, 6, 2, 2, 27, 49, 440000),
#   'diff': 680843},
#  {'_id': 364812,
#   'min': datetime.datetime(2020, 6, 13, 1, 38, 14, 663000),
#   'diff': 24835836},
#  {'_id': 78690,
#   'min': datetime.datetime(2017, 6, 14, 21, 50, 28, 800000),
#   'diff': 491230},
#  {'_id': 216418,
#   'min': datetime.datetime(2018, 12, 27, 15, 9, 57, 933000),
#   'diff': 2931122066},
#  {'_id': 219147,
#   'min': datetime.datetime(2018, 12, 3, 21, 46, 35, 597000),
#   'diff': 939604},
#  {'_id': 30273,
#   'min': datetime.datetime(2016, 10, 27, 21, 53, 41, 710000),
#   'diff': 920617},
#  {'_id': 587805,
#   'min': datetime.datetime(2023, 3, 22, 10, 9, 56, 463000),
#   'diff': 58639960},
#  {'_id': 483803,
#   'min': datetime.datetime(2021, 9, 12, 20, 28, 5, 80000),
#   'diff': 2020897},
#  {'_id': 249497,
#   'min': datetime.datetime(2019, 3, 28, 6, 42, 1, 657000),
#   'diff': 11576370},
#  {'_id': 559301,
#   'min': datetime.datetime(2022, 9, 29, 7, 20, 4, 623000),
#   'diff': 100645536},
#  {'_id': 148765,
#   'min': datetime.datetime(2018, 3, 20, 15, 13, 32, 773000),
#   'diff': 394376},
#  {'_id': 206516,
#   'min': datetime.datetime(2018, 10, 23, 2, 2, 0, 660000),
#   'diff': 141286300},
#  {'_id': 214373,
#   'min': datetime.datetime(2018, 11, 20, 19, 5, 33, 787000),
#   'diff': 358988674},
#  {'_id': 26034,
#   'min': datetime.datetime(2016, 10, 4, 15, 38, 11, 33000),
#   'diff': 30413490},
#  {'_id': 213081,
#   'min': datetime.datetime(2018, 11, 12, 22, 34, 17, 923000),
#   'diff': 509046},
#  {'_id': 206664,
#   'min': datetime.datetime(2018, 10, 22, 20, 58, 55, 257000),
#   'diff': 72403000},
#  {'_id': 91070,
#   'min': datetime.datetime(2017, 7, 28, 20, 17, 0, 450000),
#   'diff': 93420917},
#  {'_id': 281614,
#   'min': datetime.datetime(2019, 7, 25, 18, 14, 38, 93000),
#   'diff': 372010},
#  {'_id': 107585,
#   'min': datetime.datetime(2017, 10, 5, 19, 15, 23, 540000),
#   'diff': 723940},
#  {'_id': 323993,
#   'min': datetime.datetime(2020, 1, 23, 18, 12, 58, 883000),
#   'diff': 1180440},
#  {'_id': 497009,
#   'min': datetime.datetime(2021, 11, 13, 19, 28, 47, 983000),
#   'diff': 4724063},
#  {'_id': 477840,
# ...
#   'min': datetime.datetime(2022, 5, 24, 15, 47, 32, 947000),
#   'diff': 1199914},
#  {'_id': 83969,
#   'min': datetime.datetime(2017, 7, 5, 19, 4, 19, 487000),
#   'diff': 3515330},
#  {'_id': 313981,
#   'min': datetime.datetime(2019, 12, 5, 6, 55, 52, 907000),
#   'diff': 310410},
#  {'_id': 99522,
#   'min': datetime.datetime(2017, 9, 3, 15, 42, 29, 667000),
#   'diff': 1130844},
#  {'_id': 333941,
#   'min': datetime.datetime(2020, 6, 8, 1, 21, 47, 990000),
#   'diff': 8390637427},
#  {'_id': 509316,
#   'min': datetime.datetime(2022, 1, 15, 16, 4, 55, 180000),
#   'diff': 1838977},
#  {'_id': 276433,
#   'min': datetime.datetime(2019, 7, 3, 16, 51, 49, 967000),
#   'diff': 1440300},
#  {'_id': 158718,
#   'min': datetime.datetime(2018, 4, 24, 15, 36, 23, 720000),
#   'diff': 7249073},
#  {'_id': 54726,
#   'min': datetime.datetime(2017, 3, 11, 19, 53, 30, 970000),
#   'diff': 607010},
#  {'_id': 345643,
#   'min': datetime.datetime(2020, 4, 13, 13, 47, 46, 290000),
#   'diff': 149482463},
#  {'_id': 366176,
#   'min': datetime.datetime(2020, 6, 17, 10, 12, 30, 143000),
#   'diff': 7255363},
#  {'_id': 289676,
#   'min': datetime.datetime(2019, 9, 1, 4, 14, 36, 883000),
#   'diff': 741106},
#  {'_id': 109889,
#   'min': datetime.datetime(2017, 10, 16, 15, 10, 19, 943000),
#   'diff': 579976},
#  {'_id': 112663,
#   'min': datetime.datetime(2017, 10, 29, 3, 10, 59, 640000),
#   'diff': 191008930},
#  {'_id': 2661,
#   'min': datetime.datetime(2016, 2, 19, 16, 43, 45, 790000),
#   'diff': 2885757890},
#  {'_id': 220776,
#   'min': datetime.datetime(2018, 12, 10, 7, 36, 8, 60000),
#   'diff': 62933730},
#  {'_id': 436268,
#   'min': datetime.datetime(2021, 3, 17, 20, 16, 29, 787000),
#   'diff': 5833710},
#  {'_id': 189282,
#   'min': datetime.datetime(2018, 8, 16, 15, 18, 8, 537000),
#   'diff': 424887},
#  {'_id': 519350,
#   'min': datetime.datetime(2022, 3, 8, 20, 55, 51, 650000),
#   'diff': 1043533},
#  {'_id': 344146,
#   'min': datetime.datetime(2020, 4, 7, 18, 21, 52, 390000),
#   'diff': 6330490},
#  {'_id': 2067,
#   'min': datetime.datetime(2016, 1, 5, 5, 18, 54, 807000),
#   'diff': 10033444},
#  {'_id': 24772,
#   'min': datetime.datetime(2016, 9, 23, 12, 40, 19, 987000),
#   'diff': 15021470},
#  {'_id': 277133,
#   'min': datetime.datetime(2019, 7, 5, 23, 20, 50, 93000),
#   'diff': 3326363},
#  {'_id': 573054,
#   'min': datetime.datetime(2022, 12, 9, 19, 56, 23, 363000),
#   'diff': 8294273},
#  {'_id': 218371,
#   'min': datetime.datetime(2019, 4, 27, 1, 58, 31, 993000),
#   'diff': 12760968756},
#  {'_id': 316306,
#   'min': datetime.datetime(2019, 12, 15, 17, 44, 3, 453000),
#   'diff': 389810},
#  {'_id': 42134,
#   'min': datetime.datetime(2017, 1, 3, 17, 56, 15, 727000),
#   'diff': 5524007},
#  {'_id': 10883,
#   'min': datetime.datetime(2016, 5, 24, 23, 0, 58, 207000),
#   'diff': 7490307},
#  {'_id': 189300,
#   'min': datetime.datetime(2018, 8, 17, 23, 28, 25, 900000),
#   'diff': 113850893},
#  {'_id': 500709,
#   'min': datetime.datetime(2021, 12, 1, 18, 58, 53, 280000),
#   'diff': 583423},
#  {'_id': 510644,
#   'min': datetime.datetime(2022, 3, 21, 17, 58, 55, 630000),
#   'diff': 4934338513},
#  {'_id': 356923,
#   'min': datetime.datetime(2020, 5, 18, 19, 19, 35, 590000),
#   'diff': 188393},
#  {'_id': 127858,
#   'min': datetime.datetime(2017, 12, 29, 21, 10, 15, 290000),
#   'diff': 1624740},
#  {'_id': 47114,
#   'min': datetime.datetime(2017, 2, 1, 4, 48, 5, 560000),
#   'diff': 2299133},
#  {'_id': 382148,
#   'min': datetime.datetime(2020, 8, 15, 16, 27, 53, 283000),
#   'diff': 46093573},
#  {'_id': 511601,
#  {'_id': 322536,
#   'min': datetime.datetime(2020, 1, 21, 16, 53, 47, 103000),
#   'diff': 354856463},
#  ...]

# %% [markdown]
# La siguiente consulta sí calcula la media:

# %%
avg_answer_time: CommandCursor[dict[str,Any]] = db.posts.aggregate([
    { "$match" : {"PostTypeId" : 2} },
    { '$group' : {
        '_id' : '$ParentId',
        # 'answers' : { '$push' : {'Id' : "$Id", 'CreationDate' : "$CreationDate"}},
        'min' : {'$min' : "$CreationDate"}
      }
    },
    { "$lookup" : {
        'from': "posts",
        'localField': "_id",
        'foreignField': "Id",
        'as': "post"}
    },
    { "$unwind" : "$post"},
    { "$project" : {
        "_id" : True,
        "min" : True,
        "diff" : {"$subtract" : ["$min", "$post.CreationDate"]}
      }
    },
    #    { "$sort" : {'_id' : 1} }
    {
      "$group" :  {
        "_id" : None,
        "avg" : { "$avg" : "$diff"}
      }
    }
])
avg_answer_time = list(avg_answer_time)
avg_answer_time
# Out:
# [{'_id': None, 'avg': 943326388.0748069}]

# %% [markdown]
# ## EJERCICIO 1: Listar aquellos usuarios con una reputación (`Reputation`) superior o igual a 500 y un número de visualizaciones (`Views`) superior a 200. De dichos usuarios solo mostrar los campos:
# - `DisplayName`
# - `Location`
# - `Reputation`
# - `Views`
#
# *IMPORTANTE: No mostrar el campo `_id`*

# %%
usuarios: CommandCursor[dict[str, Any]] = db.users.aggregate([
    {"$match": {"Reputation": {"$gte": 500}, "Views": {"$gt": 200}}},
    {"$project": {"_id": 0, "DisplayName": 1, "Location": 1, "Reputation": 1, "Views": 1}}
])
list(usuarios)
# Out:
# [{'DisplayName': 'Carlos Muñoz',
#   'Location': 'Lima, Peru',
#   'Reputation': 13368,
#   'Views': 2231},
#  {'DisplayName': 'jachguate',
#   'Location': 'Guatemala',
#   'Reputation': 30128,
#   'Views': 2892},
#  {'DisplayName': 'Konamiman',
#   'Location': 'Palma de Mallorca, Spain',
#   'Reputation': 5278,
#   'Views': 787},
#  {'DisplayName': 'Angel Angel',
#   'Location': '',
#   'Reputation': 10093,
#   'Views': 1023},
#  {'DisplayName': 'rnrneverdies',
#   'Location': 'Argentina',
#   'Reputation': 16867,
#   'Views': 1643},
#  {'DisplayName': 'Lamak',
#   'Location': 'Chile',
#   'Reputation': 8505,
#   'Views': 1348},
#  {'DisplayName': 'Diego', 'Location': '', 'Reputation': 5693, 'Views': 332},
#  {'DisplayName': 'Davlio',
#   'Location': 'Lima, Peru',
#   'Reputation': 2980,
#   'Views': 333},
#  {'DisplayName': 'Rubén',
#   'Location': 'Monterrey, Mexico',
#   'Reputation': 11406,
#   'Views': 1886},
#  {'DisplayName': 'Shaz',
#   'Location': 'Canada / Colombia',
#   'Reputation': 29168,
#   'Views': 4246},
#  {'DisplayName': 'astrojuanlu',
#   'Location': 'Spain',
#   'Reputation': 1084,
#   'Views': 223},
#  {'DisplayName': 'Mauricio Arias Olave',
#   'Location': 'Bogotá, Colombia',
#   'Reputation': 3148,
#   'Views': 1218},
#  {'DisplayName': 'fedorqui',
#   'Location': '',
#   'Reputation': 16620,
#   'Views': 3261},
#  {'DisplayName': 'Jorgesys',
#   'Location': 'Mexico City, CDMX, Mexico / Iași, Romania',
#   'Reputation': 109420,
#   'Views': 17565},
#  {'DisplayName': 'César',
#   'Location': 'Lima, Peru',
#   'Reputation': 17360,
#   'Views': 1710},
#  {'DisplayName': 'Mariano',
#   'Location': 'Buenos Aires, Argentina',
#   'Reputation': 24464,
#   'Views': 4283},
#  {'DisplayName': 'Wilfredo',
#   'Location': 'Buenos Aires, CABA, Argentina',
#   'Reputation': 2567,
#   'Views': 211},
#  {'DisplayName': 'Eduardo Munizaga',
#   'Location': 'Chile',
#   'Reputation': 2804,
#   'Views': 396},
#  {'DisplayName': 'Emilio Platzer',
#   'Location': 'Argentina',
#   'Reputation': 2452,
#   'Views': 213},
#  {'DisplayName': 'Alter Lagos',
#   'Location': 'Chillan  Auckland ',
#   'Reputation': 5466,
#   'Views': 515},
#  {'DisplayName': 'Alan', 'Location': '', 'Reputation': 2272, 'Views': 309},
#  {'DisplayName': 'Alvaro Montoro',
#   'Location': 'Austin, TX',
#   'Reputation': 49245,
#   'Views': 7610},
#  {'DisplayName': 'Marcos Crispino',
#   'Location': 'Montevideo, Uruguay',
#   'Reputation': 3485,
#   'Views': 339},
#  {'DisplayName': 'Anonymous Coward',
#   'Location': '',
#   'Reputation': 6344,
#   'Views': 970},
#  {'DisplayName': 'gbianchi',
#   'Location': 'Argentina',
#   'Reputation': 20347,
#   'Views': 9665},
#  {'DisplayName': 'Ruslan López',
#   'Location': 'Mexico City, Mexico',
#   'Reputation': 11540,
#   'Views': 2791},
#  {'DisplayName': 'Diana Carolina Hernandez',
#   'Location': 'Cali, Colombia',
#   'Reputation': 781,
#   'Views': 215},
#  {'DisplayName': 'JuanK',
#   'Location': 'Bogota, Colombia',
#   'Reputation': 2467,
#   'Views': 310},
#  {'DisplayName': 'Gepser Hoil',
#   'Location': 'Berlin, Germany',
#   'Reputation': 3663,
#   'Views': 275},
#  {'DisplayName': 'dwarandae',
#   'Location': 'Bogota, Colombia',
#   'Reputation': 2499,
#   'Views': 337},
#  {'DisplayName': 'eferion',
#   'Location': 'Madrid',
#   'Reputation': 52409,
#   'Views': 3413},
#  {'DisplayName': 'Jordi Castilla',
#   'Location': 'Barcelona',
#   'Reputation': 7399,
#   'Views': 528},
#  {'DisplayName': 'Joel Ibaceta',
#   'Location': 'Buenos Aires, Autonomous City of Buenos Aires, Argentina',
#   'Reputation': 2403,
#   'Views': 616},
#  {'DisplayName': 'ChemaCortes',
#   'Location': 'Zaragoza, Spain',
#   'Reputation': 9036,
#   'Views': 1105},
#  {'DisplayName': 'toledano',
#   'Location': 'Tlaxcala de Xicohténcatl, México',
#   'Reputation': 5136,
#   'Views': 1995},
#  {'DisplayName': 'Chofoteddy',
#   'Location': 'México, D.F.',
#   'Reputation': 6185,
#   'Views': 288},
#  {'DisplayName': 'fredyfx',
#   'Location': 'Internet',
#   'Reputation': 13063,
#   'Views': 3420},
#  {'DisplayName': 'enrique7mc',
#   'Location': 'Mexico City, Mexico',
#   'Reputation': 2914,
#   'Views': 283},
#  {'DisplayName': 'Sergio Parra Guerra',
#   'Location': 'Leganes, Spain',
#   'Reputation': 1976,
#   'Views': 289},
#  {'DisplayName': 'Gerardo Martínez',
#   'Location': 'Guadalajara, Mexico',
#   'Reputation': 3202,
#   'Views': 443},
#  {'DisplayName': 'leonbloy',
#   'Location': 'Buenos Aires, Argentina',
#   'Reputation': 2513,
#   'Views': 247},
#  {'DisplayName': 'jasilva',
#   'Location': 'México',
#   'Reputation': 5112,
#   'Views': 746},
#  {'DisplayName': 'loki',
#   'Location': 'México',
#   'Reputation': 952,
#   'Views': 244},
#  {'DisplayName': 'x4mp73r',
#   'Location': 'Guadalajara, México',
#   'Reputation': 2078,
#   'Views': 422},
#  {'DisplayName': 'devconcept',
#   'Location': 'Holguín, Cuba',
#   'Reputation': 12761,
#   'Views': 1095},
#  {'DisplayName': 'Codelaby',
#   'Location': 'Barcelona, España',
#   'Reputation': 11131,
#   'Views': 1799},
#  {'DisplayName': 'Danilo ', 'Location': '', 'Reputation': 2528, 'Views': 270},
#  {'DisplayName': 'Montse Mkd',
#   'Location': '',
#   'Reputation': 1229,
#   'Views': 612},
#  {'DisplayName': 'Juan Pinzón',
#   'Location': 'Loja, Ecuador',
#   'Reputation': 9238,
#   'Views': 935},
#  {'DisplayName': 'Leandro Tuttini',
#   'Location': 'Argentina',
#   'Reputation': 35846,
#   'Views': 5928},
#  {'DisplayName': 'Revolucion for Monica',
#   'Location': 'Congo-Kinshasa',
#   'Reputation': 4447,
#   'Views': 1372},
#  {'DisplayName': 'dddenis',
#   'Location': 'España',
#   'Reputation': 3993,
#   'Views': 384},
#  {'DisplayName': 'PaperBirdMaster',
#   'Location': 'Barcelona, Espanya',
#   'Reputation': 47301,
#   'Views': 5458},
#  {'DisplayName': 'Pipe', 'Location': '', 'Reputation': 3282, 'Views': 406},
#  {'DisplayName': 'kikocorreoso',
#   'Location': '',
#   'Reputation': 2195,
#   'Views': 254},
#  {'DisplayName': 'Pedro Miguel Pimienta Morales',
#   'Location': 'Colombia',
#   'Reputation': 4385,
#   'Views': 772},
#  {'DisplayName': 'Juan',
#   'Location': 'Córdoba, Argentina',
#   'Reputation': 1726,
#   'Views': 260},
#  {'DisplayName': 'Arnau Castellví',
#   'Location': '',
#   'Reputation': 2574,
#   'Views': 370},
#  {'DisplayName': 'wchiquito',
#   'Location': '',
#   'Reputation': 1246,
#   'Views': 825},
#  {'DisplayName': 'abrahamhs',
#   'Location': 'Kandor',
#   'Reputation': 3746,
#   'Views': 434},
#  {'DisplayName': 'Eduen Sarceño',
#   'Location': 'Guatemala',
#   'Reputation': 2102,
#   'Views': 312},
#  {'DisplayName': 'Pedro Ávila',
#   'Location': 'Lima, Peru',
#   'Reputation': 4057,
#   'Views': 779},
#  {'DisplayName': 'Marcos Martínez',
#   'Location': 'Montevideo, Uruguay',
#   'Reputation': 2332,
#   'Views': 376},
#  {'DisplayName': 'Eduardo Javier Maldonado',
#   'Location': 'Tlajomulco de Zúñiga, México',
#   'Reputation': 2495,
#   'Views': 473},
#  {'DisplayName': 'Perl',
#   'Location': 'Málaga, España',
#   'Reputation': 767,
#   'Views': 227},
#  {'DisplayName': 'NaCl',
#   'Location': 'Dominican Republic',
#   'Reputation': 6812,
#   'Views': 1175},
#  {'DisplayName': 'Lina Cortés',
#   'Location': '',
#   'Reputation': 741,
#   'Views': 438},
#  {'DisplayName': 'UselesssCat',
#   'Location': 'La Serena, Chile',
#   'Reputation': 3193,
#   'Views': 590},
#  {'DisplayName': 'akko', 'Location': '', 'Reputation': 2408, 'Views': 335},
#  {'DisplayName': 'Vicky Vicent',
#   'Location': 'España',
#   'Reputation': 1663,
#   'Views': 397},
#  {'DisplayName': 'Edgar Gutiérrez',
#   'Location': 'Bogotá, Colombia',
#   'Reputation': 3755,
#   'Views': 253},
#  {'DisplayName': 'Fernando Torres',
#   'Location': 'Mexico City, CDMX, México',
#   'Reputation': 1490,
#   'Views': 315},
#  {'DisplayName': 'V0LT3RR4',
#   'Location': 'Colombia',
#   'Reputation': 1217,
#   'Views': 270},
#  {'DisplayName': 'Muriano',
#   'Location': 'Málaga, España',
#   'Reputation': 4097,
#   'Views': 585},
#  {'DisplayName': 'OscarR',
#   'Location': 'Málaga, Spain',
#   'Reputation': 2295,
#   'Views': 206},
#  {'DisplayName': 'David',
#   'Location': 'Dolores Hidalgo Cuna de la Independencia Nacional, Guanajuato, México',
#   'Reputation': 2982,
#   'Views': 471},
#  {'DisplayName': 'Máxima Alekz',
#   'Location': 'Colombia',
#   'Reputation': 1825,
#   'Views': 338},
#  {'DisplayName': 'Asier Villanueva',
#   'Location': 'Bilbao',
#   'Reputation': 14554,
#   'Views': 1242},
#  {'DisplayName': 'Jose Hermosilla Rodrigo',
#   'Location': 'Torrent, Valencia, València, España',
#   'Reputation': 3880,
#   'Views': 413},
#  {'DisplayName': 'Black Sheep',
#   'Location': 'Málaga, Spain',
#   'Reputation': 13541,
#   'Views': 1070},
#  {'DisplayName': 'Alfonso Carrasco',
#   'Location': 'León, México',
#   'Reputation': 1403,
#   'Views': 231},
#  {'DisplayName': 'JuankGlezz',
#   'Location': 'Zamora, Michoacán, México',
#   'Reputation': 5548,
#   'Views': 976},
#  {'DisplayName': 'Efrain Mejias C',
#   'Location': 'Valencia, Carabobo, Venezuela',
#   'Reputation': 1996,
#   'Views': 471},
#  {'DisplayName': 'Alfabravo',
#   'Location': 'Colombia',
#   'Reputation': 9862,
#   'Views': 3776},
#  {'DisplayName': 'Ventur',
#   'Location': 'Ciudad de México, México',
#   'Reputation': 1828,
#   'Views': 608},
#  {'DisplayName': 'Lucas. D',
#   'Location': 'Córdoba, Cordoba, Argentina',
#   'Reputation': 1323,
#   'Views': 204},
#  {'DisplayName': 'MitaCloud',
#   'Location': 'Barcelona, España',
#   'Reputation': 2672,
#   'Views': 264},
#  {'DisplayName': 'abulafia',
#   'Location': '',
#   'Reputation': 58428,
#   'Views': 5959},
#  {'DisplayName': 'Miquel Coll',
#   'Location': 'Barcelona',
#   'Reputation': 3201,
#   'Views': 963},
#  {'DisplayName': 'Jakala', 'Location': '', 'Reputation': 4059, 'Views': 701},
#  {'DisplayName': 'Rimuru Tempest',
#   'Location': 'En la web',
#   'Reputation': 2655,
#   'Views': 450},
#  {'DisplayName': 'ErnestoRM',
#   'Location': '',
#   'Reputation': 1759,
#   'Views': 246},
#  {'DisplayName': 'Adriana Hernández',
#   'Location': 'Galicia, España',
#   'Reputation': 1594,
#   'Views': 1040},
#  {'DisplayName': 'Sr1871',
#   'Location': 'Ciudad de México, México',
#   'Reputation': 5803,
#   'Views': 559},
#  {'DisplayName': 'Jose Javier Segura',
#   'Location': 'Zaragoza, España',
#   'Reputation': 1698,
#   'Views': 242},
#  {'DisplayName': 'jbkunst',
#   'Location': 'Santiago, Chile',
#   'Reputation': 791,
#   'Views': 224},
#  {'DisplayName': 'Alberto Siurob',
#   'Location': 'Ciudad de México, CDMX, México',
#   'Reputation': 6507,
#   'Views': 695},
#  {'DisplayName': 'Rf Mvs', 'Location': '', 'Reputation': 1460, 'Views': 393},
#  {'DisplayName': 'Genarito',
#   'Location': 'Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina',
#   'Reputation': 2623,
#   'Views': 267},
#  {'DisplayName': 'Juan Carlos Villamizar Alvarez',
#   'Location': 'Los Teques, Miranda, Venezuela',
#   'Reputation': 1464,
#   'Views': 375},
#  {'DisplayName': 'D.Bulten',
#   'Location': 'España',
#   'Reputation': 6552,
#   'Views': 523},
#  {'DisplayName': 'JGarnica',
#   'Location': 'Mexico',
#   'Reputation': 1497,
#   'Views': 230},
#  {'DisplayName': 'g3rv4',
#   'Location': 'Montevideo, Uruguay',
#   'Reputation': 1804,
#   'Views': 1097},
#  {'DisplayName': 'Carlos A. Gómez',
#   'Location': 'Madrid, España',
#   'Reputation': 1641,
#   'Views': 252},
#  {'DisplayName': 'Root93', 'Location': '', 'Reputation': 1045, 'Views': 287},
#  {'DisplayName': 'Dev. Joel',
#   'Location': 'Perú',
#   'Reputation': 23779,
#   'Views': 4627},
#  {'DisplayName': 'Malthael',
#   'Location': 'Guayaquil, Guayas, Ecuador',
#   'Reputation': 826,
#   'Views': 261},
#  {'DisplayName': 'hubman',
#   'Location': 'Uruguay',
#   'Reputation': 2714,
#   'Views': 739},
#  {'DisplayName': 'Joacer',
#   'Location': 'Valencia, España',
#   'Reputation': 5835,
#   'Views': 598},
#  {'DisplayName': 'lromeraj',
#   'Location': 'España',
#   'Reputation': 1985,
#   'Views': 254},
#  {'DisplayName': 'SJuan76',
#   'Location': '',
#   'Reputation': 10930,
#   'Views': 1363},
#  {'DisplayName': 'Lombarda Arda',
#   'Location': 'Spain',
#   'Reputation': 1907,
#   'Views': 388},
#  {'DisplayName': 'May', 'Location': '', 'Reputation': 583, 'Views': 226},
#  {'DisplayName': 'J. Castro',
#   'Location': 'San Nicolás de los Garza, México',
#   'Reputation': 2487,
#   'Views': 464},
#  {'DisplayName': 'Bender Paisa',
#   'Location': 'Medellín - Antioquia, Colombia',
#   'Reputation': 12651,
#   'Views': 1373},
#  {'DisplayName': 'FJSevilla',
#   'Location': '',
#   'Reputation': 57213,
#   'Views': 5168},
#  {'DisplayName': 'German Alzate',
#   'Location': 'Barranquilla',
#   'Reputation': 3055,
#   'Views': 466},
#  {'DisplayName': 'Pikoh',
#   'Location': 'Santander, Spain',
#   'Reputation': 17481,
#   'Views': 2729},
#  {'DisplayName': 'Omar  Barrera Valentin',
#   'Location': 'Iguala de la Independencia',
#   'Reputation': 1289,
#   'Views': 216},
#  {'DisplayName': 'lois6b',
#   'Location': 'Oviedo, Spain, España',
#   'Reputation': 7560,
#   'Views': 3214},
#  {'DisplayName': 'Francisco Romero',
#   'Location': 'Zaragoza, España',
#   'Reputation': 16641,
#   'Views': 2237},
#  {'DisplayName': 'Elena López',
#   'Location': 'Santo Domingo, Distrito Nacional, República Dominicana',
#   'Reputation': 747,
#   'Views': 226},
#  {'DisplayName': 'Sal', 'Location': '', 'Reputation': 7788, 'Views': 884},
#  {'DisplayName': 'sioesi',
#   'Location': 'Chile',
#   'Reputation': 11500,
#   'Views': 1443},
#  {'DisplayName': 'Marcos',
#   'Location': 'Córdoba, Argentina',
#   'Reputation': 33832,
#   'Views': 2617},
#  {'DisplayName': 'Phi',
#   'Location': 'México',
#   'Reputation': 10110,
#   'Views': 1302},
#  {'DisplayName': 'Randall Sandoval',
#   'Location': 'Costa Rica',
#   'Reputation': 2411,
#   'Views': 270},
#  {'DisplayName': 'David',
#   'Location': 'Spain',
#   'Reputation': 1481,
#   'Views': 216},
#  {'DisplayName': 'Carmen', 'Location': '', 'Reputation': 7287, 'Views': 802},
#  {'DisplayName': 'ffflabs',
#   'Location': 'Santiago, Chile',
#   'Reputation': 22756,
#   'Views': 2508},
#  {'DisplayName': 'Pavlo B.', 'Location': '', 'Reputation': 1905, 'Views': 277},
#  {'DisplayName': 'OscarGarcia',
#   'Location': 'Spain',
#   'Reputation': 28369,
#   'Views': 2693},
#  {'DisplayName': 'Jorius',
#   'Location': 'Medellín, Colombia',
#   'Reputation': 6361,
#   'Views': 601},
#  {'DisplayName': 'sstan',
#   'Location': 'United States',
#   'Reputation': 16886,
#   'Views': 2232},
#  {'DisplayName': 'Trauma',
#   'Location': 'Málaga, España',
#   'Reputation': 26458,
#   'Views': 2876},
#  {'DisplayName': 'Awes0meM4n',
#   'Location': 'España',
#   'Reputation': 2220,
#   'Views': 664},
#  {'DisplayName': 'bypabloc_',
#   'Location': '',
#   'Reputation': 1885,
#   'Views': 509},
#  {'DisplayName': 'rencinas',
#   'Location': 'España',
#   'Reputation': 1285,
#   'Views': 334},
#  {'DisplayName': 'Orici',
#   'Location': 'Valencia, Spain',
#   'Reputation': 7709,
#   'Views': 924},
#  {'DisplayName': 'FrEqDe',
#   'Location': 'Oaxaca, México',
#   'Reputation': 3599,
#   'Views': 398},
#  {'DisplayName': 'Alejandro Caro',
#   'Location': 'Maldonado Departamento de Maldonado, Uruguay',
#   'Reputation': 879,
#   'Views': 241},
#  {'DisplayName': 'Yoel Rodriguez',
#   'Location': 'La Paz Baja California Sur',
#   'Reputation': 1733,
#   'Views': 424},
#  {'DisplayName': 'omaza1990',
#   'Location': 'Santander, España',
#   'Reputation': 2832,
#   'Views': 751},
#  {'DisplayName': 'RRGT19', 'Location': '', 'Reputation': 2011, 'Views': 428},
#  {'DisplayName': 'Pablo Lozano',
#   'Location': 'Málaga, España',
#   'Reputation': 49264,
#   'Views': 5211},
#  {'DisplayName': 'Pablo Fradua',
#   'Location': '',
#   'Reputation': 3528,
#   'Views': 293},
#  {'DisplayName': 'Rene Limon',
#   'Location': 'Puebla, Mexico',
#   'Reputation': 4630,
#   'Views': 718},
#  {'DisplayName': 'cnbandicoot',
#   'Location': '',
#   'Reputation': 2754,
#   'Views': 243},
#  {'DisplayName': 'Javier fr',
#   'Location': 'Mexico',
#   'Reputation': 1798,
#   'Views': 286},
#  {'DisplayName': 'Rostan', 'Location': '', 'Reputation': 2277, 'Views': 252},
#  {'DisplayName': 'Ivan Botero',
#   'Location': 'Colombia',
#   'Reputation': 6703,
#   'Views': 1213},
#  {'DisplayName': 'ger',
#   'Location': 'Medellín, Medellin, Antioquia, Colombia',
#   'Reputation': 1286,
#   'Views': 229},
#  {'DisplayName': 'ingswsm', 'Location': '', 'Reputation': 933, 'Views': 227},
#  {'DisplayName': 'Cristina Carrasco',
#   'Location': 'Irving, Texas',
#   'Reputation': 5464,
#   'Views': 1586},
#  {'DisplayName': 'DoubleM',
#   'Location': 'Méx., México',
#   'Reputation': 1273,
#   'Views': 537},
#  {'DisplayName': 'Ashley G.',
#   'Location': '',
#   'Reputation': 1859,
#   'Views': 929},
#  {'DisplayName': 'UserNameYo',
#   'Location': 'Spain',
#   'Reputation': 2402,
#   'Views': 232},
#  {'DisplayName': 'Raul Cacacho',
#   'Location': 'Guatemala City, Guatemala',
#   'Reputation': 2303,
#   'Views': 811},
#  {'DisplayName': 'PieroDev', 'Location': '', 'Reputation': 1980, 'Views': 562},
#  {'DisplayName': 'gugadev',
#   'Location': 'Perú',
#   'Reputation': 19084,
#   'Views': 2443},
#  {'DisplayName': 'Stefan Nolde',
#   'Location': 'Chile, Temuco',
#   'Reputation': 6748,
#   'Views': 1218},
#  {'DisplayName': 'simon',
#   'Location': 'México',
#   'Reputation': 2427,
#   'Views': 372},
#  {'DisplayName': 'information',
#   'Location': 'España',
#   'Reputation': 6460,
#   'Views': 986},
#  {'DisplayName': 'Stephanie B Bautista',
#   'Location': '',
#   'Reputation': 509,
#   'Views': 365},
#  {'DisplayName': 'Dev 200', 'Location': '', 'Reputation': 5436, 'Views': 599},
#  {'DisplayName': 'JackNavaRow',
#   'Location': '',
#   'Reputation': 7101,
#   'Views': 1871},
#  {'DisplayName': 'user2930137',
#   'Location': '',
#   'Reputation': 1361,
#   'Views': 216},
#  {'DisplayName': 'farsSharp',
#   'Location': 'Hermosillo, México',
#   'Reputation': 2376,
#   'Views': 443},
#  {'DisplayName': 'Jhosselin Giménez',
#   'Location': '',
#   'Reputation': 667,
#   'Views': 241},
#  {'DisplayName': 'Jose Felipe Charbel Pavez Gass',
#   'Location': '',
#   'Reputation': 1678,
#   'Views': 250},
#  {'DisplayName': 'A. Cedano',
#   'Location': '',
#   'Reputation': 93820,
#   'Views': 13113},
#  {'DisplayName': 'Paulo Urbano Rivera',
#   'Location': 'Santiago, Chile',
#   'Reputation': 4660,
#   'Views': 660},
#  {'DisplayName': 'Pablo Simon DiEstefano',
#   'Location': 'Zaragoza, España',
#   'Reputation': 3212,
#   'Views': 840},
#  {'DisplayName': 'BotXtrem Solutions',
#   'Location': 'Nicaragua',
#   'Reputation': 880,
#   'Views': 340},
#  {'DisplayName': 'DavElsanto',
#   'Location': 'Quito, Pichincha, Ecuador',
#   'Reputation': 1340,
#   'Views': 321},
#  {'DisplayName': 'ByGroxD',
#   'Location': 'Bogotá, Colombia',
#   'Reputation': 783,
#   'Views': 268},
#  {'DisplayName': 'M. Gress',
#   'Location': 'Cdmx México',
#   'Reputation': 1480,
#   'Views': 316},
#  {'DisplayName': 'ElChiniNet',
#   'Location': 'Ámsterdam, Países Bajos',
#   'Reputation': 3295,
#   'Views': 246},
#  {'DisplayName': "Franklin'j Gil'z",
#   'Location': 'Caracas',
#   'Reputation': 1543,
#   'Views': 252},
#  {'DisplayName': 'Kroneaux Schneider',
#   'Location': 'Ciudad de México, México',
#   'Reputation': 3697,
#   'Views': 336},
#  {'DisplayName': 'UnexpectedCharacter',
#   'Location': '',
#   'Reputation': 1853,
#   'Views': 227},
#  {'DisplayName': 'Patricio Moracho',
#   'Location': 'Argentina',
#   'Reputation': 60025,
#   'Views': 5624},
#  {'DisplayName': 'F.Igor',
#   'Location': 'Vancouver, BC, Canada',
#   'Reputation': 4472,
#   'Views': 435},
#  {'DisplayName': 'Juan',
#   'Location': 'Buenos Aires, Argentina',
#   'Reputation': 5665,
#   'Views': 427},
#  {'DisplayName': 'Legna', 'Location': '', 'Reputation': 6561, 'Views': 761},
#  {'DisplayName': 'Jose Miguel Sepulveda',
#   'Location': 'Chile, Santiago',
#   'Reputation': 2134,
#   'Views': 444},
#  {'DisplayName': 'Critical Ghost',
#   'Location': '',
#   'Reputation': 1306,
#   'Views': 493},
#  {'DisplayName': 'Ricardo D. Quiroga',
#   'Location': 'Salta - Argentina',
#   'Reputation': 2588,
#   'Views': 204},
#  {'DisplayName': 'jecorrales',
#   'Location': 'Colombia',
#   'Reputation': 975,
#   'Views': 286},
#  {'DisplayName': 'Yikarus',
#   'Location': 'León, México',
#   'Reputation': 1852,
#   'Views': 324},
#  {'DisplayName': 'fwBasic',
#   'Location': 'Venezuela',
#   'Reputation': 2824,
#   'Views': 343},
#  {'DisplayName': 'Jorge Arturo Juarez',
#   'Location': 'Guanajuato, México',
#   'Reputation': 2823,
#   'Views': 280},
#  {'DisplayName': 'Xerif',
#   'Location': 'Spain',
#   'Reputation': 7381,
#   'Views': 558},
#  {'DisplayName': 'Andrespengineer',
#   'Location': 'Santo Domingo, Distrito Nacional, República Dominicana',
#   'Reputation': 3002,
#   'Views': 295},
#  {'DisplayName': 'ESCM', 'Location': '', 'Reputation': 5030, 'Views': 811},
#  {'DisplayName': 'Einer',
#   'Location': 'Santo Domingo, Distrito Nacional, Dominican Republic',
#   'Reputation': 20513,
#   'Views': 1291},
#  {'DisplayName': 'FederHico',
#   'Location': 'Argentina',
#   'Reputation': 1230,
#   'Views': 210},
#  {'DisplayName': 'Albert Hidalgo',
#   'Location': 'Universo observable',
#   'Reputation': 2839,
#   'Views': 350},
#  {'DisplayName': 'Israel', 'Location': '', 'Reputation': 1467, 'Views': 238},
#  {'DisplayName': 'Ivan More Flores',
#   'Location': 'Distrito de Lima, Departamento de Lima, Perú',
#   'Reputation': 1602,
#   'Views': 292},
#  {'DisplayName': 'DjCrazy', 'Location': '', 'Reputation': 6816, 'Views': 574},
#  {'DisplayName': 'Manuel Robles',
#   'Location': '',
#   'Reputation': 1624,
#   'Views': 209},
#  {'DisplayName': 'Miguel Alparez',
#   'Location': 'San Fernando',
#   'Reputation': 749,
#   'Views': 215},
#  {'DisplayName': 'Marce Puente',
#   'Location': 'Argentina',
#   'Reputation': 2936,
#   'Views': 805},
#  {'DisplayName': 'phpMyGuel',
#   'Location': 'Oviedo, España',
#   'Reputation': 14767,
#   'Views': 757},
#  {'DisplayName': 'ben', 'Location': '', 'Reputation': 2327, 'Views': 245},
#  {'DisplayName': 'Soy César Mora',
#   'Location': 'Concepción, Chile',
#   'Reputation': 2310,
#   'Views': 273},
#  {'DisplayName': 'Gerry',
#   'Location': 'México',
#   'Reputation': 5238,
#   'Views': 335},
#  {'DisplayName': 'ilernet', 'Location': '', 'Reputation': 1323, 'Views': 220},
#  {'DisplayName': 'Miguel Espeso',
#   'Location': 'La Parra, Avila',
#   'Reputation': 1452,
#   'Views': 291},
#  {'DisplayName': 'L. Ronquillo',
#   'Location': 'Mérida, México',
#   'Reputation': 2531,
#   'Views': 531},
#  {'DisplayName': 'JohnnyTB',
#   'Location': 'Bogota, Colombia',
#   'Reputation': 2692,
#   'Views': 275},
#  {'DisplayName': 'Víctor Hugo Tirado',
#   'Location': 'Potosí, Bolivia',
#   'Reputation': 1795,
#   'Views': 337},
#  {'DisplayName': 'mpaladino',
#   'Location': 'CDMX, México',
#   'Reputation': 5994,
#   'Views': 269},
#  {'DisplayName': 'Kenny Barrera',
#   'Location': 'Quetzaltenango, Quetzaltenango Department, Guatemala',
#   'Reputation': 2135,
#   'Views': 386},
#  {'DisplayName': 'W Aleman',
#   'Location': 'Donostia-San Sebastián, España',
#   'Reputation': 1897,
#   'Views': 217},
#  {'DisplayName': 'Shassain',
#   'Location': 'Potosí, Bolivia',
#   'Reputation': 5514,
#   'Views': 802},
#  {'DisplayName': 'GDP',
#   'Location': 'Basque Country',
#   'Reputation': 2753,
#   'Views': 384},
#  {'DisplayName': 'Aritz',
#   'Location': 'Mordor',
#   'Reputation': 3108,
#   'Views': 548},
#  {'DisplayName': 'A. Palacio',
#   'Location': 'Mexico City, CDMX, México',
#   'Reputation': 1281,
#   'Views': 682},
#  {'DisplayName': 'Marc',
#   'Location': 'Catalunya',
#   'Reputation': 5149,
#   'Views': 580},
#  {'DisplayName': 'David Minaya',
#   'Location': 'Santiago De Los Caballeros, Santiago, República Dominicana',
#   'Reputation': 3133,
#   'Views': 412},
#  {'DisplayName': 'Cesar Romero',
#   'Location': 'Lara, Venezuela',
#   'Reputation': 2030,
#   'Views': 452},
#  {'DisplayName': 'DevMind', 'Location': '', 'Reputation': 5548, 'Views': 1063},
#  {'DisplayName': 'Triby', 'Location': '', 'Reputation': 25076, 'Views': 1885},
#  {'DisplayName': 'Bruno Sosa Fast Tag',
#   'Location': 'Montevideo, Uruguay',
#   'Reputation': 932,
#   'Views': 449},
#  {'DisplayName': 'Dariel Ramos Díaz de Villegas',
#   'Location': 'Cuba',
#   'Reputation': 4432,
#   'Views': 472},
#  {'DisplayName': 'Lobos',
#   'Location': 'El Salvador',
#   'Reputation': 16246,
#   'Views': 1197},
#  {'DisplayName': 'Luis Daniel Rovira Contreras',
#   'Location': 'Caracas, Distrito Capital, Venezuela',
#   'Reputation': 2696,
#   'Views': 414},
#  {'DisplayName': 'Alvarez',
#   'Location': 'Honduras',
#   'Reputation': 4007,
#   'Views': 785},
#  {'DisplayName': 'ret',
#   'Location': 'Basque Country, España',
#   'Reputation': 1938,
#   'Views': 379},
#  {'DisplayName': 'zerokira',
#   'Location': 'Medellín - Antioquia, Colombia',
#   'Reputation': 1915,
#   'Views': 363},
#  {'DisplayName': 'Lleims',
#   'Location': 'Mallorca, España',
#   'Reputation': 3119,
#   'Views': 312},
#  {'DisplayName': 'Luis Alfredo Serrano Díaz',
#   'Location': 'Caracas, Distrito Capital, Venezuela',
#   'Reputation': 1226,
#   'Views': 210},
#  {'DisplayName': 'Maru Amallo',
#   'Location': 'Buenos Aires, Argentina',
#   'Reputation': 1077,
#   'Views': 315},
#  {'DisplayName': 'E.Rawrdríguez.Ophanim',
#   'Location': 'Mx',
#   'Reputation': 1247,
#   'Views': 363},
#  {'DisplayName': 'David DPG',
#   'Location': 'Madrid, España',
#   'Reputation': 2463,
#   'Views': 230},
#  {'DisplayName': 'Silvestre Silva',
#   'Location': 'CDMX, México',
#   'Reputation': 1855,
#   'Views': 272},
#  {'DisplayName': 'Luis',
#   'Location': 'México',
#   'Reputation': 1609,
#   'Views': 213},
#  {'DisplayName': 'Manuco Bianco',
#   'Location': 'Tandil, Buenos Aires, Argentina',
#   'Reputation': 1212,
#   'Views': 275},
#  {'DisplayName': 'EduBw', 'Location': '', 'Reputation': 2164, 'Views': 300},
#  {'DisplayName': 'OCHOA',
#   'Location': 'Madrid',
#   'Reputation': 1790,
#   'Views': 228},
#  {'DisplayName': 'Bryro', 'Location': '', 'Reputation': 9051, 'Views': 730},
#  {'DisplayName': 'Xam', 'Location': 'Perú', 'Reputation': 899, 'Views': 426},
#  {'DisplayName': 'Jalkhov',
#   'Location': 'Tucupita, Delta Amacuro, Venezuela',
#   'Reputation': 582,
#   'Views': 326},
#  {'DisplayName': 'Rafael Bautista',
#   'Location': '/dev/sda1',
#   'Reputation': 2805,
#   'Views': 486},
#  {'DisplayName': 'AndyC',
#   'Location': 'Venezuela',
#   'Reputation': 1085,
#   'Views': 440},
#  {'DisplayName': 'diegoveloper',
#   'Location': 'Lima, Peru',
#   'Reputation': 7296,
#   'Views': 1342},
#  {'DisplayName': 'Kleith',
#   'Location': 'Buenos Aires, CABA, Argentina',
#   'Reputation': 3834,
#   'Views': 414},
#  {'DisplayName': 'David E. Luna M.',
#   'Location': 'Venezuela',
#   'Reputation': 2828,
#   'Views': 589},
#  {'DisplayName': 'srJJ', 'Location': '', 'Reputation': 1807, 'Views': 338},
#  {'DisplayName': 'Igmer Rodriguez',
#   'Location': 'El Salvador',
#   'Reputation': 4357,
#   'Views': 644},
#  {'DisplayName': 'J. Rodríguez',
#   'Location': 'República Dominicana',
#   'Reputation': 5280,
#   'Views': 555},
#  {'DisplayName': 'Roberto E Moran',
#   'Location': '',
#   'Reputation': 3469,
#   'Views': 240},
#  {'DisplayName': 'track3r',
#   'Location': 'Tortosa, Tarragona, España',
#   'Reputation': 1909,
#   'Views': 450},
#  {'DisplayName': 'Federico Madoery',
#   'Location': 'Santa Fe, Argentina',
#   'Reputation': 2888,
#   'Views': 250},
#  {'DisplayName': 'francisco dwq',
#   'Location': '',
#   'Reputation': 525,
#   'Views': 284},
#  {'DisplayName': 'FRANCISCO J. BLANCO',
#   'Location': 'Medellín, Antioquia, Colombia',
#   'Reputation': 2042,
#   'Views': 428},
#  {'DisplayName': 'Art_Code', 'Location': '', 'Reputation': 2455, 'Views': 328},
#  {'DisplayName': 'Santiago Arteaga',
#   'Location': 'Santa Cruz, Bolivia',
#   'Reputation': 1430,
#   'Views': 280},
#  {'DisplayName': 'Klaimmore',
#   'Location': 'Santiago, Chile',
#   'Reputation': 4040,
#   'Views': 413},
#  {'DisplayName': 'Julio', 'Location': '', 'Reputation': 3353, 'Views': 225},
#  {'DisplayName': 'E. Betanzos',
#   'Location': 'Mexico',
#   'Reputation': 4888,
#   'Views': 724},
#  {'DisplayName': 'Esei',
#   'Location': 'España',
#   'Reputation': 3716,
#   'Views': 502},
#  {'DisplayName': 'Diego L o L',
#   'Location': 'Águilas, España',
#   'Reputation': 1799,
#   'Views': 577},
#  {'DisplayName': 'Sebastián Lagos Yañez',
#   'Location': '',
#   'Reputation': 1533,
#   'Views': 391},
#  {'DisplayName': 'ivanao',
#   'Location': 'España',
#   'Reputation': 1134,
#   'Views': 606},
#  {'DisplayName': 'Juan Salvador Portugal',
#   'Location': 'Mendoza, Argentina',
#   'Reputation': 6635,
#   'Views': 705},
#  {'DisplayName': 'the-breaker',
#   'Location': 'La Paz, Bolivia/Chile',
#   'Reputation': 5440,
#   'Views': 914},
#  {'DisplayName': 'Levi Arista',
#   'Location': 'Cajamarca, Perú',
#   'Reputation': 2752,
#   'Views': 397},
#  {'DisplayName': 'Gastón Saillén',
#   'Location': 'Córdoba, Argentina',
#   'Reputation': 3283,
#   'Views': 556},
#  {'DisplayName': 'ASASCED',
#   'Location': 'Mexico City, CDMX, México',
#   'Reputation': 1243,
#   'Views': 204},
#  {'DisplayName': 'Kiko_L', 'Location': '', 'Reputation': 6535, 'Views': 418},
#  {'DisplayName': 'aeportugal',
#   'Location': 'Panama',
#   'Reputation': 9606,
#   'Views': 582},
#  {'DisplayName': 'alo Malbarez',
#   'Location': '',
#   'Reputation': 9308,
#   'Views': 2014},
#  {'DisplayName': 'alanfcm',
#   'Location': 'Guatemala / USA',
#   'Reputation': 20907,
#   'Views': 1777},
#  {'DisplayName': 'Diego Avila',
#   'Location': 'Ecuador',
#   'Reputation': 5456,
#   'Views': 763},
#  {'DisplayName': 'Jheyman Mejia',
#   'Location': 'Colombia',
#   'Reputation': 3922,
#   'Views': 848},
#  {'DisplayName': 'JDev', 'Location': '', 'Reputation': 2209, 'Views': 477},
#  {'DisplayName': 'Capt.Teach',
#   'Location': 'Alicante, España',
#   'Reputation': 1133,
#   'Views': 553},
#  {'DisplayName': 'josanangel',
#   'Location': '',
#   'Reputation': 2307,
#   'Views': 315},
#  {'DisplayName': 'vicasas', 'Location': '', 'Reputation': 1313, 'Views': 204},
#  {'DisplayName': 'Edgar Gc',
#   'Location': 'Xalapa-Enríquez, Veracruz, México',
#   'Reputation': 957,
#   'Views': 214},
#  {'DisplayName': 'Andres Gardiol',
#   'Location': 'San Juan, Argentina',
#   'Reputation': 1995,
#   'Views': 407},
#  {'DisplayName': 'HubertRonald',
#   'Location': '',
#   'Reputation': 3089,
#   'Views': 1043},
#  {'DisplayName': 'SuperG280',
#   'Location': '',
#   'Reputation': 1898,
#   'Views': 331},
#  {'DisplayName': 'quevedo',
#   'Location': 'Cajicá, Cundinamarca, Colombia',
#   'Reputation': 1215,
#   'Views': 455},
#  {'DisplayName': 'Luciano Montañez',
#   'Location': 'Buenos Aires, CABA, Argentina',
#   'Reputation': 2456,
#   'Views': 338},
#  {'DisplayName': 'porloscerros Ψ',
#   'Location': 'Argentina',
#   'Reputation': 6276,
#   'Views': 929},
#  {'DisplayName': 'Iñigo Irigoyen Erquicia',
#   'Location': 'San Sebastián, Spain',
#   'Reputation': 2023,
#   'Views': 263},
#  {'DisplayName': 'qwerty', 'Location': '', 'Reputation': 575, 'Views': 1341},
#  {'DisplayName': 'Cuauhtli',
#   'Location': 'México, CDMX, México',
#   'Reputation': 8214,
#   'Views': 464},
#  {'DisplayName': 'Manny',
#   'Location': 'Mexico',
#   'Reputation': 1133,
#   'Views': 210},
#  {'DisplayName': 'YemisiSCG',
#   'Location': 'Querétaro, Qro., México',
#   'Reputation': 1250,
#   'Views': 562},
#  {'DisplayName': 'David Leonardo Molina Ruiz Dav',
#   'Location': 'Caracas, Distrito Capital, Venezuela',
#   'Reputation': 4044,
#   'Views': 376},
#  {'DisplayName': 'Victor Perdomo',
#   'Location': 'Caracas, Distrito Capital, Venezuela',
#   'Reputation': 1936,
#   'Views': 233},
#  {'DisplayName': 'Miguel', 'Location': '', 'Reputation': 1443, 'Views': 315},
#  {'DisplayName': 'denifer santiago fernandez',
#   'Location': '',
#   'Reputation': 1056,
#   'Views': 214},
#  {'DisplayName': 'Emeeus',
#   'Location': 'Buenos Aires, Argentina',
#   'Reputation': 7408,
#   'Views': 382},
#  {'DisplayName': 'Fran Islas',
#   'Location': 'Santiago del Estero, Argentina',
#   'Reputation': 2379,
#   'Views': 219},
#  {'DisplayName': 'rpaillao',
#   'Location': 'Chile',
#   'Reputation': 1648,
#   'Views': 474},
#  {'DisplayName': 'enxaneta', 'Location': '', 'Reputation': 3828, 'Views': 253},
#  {'DisplayName': 'Layer', 'Location': '', 'Reputation': 6057, 'Views': 1124},
#  {'DisplayName': 'jcHernande2',
#   'Location': 'San Luis Potosí, México',
#   'Reputation': 3339,
#   'Views': 298},
#  {'DisplayName': 'Vick Muñoz',
#   'Location': 'Estado de México, México',
#   'Reputation': 2849,
#   'Views': 257},
#  {'DisplayName': 'g.4',
#   'Location': 'Mexico',
#   'Reputation': 3334,
#   'Views': 456},
#  {'DisplayName': 'Nicolas Oñate',
#   'Location': 'Madrid, España',
#   'Reputation': 3265,
#   'Views': 652},
#  {'DisplayName': 'cosito', 'Location': '', 'Reputation': 994, 'Views': 316},
#  {'DisplayName': 'Juan Perez',
#   'Location': '',
#   'Reputation': 530,
#   'Views': 234},
#  {'DisplayName': 'MrDave1999',
#   'Location': 'Medellín, Colombia',
#   'Reputation': 7586,
#   'Views': 1729},
#  {'DisplayName': 'Luis',
#   'Location': 'México',
#   'Reputation': 673,
#   'Views': 212},
#  {'DisplayName': 'Julio Cesar',
#   'Location': 'Quito, Ecuador',
#   'Reputation': 3280,
#   'Views': 415},
#  {'DisplayName': 'Orlando De La Rosa',
#   'Location': 'Panamá',
#   'Reputation': 3054,
#   'Views': 575},
#  {'DisplayName': 'unknow',
#   'Location': 'España',
#   'Reputation': 1493,
#   'Views': 575},
#  {'DisplayName': 'Rubiales Alberto',
#   'Location': 'Madrid, Spain',
#   'Reputation': 7723,
#   'Views': 875},
#  {'DisplayName': 'Riaven',
#   'Location': 'Chile',
#   'Reputation': 3417,
#   'Views': 633},
#  {'DisplayName': 'Javier Cake',
#   'Location': 'Spain',
#   'Reputation': 1493,
#   'Views': 312},
#  {'DisplayName': 'John',
#   'Location': 'Planeta tierra - Gmail',
#   'Reputation': 1472,
#   'Views': 260},
#  {'DisplayName': 'ArianJM',
#   'Location': 'Madrid, España',
#   'Reputation': 3409,
#   'Views': 263},
#  {'DisplayName': 'Víctor Álvarez',
#   'Location': 'Caracas, Distrito Capital, Venezuela',
#   'Reputation': 2624,
#   'Views': 253},
#  {'DisplayName': 'Panri93', 'Location': '', 'Reputation': 695, 'Views': 748},
#  {'DisplayName': 'Mauricio Contreras',
#   'Location': 'Barcelona, España',
#   'Reputation': 15819,
#   'Views': 3365},
#  {'DisplayName': 'Miguel Zarate',
#   'Location': 'Florida and CDMX',
#   'Reputation': 2395,
#   'Views': 401},
#  {'DisplayName': 'Lucas Damian',
#   'Location': 'Buenos Aires, Argentina',
#   'Reputation': 1988,
#   'Views': 306},
#  {'DisplayName': 'Luis Cazares',
#   'Location': 'Atlanta, GA, USA',
#   'Reputation': 11304,
#   'Views': 799},
#  {'DisplayName': 'David JP',
#   'Location': 'Santander, España',
#   'Reputation': 10783,
#   'Views': 1075},
#  {'DisplayName': 'D. Albarracín',
#   'Location': 'Sevilla, España',
#   'Reputation': 2180,
#   'Views': 344},
#  {'DisplayName': 'RazerJs',
#   'Location': 'Italy',
#   'Reputation': 2313,
#   'Views': 270},
#  {'DisplayName': 'LauraZ', 'Location': '', 'Reputation': 882, 'Views': 222},
#  {'DisplayName': 'jsdnlb',
#   'Location': 'Medellín, Antioquia, Colombia',
#   'Reputation': 2479,
#   'Views': 367},
#  {'DisplayName': 'BetaM', 'Location': '', 'Reputation': 31219, 'Views': 7873},
#  {'DisplayName': 'x3k', 'Location': '', 'Reputation': 3801, 'Views': 298},
#  {'DisplayName': 'VRoxa',
#   'Location': 'Barcelona, España',
#   'Reputation': 3070,
#   'Views': 277},
#  {'DisplayName': 'Excorpion',
#   'Location': 'Chile',
#   'Reputation': 4461,
#   'Views': 983},
#  {'DisplayName': 'Franqo Balsamo',
#   'Location': '',
#   'Reputation': 535,
#   'Views': 423},
#  {'DisplayName': 'L F',
#   'Location': 'Lima, Perú',
#   'Reputation': 554,
#   'Views': 259},
#  {'DisplayName': 'Jonatan Lavado',
#   'Location': 'Trujillo, Perú',
#   'Reputation': 3131,
#   'Views': 222},
#  {'DisplayName': 'Srsole',
#   'Location': 'Barcelona, España',
#   'Reputation': 1289,
#   'Views': 279},
#  {'DisplayName': 'Alexander Rodriguez',
#   'Location': 'Venezuela',
#   'Reputation': 2723,
#   'Views': 365},
#  {'DisplayName': 'Adrián Sanz Wallace',
#   'Location': 'Madrid, España',
#   'Reputation': 2353,
#   'Views': 206},
#  {'DisplayName': 'EJS',
#   'Location': 'Madrid, España',
#   'Reputation': 621,
#   'Views': 273},
#  {'DisplayName': 'Rafael Acosta',
#   'Location': 'España',
#   'Reputation': 4427,
#   'Views': 501},
#  {'DisplayName': 'ordago', 'Location': '', 'Reputation': 4777, 'Views': 645},
#  {'DisplayName': 'Agustin G.',
#   'Location': 'Argentina',
#   'Reputation': 2760,
#   'Views': 278},
#  {'DisplayName': 'Roger Torné',
#   'Location': 'Barcelona, Spain',
#   'Reputation': 7542,
#   'Views': 1173},
#  {'DisplayName': 'Lucía',
#   'Location': 'Madrid, España',
#   'Reputation': 1663,
#   'Views': 289},
#  {'DisplayName': 'Israel-ICM',
#   'Location': 'La Paz, Bolivia',
#   'Reputation': 3665,
#   'Views': 1195},
#  {'DisplayName': 'Javi fer2',
#   'Location': 'Asturias, España',
#   'Reputation': 6904,
#   'Views': 583},
#  {'DisplayName': 'Juan Carlos Guibovich',
#   'Location': 'Perú',
#   'Reputation': 3189,
#   'Views': 350},
#  {'DisplayName': 'FranAcuna',
#   'Location': 'San José, Costa Rica',
#   'Reputation': 4132,
#   'Views': 386},
#  {'DisplayName': 'Pablochaches',
#   'Location': 'Guatemala',
#   'Reputation': 2521,
#   'Views': 477},
#  {'DisplayName': 'Bicho',
#   'Location': 'Ecuador',
#   'Reputation': 1878,
#   'Views': 688},
#  {'DisplayName': 'Iria',
#   'Location': 'Edinburgh, UK',
#   'Reputation': 620,
#   'Views': 330},
#  {'DisplayName': 'Narciso Aifuz',
#   'Location': 'Paraguay',
#   'Reputation': 1686,
#   'Views': 211},
#  {'DisplayName': 'Arriel',
#   'Location': 'Managua, Nicaragua',
#   'Reputation': 1222,
#   'Views': 429},
#  {'DisplayName': 'padaleiana',
#   'Location': 'Colonias Unidas, Paraguay',
#   'Reputation': 2760,
#   'Views': 2498},
#  {'DisplayName': 'iqanansoft',
#   'Location': '',
#   'Reputation': 541,
#   'Views': 333},
#  {'DisplayName': 'hawks',
#   'Location': 'Barcelona, España',
#   'Reputation': 3530,
#   'Views': 326},
#  {'DisplayName': 'Ramiro Barone',
#   'Location': 'Córdoba, Argentina',
#   'Reputation': 2803,
#   'Views': 582},
#  {'DisplayName': 'Learning Developer',
#   'Location': 'Madrid, España',
#   'Reputation': 1101,
#   'Views': 234},
#  {'DisplayName': 'Dante S.',
#   'Location': '',
#   'Reputation': 7056,
#   'Views': 1070},
#  {'DisplayName': 'Mateo', 'Location': '', 'Reputation': 8438, 'Views': 1205},
#  {'DisplayName': 'HeytalePazguato',
#   'Location': 'Japan',
#   'Reputation': 10821,
#   'Views': 1626},
#  {'DisplayName': 'Ariel Montes',
#   'Location': 'Como, CO, Italy',
#   'Reputation': 2404,
#   'Views': 355},
#  {'DisplayName': 'Adrian', 'Location': '', 'Reputation': 3496, 'Views': 525},
#  {'DisplayName': 'Juan Rivera',
#   'Location': '',
#   'Reputation': 1529,
#   'Views': 313},
#  {'DisplayName': 'Candid Moe',
#   'Location': 'Springfield',
#   'Reputation': 25649,
#   'Views': 3527},
#  {'DisplayName': 'Christian',
#   'Location': 'Osaka',
#   'Reputation': 10104,
#   'Views': 2738},
#  {'DisplayName': 'gaidyjg', 'Location': '', 'Reputation': 764, 'Views': 234},
#  {'DisplayName': 'Jaime Menendez',
#   'Location': 'Cape Coral, Florida, United States.',
#   'Reputation': 7227,
#   'Views': 947},
#  {'DisplayName': 'eftshift0',
#   'Location': 'Netherlands',
#   'Reputation': 3244,
#   'Views': 342},
#  {'DisplayName': 'Javier G.Raya',
#   'Location': 'Ceuta, España',
#   'Reputation': 1981,
#   'Views': 379},
#  {'DisplayName': 'Benito-B',
#   'Location': 'Valencia, España',
#   'Reputation': 4042,
#   'Views': 1641},
#  {'DisplayName': 'Japv',
#   'Location': 'La Habana, Cuba',
#   'Reputation': 11587,
#   'Views': 1069},
#  {'DisplayName': 'Pollo',
#   'Location': 'La Plata, Argentina',
#   'Reputation': 2490,
#   'Views': 261},
#  {'DisplayName': 'Sinner of the System',
#   'Location': 'Argentina',
#   'Reputation': 4960,
#   'Views': 472},
#  {'DisplayName': 'ricardo-dlc',
#   'Location': 'Cancún, Q.R., México',
#   'Reputation': 1916,
#   'Views': 272},
#  {'DisplayName': 'Daniel Briceño',
#   'Location': 'Venezuela',
#   'Reputation': 850,
#   'Views': 278},
#  {'DisplayName': 'Rodrigo Ramírez',
#   'Location': 'Perú',
#   'Reputation': 6149,
#   'Views': 1192},
#  {'DisplayName': 'Desarrollos-Web-Urquiza',
#   'Location': '',
#   'Reputation': 1601,
#   'Views': 600},
#  {'DisplayName': 'Luis S. Romero',
#   'Location': 'Uruguay',
#   'Reputation': 3239,
#   'Views': 257},
#  {'DisplayName': 'Eduardo Jiménez',
#   'Location': '',
#   'Reputation': 2177,
#   'Views': 213},
#  {'DisplayName': 'infinit3Loop__',
#   'Location': 'Buenos Aires, Argentina',
#   'Reputation': 2986,
#   'Views': 282},
#  {'DisplayName': 'el.trasgu',
#   'Location': 'Astúries, España',
#   'Reputation': 3129,
#   'Views': 249},
#  {'DisplayName': 'icatalan',
#   'Location': 'Spain',
#   'Reputation': 665,
#   'Views': 504},
#  {'DisplayName': 'Dramaturgo',
#   'Location': 'Peruvian',
#   'Reputation': 3687,
#   'Views': 405},
#  {'DisplayName': 'José Carlos PHP',
#   'Location': 'Spain',
#   'Reputation': 1420,
#   'Views': 217},
#  {'DisplayName': 'Cris223511.dev',
#   'Location': 'La Molina, Lima, Perú',
#   'Reputation': 9194,
#   'Views': 1019},
#  {'DisplayName': 'masterguru',
#   'Location': '',
#   'Reputation': 15789,
#   'Views': 2016},
#  {'DisplayName': 'DFG', 'Location': '', 'Reputation': 575, 'Views': 201},
#  {'DisplayName': 'Yussef', 'Location': '', 'Reputation': 17450, 'Views': 2140}]

# %% [markdown]
# ## EJERCICIO 2: Listar todos post que son preguntas y sus votos asociados. Para ello, se permite definir los indices que se consideren adecuados.
#
# *Ejemplo*: Suponiendo que el post con `_id` `65e6f1c8d93b356db73e5433` tuviera tres votos asociados, la solución debe devolver una salida de en este formato (nótese que los campos `CreationDate`, `Score` e `_id` se refieren al mismo post):
#
# ```json
# {'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   '_id': ObjectId('65e6f1c8d93b356db73e5433'),
#   'post_votes': {'VoteTypeId': 2}},
#  {'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   '_id': ObjectId('65e6f1c8d93b356db73e5433'),
#   'post_votes': {'VoteTypeId': 2}},
#  {'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   '_id': ObjectId('65e6f1c8d93b356db73e5433'),
#   'post_votes': {'VoteTypeId': 16}}
# ```

# %%
# prompt: con este enunciado necesito que me digas si la consulta de abajo está bien, porque me tarda mucho:
# EJERCICIO 2: Listar todos post que son preguntas y sus votos asociados. Para ello, se permite definir los indices que se consideren adecuados.
# Ejemplo: Suponiendo que el post con _id 65e6f1c8d93b356db73e5433 tuviera tres votos asociados, la solución debe devolver una salida de en este formato (nótese que los campos CreationDate, Score e _id se refieren al mismo post):
# {'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   '_id': ObjectId('65e6f1c8d93b356db73e5433'),
#   'post_votes': {'VoteTypeId': 2}},
#  {'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   '_id': ObjectId('65e6f1c8d93b356db73e5433'),
#   'post_votes': {'VoteTypeId': 2}},
#  {'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   '_id': ObjectId('65e6f1c8d93b356db73e5433'),
#   'post_votes': {'VoteTypeId': 16}}
# question_votes: CommandCursor[dict[str, Any]] = db.posts.aggregate([
#     {"$match": {"PostTypeId": 1}},
#     {"$lookup": {
#         "from": "votes",
#         "localField": "Id",
#         "foreignField": "PostId",
#         "as": "post_votes"
#     }},
#     {"$unwind": "$post_votes"},
#     {"$project": {
#         "_id": 1,
#         "CreationDate": 1,
#         "Score": 1,
#         "post_votes": "$post_votes"
#     }}
# ])
# list(question_votes)

# Create index on votes.PostId for faster lookups
db.votes.create_index([("PostId", 1)])

question_votes: CommandCursor[dict[str, Any]] = db.posts.aggregate([
    {"$match": {"PostTypeId": 1}},
    {"$lookup": {
        "from": "votes",
        "localField": "Id",
        "foreignField": "PostId",
        "as": "post_votes"
    }},
    {"$unwind": "$post_votes"},
    {"$project": {
        "_id": 1,
        "CreationDate": 1,
        "Score": 1,
        "post_votes": "$post_votes"
    }}
])
list(question_votes)
# Out:
# [{'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc77533197d'),
#    'Id': 1,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2015, 10, 29, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc775331984'),
#    'Id': 9,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2015, 10, 30, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc775331985'),
#    'Id': 10,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2015, 10, 30, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 16}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc7753319a7'),
#    'Id': 48,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2015, 11, 2, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 16}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc775331ae2'),
#    'Id': 391,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2015, 12, 1, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc7753326b8'),
#    'Id': 3761,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2015, 12, 14, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc7753336ae'),
#    'Id': 8248,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2016, 1, 12, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778e3e772cc775334084'),
#    'Id': 11084,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2016, 1, 30, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9778f3e772cc77533ac8e'),
#    'Id': 45589,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2016, 9, 5, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977913e772cc77534833f'),
#    'Id': 114810,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2017, 3, 21, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977913e772cc77534ba0b'),
#    'Id': 132428,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2017, 4, 27, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977943e772cc775359663'),
#    'Id': 201739,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2017, 10, 4, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977953e772cc7753604d1'),
#    'Id': 234359,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 1, 5, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977963e772cc7753652f9'),
#    'Id': 257561,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 3, 2, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977973e772cc77536dd50'),
#    'Id': 299468,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 5, 18, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977973e772cc77537213d'),
#    'Id': 319516,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 7, 12, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977983e772cc7753765ab'),
#    'Id': 339586,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 9, 4, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977983e772cc77537668a'),
#    'Id': 339827,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 9, 4, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977983e772cc775376e62'),
#    'Id': 342051,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 9, 9, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977993e772cc77537e244'),
#    'Id': 375886,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2018, 11, 27, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c977993e772cc775386631'),
#    'Id': 415994,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 2, 27, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779a3e772cc775388f59'),
#    'Id': 427895,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 3, 26, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779a3e772cc77538a34f'),
#    'Id': 433744,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 4, 8, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779a3e772cc77538bb6a'),
#    'Id': 440720,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 4, 23, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779a3e772cc77538c055'),
#    'Id': 443112,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 4, 25, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779b3e772cc775393313'),
#    'Id': 476543,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 7, 7, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779b3e772cc775393a3e'),
#    'Id': 478724,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 7, 11, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779c3e772cc77539a76b'),
#    'Id': 511736,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 9, 23, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779c3e772cc77539ab11'),
#    'Id': 512773,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 9, 25, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779c3e772cc77539abfa'),
#    'Id': 513048,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 9, 25, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779c3e772cc77539ad59'),
#    'Id': 513447,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 9, 26, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779c3e772cc77539c692'),
#    'Id': 520978,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 10, 13, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779d3e772cc7753a28dd'),
#    'Id': 550928,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2019, 12, 21, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c9779f3e772cc7753b939f'),
#    'Id': 663211,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2020, 10, 15, 0, 0),
#    'PostId': 1,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f664'),
#   'CreationDate': datetime.datetime(2015, 10, 29, 15, 56, 52, 933000),
#   'Score': 40,
#   'post_votes': {'_id': ObjectId('67c

#    'UserId': '',
#    'VoteTypeId': 2}},
#  {'_id': ObjectId('67c9773d3e772cc77527f6cc'),
#   'CreationDate': datetime.datetime(2015, 12, 1, 20, 17, 56, 463000),
#   'Score': 20,
#   'post_votes': {'_id': ObjectId('67c9778f3e772cc77533de4f'),
#    'Id': 61844,
#    'BountyAmount': '',
#    'CreationDate': datetime.datetime(2016, 10, 26, 0, 0),
#    'PostId': 129,
#    'UserId': '',
#    'VoteTypeId': 2}},
#  ...]

# %% [markdown]
# ## EJERCICIO 3: Listar los nombres de usuarios (campo `DisplayName` de `users`) que tienen más preguntas que respuestas
#
# (Contando los usuarios debe salir exactamente 54483 usuarios).

# %%
usuarios_mas_preguntas = db.posts.aggregate([
    {
        '$group': {
            '_id': '$OwnerUserId',
            'preguntas': { '$sum': { "$cond": { "if" : { "$eq" : [ "$PostTypeId", 1 ]}, "then" : 1, "else" : 0 }} },
            'respuestas': { '$sum': { "$cond": { "if" : { "$eq" : [ "$PostTypeId", 2 ]}, "then" : 1, "else" : 0 }} }
        }
    },
    { '$match': { '$expr': { '$gt': [ '$preguntas', '$respuestas' ] } } },
    {
        '$lookup': {
            'from': "users",
            'localField': "_id",
            'foreignField': "Id",
            'as': "user"
        }
    },
    { '$unwind': '$user' },
    { '$project': { '_id': 0, 'DisplayName': '$user.DisplayName' } }
])
len(list(usuarios_mas_preguntas))
# Out:
# 54483

# %% [markdown]
# ## EJERCICIO 4: Comprobad, de forma similar a los ejemplos anteriores, que el campo `CommentCount` de `Posts` es correcto, comprobándolo con la colección `Comments`. Definid los índices necesarios.
#
# El resultado de la consulta de los números de comentarios que difieren debe ser vacío como en el ejemplo de los votos anterior.

# %%
# prompt: EJERCICIO 4: Comprobad, de forma similar a los ejemplos anteriores, que el campo CommentCount de Posts es correcto, comprobándolo con la colección Comments. Definid los índices necesarios.
# El resultado de la consulta de los números de comentarios que difieren debe ser vacío como en el ejemplo de los votos anterior. hazlo de manera mas sencilla y legible posible con un formato similar a esto :avg_answer_time: CommandCursor[dict[str,Any]] = db.posts.aggregate([
#     { "$match" : {"PostTypeId" : 2} },
#     { '$group' : {
#         '_id' : '$ParentId',
#         # 'answers' : { '$push' : {'Id' : "$Id", 'CreationDate' : "$CreationDate"}},
#         'min' : {'$min' : "$CreationDate"}
#       }
#     },
#     { "$lookup" : {
#         'from': "posts",
#         'localField': "_id",
#         'foreignField': "Id",
#         'as': "post"}
#     },
#     { "$unwind" : "$post"},
#     { "$project" : {
#         "_id" : True,
#         "min" : True,
#         "diff" : {"$subtract" : ["$min", "$post.CreationDate"]}
#       }
#     },
#     #    { "$sort" : {'_id' : 1} }
#     {
#       "$group" :  {
#         "_id" : None,
#         "avg" : { "$avg" : "$diff"}
#       }
#     }
# ])
# avg_answer_time = list(avg_answer_time)
# avg_answer_time

db.comments.create_index([("PostId", HASHED)])

comment_count_comp: CommandCursor[dict[str, Any]] = db.posts.aggregate([
    {
        "$lookup": {
            "from": "comments",
            "localField": "Id",
            "foreignField": "PostId",
            "as": "comments"
        }
    },
    {
        "$project": {
            "_id": 0,
            "Id": 1,
            "CommentCount": 1,
            "calculated_comment_count": {"$size": "$comments"}
        }
    },
    {
        "$match": {
            "$expr": {
                "$ne": ["$CommentCount", "$calculated_comment_count"]
            }
        }
    }
])

list(comment_count_comp)
# Out:
# []
