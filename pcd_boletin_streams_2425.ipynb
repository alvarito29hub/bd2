# %% [markdown]
# <a href="https://colab.research.google.com/github/alvarito29hub/bd2/blob/main/pcd_boletin_streams_2425.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROGRAMACIÓN PARA CIENCIA DE LOS DATOS -- CURSO 2024-2025
# ## Boletín de prácticas - Procesamiento de streams
# ### 0. Introduccion
# En este boletín vamos a practicar los tres tipos de streams vistos en a clase de teoría,
# * El módulo `io`
# * El módulo `asyncio`
# * `Apache Kafka`
#
# Al final del boletín encontraréis unos ejercicios a realizar de forma individual de cara a repasar los conceptos vistos en la sesión de prácticas.

# %% [markdown]
# ### 1. El módulo `io`

# %% [markdown]
# #### 1.1 Operaciones básicas
#
# Al igual que lo que hacemos con las variables, los datos se pueden guardar como bytes en un buffer en memoria cuando utilizamos las operaciones `BytesIO` del módulo `io`.

# %%
import io
import time

stream_str = io.BytesIO(b"Esto es un ejemplo muy sencillo de BytesIO")
print(stream_str.getvalue())
# Out:
# b'Esto es un ejemplo muy sencillo de BytesIO'

# %% [markdown]
# Si queremos codificar la salida del stream a un formato de concreto podemos usar el método `decode` especificando el formato de codificación del texto.

# %%
print(stream_str.getvalue().decode('utf-8'))
# Out:
# Esto es un ejemplo muy sencillo de BytesIO

# %% [markdown]
# Vamos ahora a usar un stream de tipo `StringIO`. Vemos que podemos usar la función `print` especificando el parámetro `file` para escribir sobre un fichero `in-memory`.

# %%
data = io.StringIO()
data.write('Inicio del stream StringIO: ')
print('Python.', file=data)

print(data.getvalue())

data.close()
# Out:
# Inicio del stream StringIO: Python.

# %% [markdown]
# Vamos a crear ahora un stream binario a un fichero (`test.dat`) y vamos a realizar una escritura sobre el mismo.

# %%
begin = time.time()
with open("test.dat", "wb") as f:
  for i in range(0,50000):
    f.write(b"Hola Mundo")
end= time.time()
segundos = end-begin
print("Escritura fichero:",segundos)
# Out:
# Escritura fichero: 0.015816926956176758

# %% [markdown]
# Al terminar de ejecutar la celda de arriba, vemos que en nuestro directorio de archivos se ha creado un fichero con el nombre especificado.
#
# Ahora podemos hacer lo mismo pero usando un stream en memoria en vez de uno directamente a un fichero.

# %%
with io.BytesIO() as f:
  for i in range(0,50000):
    f.write(b"Hola Mundo")

# %% [markdown]
# En ambos casos estamos escribiendo sobre un stream binario, salvo que uno va a parar a un fichero `test.dat` y el otro está alojado en la memoria RAM de la máquina.
#
# #### 1.2 Eficiencia
# ¿Cuál es entonces la diferencia? Vamos comprobar la eficiencia de usar streams `BytesIO` respecto a usar un stream a fichero (disco).

# %%
begin = time.time()
buffer = b""
for i in range(0,50000):
  buffer += b"Hola Mundo"
end = time.time()
segundos = end-begin
print("Concatenacion:", segundos)
# Out:
# Concatenacion: 0.37927985191345215

# %%
begin = time.time()
buffer = io.BytesIO()
for i in range(0,50000):
  buffer.write(b"Hola Mundo")
end= time.time()
segundos = end-begin
buffer.close()
print("BytesIO:",segundos)
# Out:
# BytesIO: 0.0058994293212890625

# %% [markdown]
# Como vemos el performance es sensiblemente superior si usamos `BytesIO` que la concatenación directa.
#
# Esto, por ejemplo, permitiría otra forma de escritura a ficheros

# %%
begin = time.time()
buffer = io.BytesIO()
for i in range(0,50000):
  buffer.write(b"Hola Mundo")

with open("test_bufferio.dat", "wb") as f:
  f.write(buffer.getvalue())
end= time.time()
segundos = end-begin
print("Escritura fichero con BytesIO:",segundos)
# Out:
# Escritura fichero con BytesIO: 0.005679130554199219

# %% [markdown]
# #### 1.3 Manipulación streams de fuentes de datos remotas
#
# Vamos a ver cómo podriamos usar los streams `BytesIO` para poder procesar una imagen en lugar de almacenarla en un fichero.
#
# En primer lugar vamos a descargarnos una imagen con el escudo de la UPCT.

# %%
from PIL import Image
import requests
import io

response = requests.get("https://www.upct.es/contenido/universidad/galeria/identidad-2021/logos/logos-escuelas-upct-eut/Caminos_upct_eut_1.png")

# %% [markdown]
# Creamos un stream `BytesIO` a partir de los datos de la imagen descargada

# %%
image_stream = io.BytesIO(response.content)

# %% [markdown]
# Abrimos la imagen utilizando la librería PIL (`Python Imaging Library`)

# %%
image = Image.open(image_stream)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=4726x1446>

# %% [markdown]
# Rotamos la imagen 90 grados en sentido antihorario

# %%
rotated_image = image.rotate(90)
rotated_image
# Out:
# <PIL.Image.Image image mode=RGBA size=4726x1446>

# %% [markdown]
# Creamos un nuevo stream `BytesIO` para guardar la imagen rotada

# %%
rotated_image_stream = io.BytesIO()

# %% [markdown]
# Guardamos la imagen rotada en formato `png` en el nuevo stream `BytesIO`

# %%
rotated_image.save(rotated_image_stream, format='PNG')

# %% [markdown]
# Guardamos también la imagen rotada en un archivo en disco (solo para comparación)

# %%
rotated_image.save("rotated_image.png", format='PNG')

# %% [markdown]
# Obtenemos los datos de la imagen rotada como bytes

# %%
rotated_image_data = rotated_image_stream.getvalue()

# %% [markdown]
# Por último, comparamos el tamaño de los datos de la imagen en disco con los datos en memoria

# %%
import os
rotated_image_file_stats= os.stat("rotated_image.png")
print("Tamaño de la imagen rotada en disco:", rotated_image_file_stats.st_size, "bytes")
print("Tamaño de la imagen rotada en memoria:", len(rotated_image_data), "bytes")
# Out:
# Tamaño de la imagen rotada en disco: 66566 bytes
# Tamaño de la imagen rotada en memoria: 66566 bytes

# %% [markdown]
# #### 1.4 Manejo de punteros
#
# En los streams también podemos controlar los punteros que indican qué datos leer de un stream.

# %%
initial_text = "Esto es un ejemplo de texto para usar con StringIO en Python."

# %% [markdown]
# Creamos un stream `StringIO` a partir del texto inicial

# %%
text_stream = io.StringIO(initial_text)

# %% [markdown]
# Leemos los primeros 20 caracteres del stream

# %%
parte1 = text_stream.read(20)
print("Primera parte del contenido:", parte1)
# Out:
# Primera parte del contenido: Esto es un ejemplo d

# %% [markdown]
# Obtenemos la posición actual del puntero

# %%
posicion_actual = text_stream.tell()
print("Posición actual del puntero:", posicion_actual)
# Out:
# Posición actual del puntero: 20

# %% [markdown]
# Movemos el puntero al inicio del stream

# %%
text_stream.seek(0)
# Out:
# 0

# %% [markdown]
# Leemos los siguientes 15 caracteres del stream desde el principio

# %%
parte2 = text_stream.read(15)
print("Segunda parte del contenido:", parte2)
# Out:
# Segunda parte del contenido: Esto es un ejem

# %% [markdown]
# Obtenemos la nueva posición del puntero

# %%
nueva_posicion = text_stream.tell()
print("Nueva posición del puntero:", nueva_posicion)
# Out:
# Nueva posición del puntero: 15

# %% [markdown]
# ### 2. El módulo `asyncIO`

# %% [markdown]
# A fin de practicar con las corutinas en primer lugar vamos a crear una muy sencilla que simplemente *duerme* durante 1 segundo y a continuación se imprime un mensaje.

# %% [markdown]
# #### 2.1 Creación de corutinas

# %%
import asyncio

async def mi_corutina():
    # Código asincrónico
    await asyncio.sleep(1)
    return "¡Hola, soy una corutina!"

# %% [markdown]
# En un entorno Python *tradicional* la forma de invocar a dicha corutina sería mediante el siguiente código.

# %%
resultado = asyncio.run(mi_corutina())
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 resultado = asyncio.run(mi_corutina())
#       2 print(resultado)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# ¿Qué ha fallado? Pues que en un notebook el código ya se ejecuta en un bucle de eventos (`event loop`) al estar en un Jupyer Notebook. Por tanto, la forma correcta de invocar a dicha corutina es mediante la siguiente instrucción.

# %%
await mi_corutina()
# Out:
# '¡Hola, soy una corutina!'

# %% [markdown]
# Por otro lado, las corutinas pueden esperar otras corutinas usando
# el comando `await`
#
# Vamos a crear una segunda corutina que espera a obtener el resulado de `mi_corutina` afin de mostrar un mensaje por pantalla.

# %%
async def corutina_principal():
    resultado = await mi_corutina()
    print("He recibido::", resultado)

await corutina_principal()
# Out:
# He recibido:: ¡Hola, soy una corutina!

# %% [markdown]
# También podemos ejecutar

# %%
async def corutina_1():
    await asyncio.sleep(1)
    print("Corutina 1 terminada")

async def corutina_2():
    await asyncio.sleep(2)
    print("Corutina 2 terminada")

async def correr_corutinas():
    await asyncio.gather(corutina_1(), corutina_2())

await correr_corutinas()
# Out:
# Corutina 1 terminada
# Corutina 2 terminada

# %% [markdown]
# #### 2.2 Ejemplo avanzado
#
# Vamos a ver un ejemplo de uso de corutinas para procesar un texto muy largo de forma paralela.

# %%
async def procesar_texto(texto):
    print("Iniciando procesamiento de texto")
    # Simulamos un procesamiento intensivo del texto
    await asyncio.sleep(3)
    texto_procesado = texto.upper()
    print("Procesamiento de texto finalizado")
    return texto_procesado

async def procesar_texto_en_paralelo(texto):
    # Creamos varias corutinas para procesar el texto simultáneamente
    corutina_1 = procesar_texto(texto[:10])
    corutina_2 = procesar_texto(texto[10:25])
    corutina_3 = procesar_texto(texto[25:])

    # Ejecutamos las corutinas simultáneamente
    resultados = await asyncio.gather(corutina_1, corutina_2, corutina_3)

    return resultados

async def main():
    # Supongamos que tenemos un texto muy largo
    texto_largo = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Fusce pretium est a magna vestibulum, eget consequat orci sollicitudin."

    # Procesamos el texto utilizando múltiples corutinas en paralelo
    resultados = await procesar_texto_en_paralelo(texto_largo)

    # Imprimimos los resultados
    for i, resultado in enumerate(resultados, start=1):
        print(f"Texto procesado {i}:", resultado[:50], "...")
        print(f"Longitud del texto procesado {i}:", len(resultado))

# Recuerda que si quisieras ejecutar este código en un entorno fuera del un Jupyter notebook deberias ejecutarl
#asyncio.run(main())

await main()
# Out:
# Iniciando procesamiento de texto
# Iniciando procesamiento de texto
# Iniciando procesamiento de texto
# Procesamiento de texto finalizado
# Procesamiento de texto finalizado
# Procesamiento de texto finalizado
# Texto procesado 1: LOREM IPSU ...
# Longitud del texto procesado 1: 10
# Texto procesado 2: M DOLOR SIT AME ...
# Longitud del texto procesado 2: 15
# Texto procesado 3: T, CONSECTETUR ADIPISCING ELIT. FUSCE PRETIUM EST  ...
# Longitud del texto procesado 3: 103

# %% [markdown]
# ### 3. Apache Kafka

# %% [markdown]
# #### 3.1 Instalación de los paquetes `kafka`
#
# En primer lugar vamos a instalar la librería `kafka-python` que es la que nos va a permitir usar el framework de kafka a través de Python.

# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.1.4-py2.py3-none-any.whl.metadata (9.1 kB)
# Downloading kafka_python-2.1.4-py2.py3-none-any.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.6/276.6 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.1.4

# %% [markdown]
# #### 3.2 Descargamos e instalamos las instancias Kafka and Zookeeper instances
#
# En este boletín instalaremos y ejecutaremos las siguientes instancias:
#
# - Kafka (Brokers: 127.0.0.1:9092)
# - Zookeeper (Node: 127.0.0.1:2181)

# %%
# !curl -sSOL https://archive.apache.org/dist/kafka/3.6.2/kafka_2.13-3.6.2.tgz
# !tar -xzf kafka_2.13-3.6.2.tgz

# %%
# !./kafka_2.13-3.6.2/bin/zookeeper-server-start.sh -daemon ./kafka_2.13-3.6.2/config/zookeeper.properties
# !./kafka_2.13-3.6.2/bin/kafka-server-start.sh -daemon ./kafka_2.13-3.6.2/config/server.properties
# !echo "Esperamos 10 segundos hasta que los servicios kafka y zookeeper estén activos y funcionando"
# !sleep 10
# Out:
# Esperamos 10 segundos hasta que los servicios kafka y zookeeper estén activos y funcionando

# %% [markdown]
# Una vez que se han iniciado las instancias como procesos *demonio* en el servidor, ejecutarmos el comando `grep` para obtener el listado de procesos en el servidor y ver que efectivamente tenemos los servicios zookeeper y kafka activados.

# %%
# !ps -ef | grep kafka
# Out:
# root       16177     816  0 08:56 ?        00:00:00 /bin/bash -c ps -ef | grep kafka
# root       16179   16177  0 08:56 ?        00:00:00 grep kafka

# %% [markdown]
# Creamos el tópico kafka con el que vamos a trabajar, en este caso lo vamos a llamar `netflix`

# %%
# !./kafka_2.13-3.6.2/bin/kafka-topics.sh --create --topic netflix --bootstrap-server localhost:9092
# Out:
# Error while executing topic command : Topic 'netflix' already exists.
# [2025-04-03 08:56:22,283] ERROR org.apache.kafka.common.errors.TopicExistsException: Topic 'netflix' already exists.
#  (kafka.admin.TopicCommand$)

# %% [markdown]
# Obtenemos una descripción del tópico recién creado.

# %%
# !./kafka_2.13-3.6.2/bin/kafka-topics.sh --describe --bootstrap-server 127.0.0.1:9092  --topic netflix
# Out:
# Topic: netflix	TopicId: ZcvV7nJMQbGvKBXs6dgiBg	PartitionCount: 1	ReplicationFactor: 1	Configs:
# 	Topic: netflix	Partition: 0	Leader: 0	Replicas: 0	Isr: 0

# %% [markdown]
# #### 3.3 Productor
#
# Vamos ahora a crear el productor para nuestro escenario. Dicho productor va a simular la evolución en tiempo real del precio de las acciones de *Netflix* en la bolsa.

# %%
nombre_topico='netflix'

# %% [markdown]
# El código de dicho productor se encuentra en el fichero `producer.py` que puedes descargarte del aula virtual junto con el fichero `NFLX.csv`
#
# Sube ambos ficheros a *Google Collab* en el directorio raiz.
#
# Vamos a visualizar su contenido, en donde podemos ver que dicho productor va leyendo línea por línea el fichero `NFLX.csv` con el valor de las acciones y las va lanzando al broker Kafka asociado al tópico `netflix`.

# %%
# !cat producer.py
# Out:
# # producer.py
# from kafka import KafkaProducer  # Para enviar mensajes a Kafka
# import time                      # Para hacer pausas entre envíos
# import json                      # Para convertir los datos a formato JSON
# import pandas as pd              # Para leer y manipular el archivo CSV
# import sys                       # Para recibir argumentos desde la línea de comandos
#
# #Reader es una clase que lee un archivo CSV y lo almacena en self.data.
# #Se inicializa con file_name (nombre del archivo CSV).
# class Reader:
#     def __init__(self, file_name):
#         self.file_name = file_name
#         self.data = pd.DataFrame()
#         self.read_file()
#         self.process_data()
#
#     #Lee el archivo CSV
#     #Usa pd.read_csv() para leer el CSV.
#     #sep=',' Indica que los valores están separados por comas.
#     #header='infer' Detecta automáticamente los encabezados.
#     #encoding='iso-8859-1' Usa esta codificación (útil si hay caracteres especiales).
#     def read_file(self):
#         self.data = pd.read_csv(self.file_name,
#                                 sep=',',
#                                 header='infer',
#                                 encoding='iso-8859-1')
#
#     # Procesa los datos
#     def process_data(self):
#         columns_tmp = self.data.columns
#         #Convierte los nombres de las columnas a minúsculas.
#         columns_tmp = [column_name.lower() for column_name in columns_tmp]
#         self.data.columns = columns_tmp
#         #Renombra algunas columnas
#         self.data.rename(columns={'open': 'open_price',
#                                   'close': 'close_price',
#                                   'adj close': 'adj_close'}, inplace=True)
#
#
# #Produce mensajes a Kafka
# class Producer:
#     #file_name  Archivo CSV que se va a leer.
#     #topic  El nombre del topic en Kafka al que se enviarán los datos.
#     #freq Frecuencia (en segundos) entre cada mensaje enviado.
#     def __init__(self, file_name, topic, freq):
#         self.topic = topic
#         self.freq = freq if isinstance(freq, int) else int(freq)
#         #Configura KafkaProducer: Convierte los datos en JSON codificado en UTF-8 antes de enviarlos.
#         self.producer = KafkaProducer(bootstrap_servers='localhost:9092',
#                                       value_serializer=lambda x: json.dumps(x).encode('utf-8'))
#         #Se usa la clase Reader para leer y procesar los datos del CSV
#         self.reader = Reader(file_name)
#
#     #Envía los datos a Kafka
#     def start_write(self):
#         #Recorre cada fila del CSV
#         for index, value in self.reader.data.iterrows():
#             dict_data = dict(value)  #Convierte la fila en un diccionario
#             self.producer.send(self.topic, value=dict_data) #Envía el mensaje a Kafka en el topic especiifcado
#             print(f'Message {index + 1}: {dict_data}')  #Muestra en pantalla el número del mensaje y su contenido.
#             time.sleep(self.freq)  #Espera un tiempo antes de enviar el siguiente mensaje
#
#
# if __name__ == '__main__':
#     #sys.argv[1] : Nombre del archivo CSV.
#     #sys.argv[2] : Nombre del topic en Kafka.
#     #sys.argv[3] : Frecuencia de envío de mensajes.
#     producer = Producer(sys.argv[1], sys.argv[2], sys.argv[3])
#     producer.start_write()

# %% [markdown]
# Ahora vamos a ejecutar dicho productor en segundo plano para simular el envio asíncrono y en tiempo real de los valores bursátiles de *Netflix*.
#
# Para ello, hacemos uso del comando `nohup` de Linux.

# %%
# !nohup python -m producer NFLX.csv netflix 5 &
# Out:
# nohup: appending output to 'nohup.out'

# %% [markdown]
# Podemos visualizar por consola los mensajes que dicho productor ya ha enviado al broker asociados al tópico `netflix` usando el script `kafka-console-consumer.sh`

# %%
# !./kafka_2.13-3.6.2/bin/kafka-console-consumer.sh --topic netflix --from-beginning --bootstrap-server localhost:9092
# Out:
# {"date": "2023-02-16", "open_price": 355.0, "high": 361.5, "low": 350.309998, "close_price": 350.709991, "adj_close": 350.709991, "volume": 5215700}
# Processed a total of 1 messages

# %% [markdown]
# #### 3.4 Consumidor
#
# El consumidor vamos a implementarlo como una clase muy sencilla que usa la clase `KafkaConsumer`para definir un cosumidor sobre el tópico `netflix` y en el que su método  `receive_message` se encarga de ir imprimiendo por pantalla cada nuevo mensaje leido y almacenandolo en una lista en su atributo `data`.

# %%
from kafka import KafkaConsumer
import json


class Consumer:
    def __init__(self, topic):
        self._consumer = KafkaConsumer(topic,
                                       bootstrap_servers='localhost:9092',
                                       value_deserializer=lambda x: json.loads(x.decode('utf-8')),
                                       group_id='nflx')

        self.data = []

    @property
    def consumer(self):
        return self._consumer

    @consumer.setter
    def consumer(self, value):
        if isinstance(value, KafkaConsumer):
            self._consumer = value

    def iniciar_consumicion(self):
        self.receive_message()

    def receive_message(self):
        message_count = 0
        for message in self._consumer:
            message = message.value
            print(f'Message {message_count}: {message}')
            self.data.append(message)
            message_count += 1

# %% [markdown]
# Ya solo nos queda instanciar el consumidor e iniciar su lectura de los eventos enviados por el productor invocando al método `iniciar_consumición`.

# %%
consumer = Consumer(nombre_topico)
consumer.iniciar_consumicion()
# Out:
# Message 0: {'date': '2023-02-21', 'open_price': 342.850006, 'high': 344.130005, 'low': 336.420013, 'close_price': 337.5, 'adj_close': 337.5, 'volume': 5710300}
# Message 1: {'date': '2023-02-22', 'open_price': 337.5, 'high': 341.910004, 'low': 332.820007, 'close_price': 334.880005, 'adj_close': 334.880005, 'volume': 4546200}
# Message 2: {'date': '2023-02-23', 'open_price': 331.230011, 'high': 331.279999, 'low': 314.299988, 'close_price': 323.649994, 'adj_close': 323.649994, 'volume': 13238700}
# Message 3: {'date': '2023-02-24', 'open_price': 319.299988, 'high': 321.5, 'low': 314.519989, 'close_price': 317.149994, 'adj_close': 317.149994, 'volume': 6830700}
# Message 4: {'date': '2023-02-27', 'open_price': 323.869995, 'high': 330.0, 'low': 322.119995, 'close_price': 323.029999, 'adj_close': 323.029999, 'volume': 6142600}
# Message 5: {'date': '2023-02-28', 'open_price': 323.700012, 'high': 327.619995, 'low': 321.170013, 'close_price': 322.130005, 'adj_close': 322.130005, 'volume': 3676100}
# Message 6: {'date': '2023-03-01', 'open_price': 321.549988, 'high': 326.600006, 'low': 312.359985, 'close_price': 313.480011, 'adj_close': 313.480011, 'volume': 4911300}
# Message 7: {'date': '2023-03-02', 'open_price': 310.959991, 'high': 315.570007, 'low': 310.380005, 'close_price': 311.880005, 'adj_close': 311.880005, 'volume': 4911000}
# Message 8: {'date': '2023-03-03', 'open_price': 315.450012, 'high': 317.48999, 'low': 310.820007, 'close_price': 315.179993, 'adj_close': 315.179993, 'volume': 5953300}
# Message 9: {'date': '2023-03-06', 'open_price': 317.0, 'high': 323.299988, 'low': 311.839996, 'close_price': 312.029999, 'adj_close': 312.029999, 'volume': 5660700}
# Message 10: {'date': '2023-03-07', 'open_price': 312.679993, 'high': 314.299988, 'low': 306.619995, 'close_price': 308.470001, 'adj_close': 308.470001, 'volume': 4553100}
# Message 11: {'date': '2023-03-08', 'open_price': 309.290009, 'high': 311.829987, 'low': 305.75, 'close_price': 311.790009, 'adj_close': 311.790009, 'volume': 3479500}
# Message 12: {'date': '2023-03-09', 'open_price': 312.079987, 'high': 312.51001, 'low': 294.880005, 'close_price': 297.779999, 'adj_close': 297.779999, 'volume': 7443400}
# Message 13: {'date': '2023-03-10', 'open_price': 297.899994, 'high': 298.790009, 'low': 289.0, 'close_price': 292.76001, 'adj_close': 292.76001, 'volume': 5759300}
# Message 14: {'date': '2023-03-13', 'open_price': 287.339996, 'high': 299.23999, 'low': 285.329987, 'close_price': 293.51001, 'adj_close': 293.51001, 'volume': 6292400}
# Message 15: {'date': '2023-03-14', 'open_price': 295.970001, 'high': 297.450012, 'low': 290.309998, 'close_price': 294.940002, 'adj_close': 294.940002, 'volume': 5956700}
# Message 16: {'date': '2023-03-15', 'open_price': 292.51001, 'high': 306.309998, 'low': 292.279999, 'close_price': 303.790009, 'adj_close': 303.790009, 'volume': 9215300}
# Message 17: {'date': '2023-03-16', 'open_price': 304.75, 'high': 316.600006, 'low': 301.709991, 'close_price': 310.059998, 'adj_close': 310.059998, 'volume': 7903700}
# Message 18: {'date': '2023-03-17', 'open_price': 310.059998, 'high': 310.76001, 'low': 300.0, 'close_price': 303.5, 'adj_close': 303.5, 'volume': 6918800}
# Message 19: {'date': '2023-03-20', 'open_price': 299.790009, 'high': 307.5, 'low': 296.0, 'close_price': 305.130005, 'adj_close': 305.130005, 'volume': 5113400}
# Message 20: {'date': '2023-03-21', 'open_price': 306.320007, 'high': 307.920013, 'low': 300.429993, 'close_price': 305.790009, 'adj_close': 305.790009, 'volume': 4886300}
# Message 21: {'date': '2023-03-22', 'open_price': 306.309998, 'high': 306.450012, 'low': 293.540009, 'close_price': 293.899994, 'adj_close': 293.899994, 'volume': 5808000}
# Message 22: {'date': '2023-03-23', 'open_price': 304.679993, 'high': 322.779999, 'low': 304.140015, 'close_price': 320.369995, 'adj_close': 320.369995, 'volume': 15653300}
# Message 23: {'date': '2023-03-24', 'open_price': 320.630005, 'high': 331.829987, 'low': 320.630005, 'close_price': 328.390015, 'adj_close': 328.390015, 'volume': 12991700}
# Message 24: {'date': '2023-03-27', 'open_price': 327.549988, 'high': 336.440002, 'low': 324.410004, 'close_price': 327.660004, 'adj_close': 327.660004, 'volume': 8625800}
# Message 25: {'date': '2023-03-28', 'open_price': 326.059998, 'high': 333.320007, 'low': 321.279999, 'close_price': 323.519989, 'adj_close': 323.519989, 'volume': 6489400}
# Message 26: {'date': '2023-03-29', 'open_price': 326.290009, 'high': 332.850006, 'low': 325.730011, 'close_price': 332.029999, 'adj_close': 332.029999, 'volume': 6287300}
# Message 27: {'date': '2023-03-30', 'open_price': 340.269989, 'high': 343.290009, 'low': 335.299988, 'close_price': 338.429993, 'adj_close': 338.429993, 'volume': 7131500}
# Message 28: {'date': '2023-03-31', 'open_price': 340.049988, 'high': 345.839996, 'low': 337.200012, 'close_price': 345.480011, 'adj_close': 345.480011, 'volume': 5610200}
# Message 29: {'date': '2023-04-03', 'open_price': 341.829987, 'high': 348.579987, 'low': 340.399994, 'close_price': 348.279999, 'adj_close': 348.279999, 'volume': 4413700}
# Message 30: {'date': '2023-04-04', 'open_price': 348.48999, 'high': 349.799988, 'low': 343.950012, 'close_price': 346.75, 'adj_close': 346.75, 'volume': 3298100}
# Message 31: {'date': '2023-04-05', 'open_price': 345.299988, 'high': 345.429993, 'low': 336.25, 'close_price': 342.350006, 'adj_close': 342.350006, 'volume': 4205500}
# Message 32: {'date': '2023-04-06', 'open_price': 339.339996, 'high': 340.480011, 'low': 332.630005, 'close_price': 339.329987, 'adj_close': 339.329987, 'volume': 4660500}
# Message 33: {'date': '2023-04-10', 'open_price': 335.269989, 'high': 339.880005, 'low': 333.359985, 'close_price': 338.98999, 'adj_close': 338.98999, 'volume': 2657900}
# Message 34: {'date': '2023-04-11', 'open_price': 343.450012, 'high': 347.140015, 'low': 337.640015, 'close_price': 338.209991, 'adj_close': 338.209991, 'volume': 4044800}
# Message 35: {'date': '2023-04-12', 'open_price': 340.809998, 'high': 342.799988, 'low': 330.040009, 'close_price': 331.029999, 'adj_close': 331.029999, 'volume': 3965400}
# Message 36: {'date': '2023-04-13', 'open_price': 339.98999, 'high': 346.429993, 'low': 338.75, 'close_price': 346.190002, 'adj_close': 346.190002, 'volume': 7406400}
# Message 37: {'date': '2023-04-14', 'open_price': 342.940002, 'high': 344.850006, 'low': 336.410004, 'close_price': 338.630005, 'adj_close': 338.630005, 'volume': 5350500}
# Message 38: {'date': '2023-04-17', 'open_price': 338.0, 'high': 338.390015, 'low': 327.5, 'close_price': 332.720001, 'adj_close': 332.720001, 'volume': 6136000}
# Message 39: {'date': '2023-04-18', 'open_price': 335.0, 'high': 337.190002, 'low': 330.5, 'close_price': 333.700012, 'adj_close': 333.700012, 'volume': 17944500}
# Message 40: {'date': '2023-04-19', 'open_price': 324.209991, 'high': 325.75, 'low': 316.100006, 'close_price': 323.119995, 'adj_close': 323.119995, 'volume': 22128300}
# Message 41: {'date': '2023-04-20', 'open_price': 320.390015, 'high': 331.429993, 'low': 318.329987, 'close_price': 325.350006, 'adj_close': 325.350006, 'volume': 9947800}
# Message 42: {'date': '2023-04-21', 'open_price': 323.0, 'high': 328.290009, 'low': 319.5, 'close_price': 327.980011, 'adj_close': 327.980011, 'volume': 6348000}
# Message 43: {'date': '2023-04-24', 'open_price': 330.200012, 'high': 334.660004, 'low': 326.75, 'close_price': 329.019989, 'adj_close': 329.019989, 'volume': 5586600}
# Message 44: {'date': '2023-04-25', 'open_price': 328.5, 'high': 328.660004, 'low': 321.100006, 'close_price': 322.549988, 'adj_close': 322.549988, 'volume': 5426600}
# Message 45: {'date': '2023-04-26', 'open_price': 321.359985, 'high': 325.899994, 'low': 320.470001, 'close_price': 321.149994, 'adj_close': 321.149994, 'volume': 4623200}
# Message 46: {'date': '2023-04-27', 'open_price': 324.299988, 'high': 327.450012, 'low': 317.440002, 'close_price': 325.850006, 'adj_close': 325.850006, 'volume': 5618800}
# Message 47: {'date': '2023-04-28', 'open_price': 325.23999, 'high': 330.809998, 'low': 324.0, 'close_price': 329.929993, 'adj_close': 329.929993, 'volume': 4221900}
# Message 48: {'date': '2023-05-01', 'open_price': 329.440002, 'high': 331.230011, 'low': 318.089996, 'close_price': 324.119995, 'adj_close': 324.119995, 'volume': 5341500}
# Message 49: {'date': '2023-05-02', 'open_price': 325.0, 'high': 326.070007, 'low': 315.619995, 'close_price': 317.549988, 'adj_close': 317.549988, 'volume': 4318600}
# Message 50: {'date': '2023-05-03', 'open_price': 317.549988, 'high': 324.619995, 'low': 315.850006, 'close_price': 319.299988, 'adj_close': 319.299988, 'volume': 5064100}
# Message 51: {'date': '2023-05-04', 'open_price': 319.01001, 'high': 323.609985, 'low': 317.950012, 'close_price': 320.779999, 'adj_close': 320.779999, 'volume': 3879700}
# Message 52: {'date': '2023-05-05', 'open_price': 323.609985, 'high': 324.149994, 'low': 319.440002, 'close_price': 322.76001, 'adj_close': 322.76001, 'volume': 3988600}
# Message 53: {'date': '2023-05-08', 'open_price': 322.98999, 'high': 332.559998, 'low': 322.029999, 'close_price': 331.209991, 'adj_close': 331.209991, 'volume': 5488600}
# Message 54: {'date': '2023-05-09', 'open_price': 330.670013, 'high': 336.320007, 'low': 329.73999, 'close_price': 332.140015, 'adj_close': 332.140015, 'volume': 5544900}
# Message 55: {'date': '2023-05-10', 'open_price': 335.209991, 'high': 337.109985, 'low': 329.51001, 'close_price': 335.420013, 'adj_close': 335.420013, 'volume': 4289900}
# Message 56: {'date': '2023-05-11', 'open_price': 334.980011, 'high': 345.470001, 'low': 331.839996, 'close_price': 344.76001, 'adj_close': 344.76001, 'volume': 8033500}
# Message 57: {'date': '2023-05-12', 'open_price': 344.76001, 'high': 348.170013, 'low': 337.359985, 'close_price': 339.890015, 'adj_close': 339.890015, 'volume': 6079900}
# Message 58: {'date': '2023-05-15', 'open_price': 340.619995, 'high': 341.899994, 'low': 335.540009, 'close_price': 335.890015, 'adj_close': 335.890015, 'volume': 3653000}
# Message 59: {'date': '2023-05-16', 'open_price': 334.0, 'high': 335.170013, 'low': 331.910004, 'close_price': 333.75, 'adj_close': 333.75, 'volume': 3332200}
# Message 60: {'date': '2023-05-17', 'open_price': 331.76001, 'high': 341.380005, 'low': 329.619995, 'close_price': 339.959991, 'adj_close': 339.959991, 'volume': 3958800}
# Message 61: {'date': '2023-05-18', 'open_price': 347.25, 'high': 375.869995, 'low': 346.369995, 'close_price': 371.290009, 'adj_close': 371.290009, 'volume': 20925200}
# Message 62: {'date': '2023-05-19', 'open_price': 369.859985, 'high': 369.98999, 'low': 363.809998, 'close_price': 365.359985, 'adj_close': 365.359985, 'volume': 7850900}
# Message 63: {'date': '2023-05-22', 'open_price': 365.359985, 'high': 372.01001, 'low': 362.5, 'close_price': 363.01001, 'adj_close': 363.01001, 'volume': 5406400}
# Message 64: {'date': '2023-05-23', 'open_price': 360.23999, 'high': 364.170013, 'low': 354.309998, 'close_price': 355.98999, 'adj_close': 355.98999, 'volume': 6866100}
# Message 65: {'date': '2023-05-24', 'open_price': 356.929993, 'high': 367.149994, 'low': 356.630005, 'close_price': 364.850006, 'adj_close': 364.850006, 'volume': 7973300}
# Message 66: {'date': '2023-05-25', 'open_price': 359.609985, 'high': 367.450012, 'low': 357.420013, 'close_price': 359.0, 'adj_close': 359.0, 'volume': 6263100}
# Message 67: {'date': '2023-05-26', 'open_price': 361.100006, 'high': 383.76001, 'low': 356.0, 'close_price': 378.880005, 'adj_close': 378.880005, 'volume': 9360400}
# Message 68: {'date': '2023-05-30', 'open_price': 397.480011, 'high': 405.109985, 'low': 385.790009, 'close_price': 392.980011, 'adj_close': 392.980011, 'volume': 10865000}
# Message 69: {'date': '2023-05-31', 'open_price': 391.890015, 'high': 396.26001, 'low': 388.910004, 'close_price': 395.230011, 'adj_close': 395.230011, 'volume': 6988000}
# Message 70: {'date': '2023-06-01', 'open_price': 397.410004, 'high': 407.519989, 'low': 393.079987, 'close_price': 403.130005, 'adj_close': 403.130005, 'volume': 7160100}
# Message 71: {'date': '2023-06-02', 'open_price': 402.890015, 'high': 406.579987, 'low': 395.899994, 'close_price': 400.470001, 'adj_close': 400.470001, 'volume': 5897300}
# Message 72: {'date': '2023-06-05', 'open_price': 400.470001, 'high': 413.859985, 'low': 400.149994, 'close_price': 403.540009, 'adj_close': 403.540009, 'volume': 7247400}
# Message 73: {'date': '2023-06-06', 'open_price': 405.0, 'high': 405.119995, 'low': 396.929993, 'close_price': 399.290009, 'adj_close': 399.290009, 'volume': 4991500}
# Message 74: {'date': '2023-06-07', 'open_price': 410.429993, 'high': 418.950012, 'low': 399.230011, 'close_price': 399.769989, 'adj_close': 399.769989, 'volume': 11932400}
# Message 75: {'date': '2023-06-08', 'open_price': 399.769989, 'high': 409.540009, 'low': 396.339996, 'close_price': 409.369995, 'adj_close': 409.369995, 'volume': 5991100}
# Message 76: {'date': '2023-06-09', 'open_price': 424.5, 'high': 425.899994, 'low': 414.76001, 'close_price': 420.019989, 'adj_close': 420.019989, 'volume': 12363000}
# Message 77: {'date': '2023-06-12', 'open_price': 418.829987, 'high': 424.700012, 'low': 416.570007, 'close_price': 423.970001, 'adj_close': 423.970001, 'volume': 5959500}
# Message 78: {'date': '2023-06-13', 'open_price': 430.01001, 'high': 437.269989, 'low': 428.399994, 'close_price': 435.730011, 'adj_close': 435.730011, 'volume': 7820500}
# Message 79: {'date': '2023-06-14', 'open_price': 434.98999, 'high': 447.329987, 'low': 433.5, 'close_price': 440.859985, 'adj_close': 440.859985, 'volume': 8413100}
# Message 80: {'date': '2023-06-15', 'open_price': 444.100006, 'high': 448.649994, 'low': 439.5, 'close_price': 445.269989, 'adj_close': 445.269989, 'volume': 7099900}
# Message 81: {'date': '2023-06-16', 'open_price': 446.149994, 'high': 447.51001, 'low': 430.899994, 'close_price': 431.959991, 'adj_close': 431.959991, 'volume': 8745500}
# Message 82: {'date': '2023-06-20', 'open_price': 430.179993, 'high': 440.0, 'low': 430.0, 'close_price': 434.700012, 'adj_close': 434.700012, 'volume': 4756000}
# Message 83: {'date': '2023-06-21', 'open_price': 432.649994, 'high': 434.549988, 'low': 422.540009, 'close_price': 424.450012, 'adj_close': 424.450012, 'volume': 5146400}
# Message 84: {'date': '2023-06-22', 'open_price': 422.929993, 'high': 424.709991, 'low': 418.679993, 'close_price': 422.480011, 'adj_close': 422.480011, 'volume': 4869500}
# Message 85: {'date': '2023-06-23', 'open_price': 418.589996, 'high': 425.820007, 'low': 417.730011, 'close_price': 424.019989, 'adj_close': 424.019989, 'volume': 8293900}
# Message 86: {'date': '2023-06-26', 'open_price': 422.440002, 'high': 430.959991, 'low': 414.899994, 'close_price': 415.940002, 'adj_close': 415.940002, 'volume': 4640000}
# Message 87: {'date': '2023-06-27', 'open_price': 417.390015, 'high': 420.880005, 'low': 411.5, 'close_price': 417.079987, 'adj_close': 417.079987, 'volume': 4818100}
# Message 88: {'date': '2023-06-28', 'open_price': 423.100006, 'high': 437.290009, 'low': 422.890015, 'close_price': 429.839996, 'adj_close': 429.839996, 'volume': 8811300}
# Message 89: {'date': '2023-06-29', 'open_price': 434.329987, 'high': 437.850006, 'low': 426.149994, 'close_price': 428.23999, 'adj_close': 428.23999, 'volume': 4932300}
# Message 90: {'date': '2023-06-30', 'open_price': 431.100006, 'high': 444.119995, 'low': 431.100006, 'close_price': 440.48999, 'adj_close': 440.48999, 'volume': 7342000}
# Message 91: {'date': '2023-07-03', 'open_price': 439.76001, 'high': 441.549988, 'low': 431.619995, 'close_price': 441.440002, 'adj_close': 441.440002, 'volume': 3733200}
# Message 92: {'date': '2023-07-05', 'open_price': 444.910004, 'high': 450.970001, 'low': 439.619995, 'close_price': 445.899994, 'adj_close': 445.899994, 'volume': 6869500}
# Message 93: {'date': '2023-07-06', 'open_price': 440.0, 'high': 442.799988, 'low': 430.720001, 'close_price': 438.839996, 'adj_close': 438.839996, 'volume': 4938800}
# Message 94: {'date': '2023-07-07', 'open_price': 438.600006, 'high': 442.329987, 'low': 435.839996, 'close_price': 438.100006, 'adj_close': 438.100006, 'volume': 4160100}

# %% [markdown]
# ### 4. Ejercicios

# %% [markdown]
# #### Ejercicio 1 - Modulo `io`
#
# Usando un stream `ByteIO` que tome como entrada la cadena `Tengan cuidado, ese mancebo es un gorila frenetico`, realiza tres lecturas, en el orden indicado abajo, sobre dicho stream usando el comando `.read`
#
# - Una primera lectura que solo obtenga la parte *Tengan cuidado,*
# - Una segunda lectura que solo obtenga la parte *ese mancebo es un gorila frenetico.*
# - Una tercera lectura que obtenga la frase entera (PISTA: recuerda lo que hacía el comando `.seek`).

# %% [markdown]
# Solución

# %%
texto = io.BytesIO(b"Tengan cuidado, ese mancebo es un gorila frenetico")

parte1 = texto.read(16)
print(parte1)

parte2 = texto.read(38)
print(parte2)

texto.seek(0)
parte3 = texto.read()
print(parte3)
# Out:
# b'Tengan cuidado, '
# b'ese mancebo es un gorila frenetico'
# b'Tengan cuidado, ese mancebo es un gorila frenetico'

# %% [markdown]
# #### Ejercicio 2 - Módulo `asyncIO`

# %% [markdown]
# Definir la corrutina que reciba como argumentos un número inicial, un número final y un retardo, de forma que imprima todos los números desde el numero inicial al final y entre casa impresión se espere los segundos indicadaos por el retardo.
#
# Ejecutar tres instancias de dicha corutina, cada una con un rango de valores diferente:
# - Una corutina que imprima los número del 10 al 20 con un retardo de 1 segundo.
# - Otra corutina que imprima los números del 20 al 30 con un retardo de 0.5 segundos y
# - otra corutina que imprima los números del 30 al 40 con un retardo de 2 segundos.

# %% [markdown]
# Solución:

# %%
import asyncio

async def print_numbers_with_delay(start, end, delay):
  for i in range(start, end + 1):
    print(i)
    await asyncio.sleep(delay)

async def main():
  await asyncio.gather(
      print_numbers_with_delay(10, 20, 1),
      print_numbers_with_delay(20, 30, 0.5),
      print_numbers_with_delay(30, 40, 2)
  )

await main()
# Out:
# 10
# 20
# 30
# 21
# 11
# 22
# 23
# 31
# 12
# 24
# 25
# 13
# 26
# 27
# 32
# 14
# 28
# 29
# 15
# 30
# 33
# 16
# 17
# 34
# 18
# 19
# 35
# 20
# 36
# 37
# 38
# 39
# 40

# %% [markdown]
# #### Ejercicio 3 - Apache Kafka
#
# Modifica el código del consumidor para almacenar el máximo valor de la cotización recibida hasta el momento. Para ello, se deberá consultar el campo `open_price` de los eventos recibidos.
#
# **IMPORTANTE: Para poder probar este ejercicio es necesario reiniciar el entorno de ejecución en *Google Collab*. Para ello, pulsa sobre el menú `Entorno de ejecución -> Reiniciar sesión`**
#
# Una vez reiniciado el entorno, ejecutamos de nuevo las siguientes instrucciones para iniciar Kafka y el productor que ya vimos antes.

# %% [markdown]
# A continuacion ya puedes definir tu consumidor. Inserta el código dentro de la función `receive_message`.

# %%
#Instalamos la librería de kafka-python
# !pip install kafka-python
#Descargamos y arrancamos Apache Kafka
# !curl -sSOL https://dlcdn.apache.org/kafka/3.6.2/kafka_2.13-3.6.2.tgz
# !tar -xzf kafka_2.13-3.6.2.tgz
# !./kafka_2.13-3.6.2/bin/zookeeper-server-start.sh -daemon ./kafka_2.13-3.6.2/config/zookeeper.properties
# !./kafka_2.13-3.6.2/bin/kafka-server-start.sh -daemon ./kafka_2.13-3.6.2/config/server.properties
# !echo "Esperamos 10 segundos hasta que los servicios kafka y zookeeper están activos y funcionando"
# !sleep 10
# !./kafka_2.13-3.6.2/bin/kafka-topics.sh --create --topic netflix --bootstrap-server localhost:9092
#Iniciamos el productor
# !nohup python -m producer NFLX.csv netflix 5 &

# %%
from kafka import KafkaConsumer
import json


class Consumer:
    def __init__(self, topic):
        self._consumer = KafkaConsumer(topic,
                                       bootstrap_servers='localhost:9092',
                                       value_deserializer=lambda x: json.loads(x.decode('utf-8')),
                                       group_id='nflx')

        self._max_value= -1

    @property
    def consumer(self):
        return self._consumer

    @consumer.setter
    def consumer(self, value):
        if isinstance(value, KafkaConsumer):
            self._consumer = value

    def iniciar_consumicion(self):
        self.receive_message()

    def receive_message(self):
      #Inserta aquí la funcionalidad solicitada en el ejercicio
      pass

# %%
consumer = Consumer('netflix')
consumer.iniciar_consumicion()

# %% [markdown]
# Solución

# %% [markdown]
# ## Referencias
#
# [Super Fast Python. Python Asyncio: The Complete Guide. 2023](https://superfastpython.com/python-asyncio/)

# %% [markdown]
# ¡Eso es todo amigos!
